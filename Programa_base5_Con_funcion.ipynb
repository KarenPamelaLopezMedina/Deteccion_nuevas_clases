# %% [markdown]
# ---
# # Banco de datos
# ---

# %%
# CAMBIOS: 

#Cambio 1
# se añadela variable mc_st en la ceda de parámetros de usuario, esta nos permite introducir el número de clusteres que deseamos crear una vez que se pueda analizar la stm.

#Cambio 2:
# Se agrega la cadena= base2 para identificar más facilmente los archivos de tiempo que se generen en esta versión.
# De la biblioteca timeit se importa default_timer como timer
# Se crea un data frame para guardar los tiempos que lleva cada proceso y saber en cuál tarda más.

#Cambio 3:
# Se eliminan las siguientes funciones: matrix_similarity_clusters y values
# Se crea la funcion g_h_o_s que reemplaza a las funciones eliminadas

# Cambio 4: 
# Ya no se mide el tiempo de la matriz GHOS porque ya no se hace.
# Se miden los tiempos en la STM para ver dónde se tarda más.
# Se tarda más en la función Analysis.
# Se miden los tiempos dentro de la función de Analysis para saber donde se tarda más.
# Se tarda más en A6

# %% [markdown]
# Importing libraries.

# %%
import pandas as pd
import numpy as np
import math
# Bibliotecas para hacer clustering
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from sklearn.model_selection import LeaveOneOut
from statistics import mean 
from datetime import datetime #Ayuda a contar el tiempo de análisis en la ventana

# import collections
from itertools import groupby
# importar un "cronómetro"
from timeit import default_timer as timer

# %%
S = pd.read_csv('/home/abril/Escritorio/Karen 2022/Bancos/normal2000_smurf2000_neptune.csv')
cadena = 'base5_caso2'

# %%
# S = S[:round(len(S.index)*.1)]
S = S[:98000] # 42000 # 98000
S
# Out:
#        Unnamed: 0  atrib1 atrib2    atrib3 atrib4  atrib5  atrib6  atrib7  \
# 0          256368       0   icmp     ecr_i     SF    1032       0       0
# 1          453300       0    udp  domain_u     SF      46      46       0
# 2          256244       0   icmp     ecr_i     SF    1032       0       0
# 3          453038       0    udp  domain_u     SF      42      42       0
# 4          256453       0   icmp     ecr_i     SF    1032       0       0
# ...           ...     ...    ...       ...    ...     ...     ...     ...
# 97995       59929       0   icmp     ecr_i     SF    1032       0       0
# 97996       22900       0   icmp     ecr_i     SF    1032       0       0
# 97997      350839       0    tcp   private    REJ       0       0       0
# 97998      226133       0   icmp     ecr_i     SF    1032       0       0
# 97999      232417       0   icmp     ecr_i     SF    1032       0       0
#
#        atrib8  atrib9  ...  atrib33  atrib34  atrib35  atrib36  atrib37  \
# 0           0       0  ...      255      1.0     0.00     1.00      0.0
# 1           0       0  ...      255      1.0     0.00     0.01      0.0
# 2           0       0  ...      255      1.0     0.00     1.00      0.0
# 3           0       0  ...      255      1.0     0.00     0.01      0.0
# 4           0       0  ...      255      1.0     0.00     1.00      0.0
# ...       ...     ...  ...      ...      ...      ...      ...      ...
# 97995       0       0  ...      255      1.0     0.00     1.00      0.0
# 97996       0       0  ...      255      1.0     0.00     1.00      0.0
# 97997       0       0  ...        1      0.0     0.06     0.00      0.0
# 97998       0       0  ...      255      1.0     0.00     1.00      0.0
# 97999       0       0  ...      255      1.0     0.00     1.00      0.0
#
#        atrib38  atrib39  atrib40  atrib41     clase
# 0          0.0      0.0      0.0      0.0    smurf.
# 1          0.0      0.0      0.0      0.0   normal.
# 2          0.0      0.0      0.0      0.0    smurf.
# 3          0.0      0.0      0.0      0.0   normal.
# 4          0.0      0.0      0.0      0.0    smurf.
# ...        ...      ...      ...      ...       ...
# 97995      0.0      0.0      0.0      0.0    smurf.
# 97996      0.0      0.0      0.0      0.0    smurf.
# 97997      0.0      0.0      1.0      1.0  neptune.
# 97998      0.0      0.0      0.0      0.0    smurf.
# 97999      0.0      0.0      0.0      0.0    smurf.
#
# [98000 rows x 43 columns]

# %% [markdown]
# # Parámetros de usuario

# %%
# Preguntar si la clase es numérica o categórica. 
# class_type lo usa preprocessing_label_coding function
class_type = 'c' #input('Is the class numeric "n" or categorical "c"? ')
# Introduce the instances for training the model
InitNumber = 2000 #int(input("Introduce the InitNumber: "))
# Introduce the instances for the step window
paso = 2000 #int(input("Window size: "))
# Introduce the instances for the short term memory
n_elements_stm = 100 # 50 o 100
# Introduce el numero de instancias para determinar si un cluster es válido
n_representative = 30
# Al Timestamp actual se le resta ventana_de_olvido para que instancias mas viejas
# que esa diferencia se eliminen 
ventana_de_olvido = 2000 # más grande
#paso * 0.5 # Ventana para no tener instancias viejas en el short_term_memory
mc_stm = 3 # Número de clústeres que se harán en la stm

# %% [markdown]
# ---
# # Modulos
# ---

# %% [markdown]
# # LABEL CODING
#
# The following function is for convert categoric attributes to label coding.
#
# Ordenate the dataframe as follows: label coding columns, numeric columns and CLASS columns.
#
# The function returns:
# - Preprocessed Dataframe.
# - Categoric columns names.
# - Numeric columns names.

# %%
def preprocessing_label_coding(S, class_type):
    """ Returns a preprocessed dataframe, for categoric attributes we use label
        coding
    INPUT: 
    - S: is the dataframe.
    - class_type: is a letter c indicates categoric and n numeric.
    OUTPUT:
    - S1: is the preprocessed dataframe.
    - num_col_names: names of the numeric attributes.
    - cat_col_names: names of the categoric attributes.
    """
    # Ask if the class is numeric or categoric.
    # class_type = input('Is the class numeric "n" or categorical "c"?')
    #Rename the last column
    S.columns = [*S.columns[:-1], 'CLASS']

    # Numeric columns
    S_numeric = S.select_dtypes(exclude='object') #This is a dataframe only with numeric attributes
    # Numeric colum names
    num_col_names = list(S_numeric.columns)

    # Categorical columns
    S_categorical = S.select_dtypes(include='object')
    # Numeric colum names
    cat_col_names = list(S_categorical.columns)
    # How many colums are categorical
    len_categorical = len(cat_col_names)

    # Label coding for categoric attributes
    aux_data = pd.DataFrame(columns = cat_col_names)
    # To do label coding:
    # 1. Convert object type to category type
    # 2 .cat.codes is for transform the categories to numbers
    # +1 because the labels starts at 0 and NaN -1 but I want that Nan = 0
    for i in range(len_categorical):
        aux_data[cat_col_names[i]] = S_categorical[cat_col_names[i]].astype('category').cat.codes + 1

    # S_categorical = label coding, zeros are replaced by NaN
    S_categorical = aux_data.replace(0,np.NaN)

    # ORDER my final dataframe with the following order:
    # Categoric columns, Numeric colums, Class column
    if class_type == 'c':
        class_colum = S_categorical['CLASS'] 
        S_categorical.drop("CLASS", axis=1, inplace=True) #Delete class_col
        cat_col_names.pop() #Eliminate CLASS for this list
        S1 = pd.concat([S_categorical,S_numeric,class_colum], axis=1) 
    else:
        print('numeric')
        A = S_numeric.shape
        if A[1] == 1: #If numeric columns only has the class column
            print(A[1])
            class_colum = S_numeric['CLASS']
            S1 = pd.concat([S_categorical,class_colum], axis=1) #Numeric columns will be empty
            num_col_names.pop() #Eliminate CLASS for this list
        else:
            print(A[1])
            class_colum = S_numeric['CLASS']
            S_numeric.drop("CLASS", axis=1, inplace=True)
            S1 = pd.concat([S_categorical,S_numeric,class_colum], axis=1)
            num_col_names.pop() #Eliminate CLASS for this list
    #print(S1)
    return S1, num_col_names, cat_col_names

# %% [markdown]
# # Modelo inicial de entrenamiento
#
#
# This first phase is the initial training of the algorithm. A set of labeled instances will be needed to create the initial model.
# As suggestion the Initial Number will be 2,000.

# %%
# - - - - - - - - - - MODEL TRAIN - - - - - - - - - -
def create_model_train(S1, InitNumber):
    """ Create the model train  
    INPUT: 
    - S1
    OUTPUT:
    - Model Train
    """
    # InitNumber = input("Introduce the InitNumber: ")
    #InitNumber = int(InitNumber)

    # Take the first window
    model_train = S1[:InitNumber]
    # Delete the model train instances from S1
    aux_index = model_train.index.tolist()
    S1 = S1.drop(aux_index)
   
    # To convert NaN to zeros
    model_train = model_train.fillna(0)
    return S1, model_train

# %% [markdown]
# ---
# # Microcluster information
# - Timestamp
# - Number of instances. Número de instancias
# - LS Linear sum. Suma lineal
# - SS Cuadratic sum. Suma cuadrática
# - Cj label of the class to which they belong. Etiqueta de la clase perteneciente
# - Centroid. Centroide
# - Radius. Radio

# %%
def microcluster_information(j, i):
    """Cálculo de la información del microcluster por 1era vez.
    Para actualizaciones del mc se usa la función update"""   
    # Time stamp
    globals()['T_'+str(Cj[j])+'_'+str(i+1)] = globals()['MC_'+str(Cj[j])+'_'+str(i+1)].index[-1]
    # Instance number
    globals()['N_'+str(Cj[j])+'_'+str(i+1)] = len(globals()['MC_'+str(Cj[j])+'_'+str(i+1)].index)
    # Lineal Sum
    globals()['LS_'+str(Cj[j])+'_'+str(i+1)] = (globals()['MC_'+str(Cj[j])+'_'+str(i+1)].sum(axis=0)).drop(labels=['CLUSTER'])
    # Square Sum
    globals()['SS_'+str(Cj[j])+'_'+str(i+1)] = np.square(globals()['MC_'+str(Cj[j])+'_'+str(i+1)]).sum(axis=0).drop(labels=['CLUSTER'])
    # Centroid LS/N
    globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)] = globals()['LS_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]
    # Radius ( (SS/N) - pow(LS / N,2) ) ** 0.5
    globals()['Radius_MC_'+str(Cj[j])+'_'+str(i+1)] = ((globals()['SS_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]) - np.square(globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)])) ** 0.5
    # Standard deviation
    globals()['SD_'+str(Cj[j])+'_'+str(i+1)] = np.square(globals()['MC_'+str(Cj[j])+'_'+str(i+1)].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)]).sum(axis=0)
    # Sigma
    globals()['sigma_'+str(Cj[j])+'_'+str(i+1)] = (globals()['SD_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]) ** 0.5

# %% [markdown]
# # GHOS SIMILARITY
#
# It recives the instance and returns the max value of similarity and says in which class and cluster is.

# %%
def g_h_o_s(num_cluster, Cj, X_test, option):
    """ This function applies the GHOS numeric similarity &
        applies clostest clusters centroid 4 short term memory
    INPUT: 
    - Cj: a list with class labels
    - num_cluster: a list with the number of cluster for each class
    - instance: the instance to compare
    - option: 'similarity' means compute similarity function
            : 'euclidean' means euclidean distance
    OUTPUT: 
    - matrix (option 'similarity'): a dataframe with the clusters and classes and their similarity
    - matrix (option 'euclidean'): a dataframe with the euclidean distances between one short term
                         memory cluster and the microclusters centroids 
                         
    
    After similarity function, this function returns the cluster, class and max
        value corresponding to the X_test
    INPUT:
    - matrix: is a matrix of whom we will get the max/min cluster/class
              with classes as rows and cluster as columns
    - option: 1 maximo means class max, cluster max, and max value
              2 minimo means class min, cluster min, and min value
    OUTPUT
    - winning_class: The majority class 
    - winning_cluster: The majority cluster
    - winning_value: The majority value
    """
    instance = X_test
    # print("y test: " + str(int(y_test)))
    # Matrix similarity clusters
    k = 0 
    columns = []   
    class_ghos = []
    index =[]
    G = []
    i_class = [] 
    i_clust = []
    
    if option == 'classification':
        # Hacer un vector con los clusteres de cada clase
        for k in range(len(Cj)): # Num of classes
            for i in range(num_cluster[k]): # Num clusters
                i_class.append('Clas_' + str(Cj[k]))
                i_clust.append('Clust_' + str(i+1))
                #index.append('Clas_' + str(Cj[k]) + '_Clust_' + str(i+1))
                #print('Centroid_MC_'+str(Cj[k])+'_'+str(i+1))
                #print('sigma_'+str(Cj[k])+'_'+str(i+1))
                # - - - - GHOS numeric - - - -
                GHOS = (abs( instance - globals()['Centroid_MC_'+str(Cj[k])+'_'+str(i+1)] ) <= globals()['sigma_'+str(Cj[k])+'_'+str(i+1)]).sum(axis=1)
                G.append(GHOS.iloc[0])
        #print(i_class)
        #print(i_clust)
        #print(G)
        # Values winning_class, winning_cluster y ghos
        # Quiero saber el máximo de la lista
        ghos = max(G)
        #print("GHOS: " +str(ghos))
        # Quiero saber la posición de ese valor máximo
        max_index = G.index(ghos) 
        # Quiero saber la clase donde se encuentra este minimo
        winning_class = int(i_class[max_index].replace('Clas_', ''))
        #print("class: " +str(winning_class))
        # Cluster donde se encuentra el mínimo
        winning_cluster = int(i_clust[max_index].replace('Clust_', ''))
        #print("clust: " +str(winning_cluster))
        
    else: #option == novel_detection
        # Hacer un vector con los clusteres de cada clase
        for k in range(len(Cj)): # Num of classes
            for i in range(num_cluster[k]): # Num clusters
                i_class.append('Clas_' + str(Cj[k]))
                i_clust.append('Clust_' + str(i+1))
                #index.append('Clas_' + str(Cj[k]) + '_Clust_' + str(i+1))
                #print('Centroid_MC_'+str(Cj[k])+'_'+str(i+1))
                #print('sigma_'+str(Cj[k])+'_'+str(i+1))
                # - - - - GHOS numeric - - - -
                GHOS = math.sqrt((np.square(instance - globals()['Centroid_MC_'+str(Cj[k])+'_'+str(i+1)])).sum())
                G.append(GHOS)
            ##print(i_class)
            ##print(i_clust)
            ##print(G)
        # Quiero saber el mínimo de la lista
        ghos = min(G) #ghos = b
        ##print("GHOS: " +str(ghos))
        # Quiero saber la posición de ese valor máximo
        min_index = G.index(ghos) 
        print(min_index)
        # Quiero saber la clase donde se encuentra este minimo
        winning_class = int(i_class[min_index].replace('Clas_', ''))
        print("class: " +str(winning_class))
        # Cluster donde se encuentra el mínimo
        winning_cluster = int(i_clust[min_index].replace('Clust_', ''))
        print("clust: " +str(winning_cluster))

    return winning_class, winning_cluster, ghos

# %% [markdown]
# # MICROCLUSTER UPDATE
#
# After calculating the GHOS similarity value and the threshold comparision if that value is equal or bigger than the threshold, the instant test is added to its respective cluster. And it must to be updated.

# %%
# - - - - - - - - - - MICROCLUSTER UPDATE - - - - - - - - - -
def update_microcluster(winning_class, winning_cluster, X_test):
    """ This function refresh cluster statistics  
    INPUT: 
    - winning_class: Class of the microcluster to be updated
    - winning_cluster: Cluster of the microcluster to be updated
    OUTPUT:
    - Microcluster updated
    """
    # Actualización del microcluster
    # Time stamp
    globals()['T_'+str(winning_class)+'_'+str(winning_cluster)] = X_test.index[-1]
    # Instance number
    globals()['N_'+str(winning_class)+'_'+str(winning_cluster)] = 1 + globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]   
    # Lineal Sum
    globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] = X_test.iloc[0] + globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] 
    # Square Sum
    globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)] = np.square(X_test.iloc[0]) + globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)]
    # Centroid LS/N
    globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)] = globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]
    # Radius ( (SS/N) - pow(LS / N,2) ) ** 0.5
    globals()['Radius_MC_'+str(winning_class)+'_'+str(winning_cluster)] = ((globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]) - np.square(globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)]))**0.5
    # Standard deviation
    globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)] = np.square(X_test.iloc[0] - globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)]) + globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)]
    # Sigma
    globals()['sigma_'+str(winning_class)+'_'+str(winning_cluster)] = (globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]) ** 0.5

# %% [markdown]
# ---
# # Short Term Memory

# %%
# - - - - - - - - - - CLUSTERS SHORT TERM MEMORY - - - - - - - - - -
def clusters_stm(short_term_memory, mc_stm):
    """ Returns the clusters obteined of short term memory  
    INPUT: 
    - short term memory: data set of the instances belonging to short term memory
    OUTPUT:
    - Clusters: Is the same dataset as short term memory only with the difference of adding a
      column wich indicates the number of what cluster of whats belongs that instance.
    """
    n_clusters_stm = []
    #n_clusters_stm.append(int(input("Introduce number of clusters: ")))
    n_clusters_stm.append(mc_stm) ###PARÁMETRO QUE CAMBIA
    kmeans_stm = KMeans(n_clusters = n_clusters_stm[-1], random_state=0).fit(short_term_memory) ##Apply k-means clustering
    centroides = kmeans_stm.cluster_centers_
    labels2 = pd.Series(kmeans_stm.labels_ + 1)
    # Ese array lo pasamos a forma de Dataframe
    labels2 = labels2.to_frame()
    # Para poderlo concatenar al model train tenemos que hacer que los índices de las instancias cuadren
    labels2.index = short_term_memory.index
    # Renombramos a la columna con la palabra CLUSTER
    labels2.rename( columns={0:'CLUSTER'}, inplace=True )
    Clusters = pd.concat([short_term_memory,labels2], axis=1)
    return Clusters, n_clusters_stm

# %%
def class_extension(Cj, clase_cercana, num_cluster, ShortCluster, aux_index_sc, \
    short_classes, aciertos_stm, index_right_stm, clasif_right_stm,\
    index_wrong_stm, clasif_wrong_stm, cluster_cercano, instancias_stm, n_ventana,\
    n_cluster_stm, N, T):
    """ This function create a cluster in a new class  
    INPUT: 
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - clase_cercana = La clase donde está la menor distancia de su centroide al 
                      centroide del n uevo microcluster.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, se debe 
                   de leer con Cj para entenderlo.
    - ShortCluster: el cluster a integrar como extensión de una clase. 
    - aux_index_sc: contiene los índices de las instancias de ese cluster obtenido del
                    Short Term Memory.
    - aciertos_stm: contador de instancias que son asignadas correctamente.
    - short_classes = son las clases originales/correctas de las instancias que están en
                      el Short Term Memory.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias asignadas.
    - index_wrong_stm = una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias NO asignadas.
    - n_ventana = es un entero que especifica que ventana se está analizando.

    OUTPUT:
    - Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, 
      clasif_wrong_stm
   """
    # Se añade la extensión de clase    
    idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
    idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
    idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

    clase_mayor_frecuencia = idx_clase # la clase original q:e más se repite
    
    # Se pregunta si la clase original con mayor repetición es igual a la calculada
    if clase_mayor_frecuencia == clase_cercana:
        print("La mayoría de los patrones son clase: " +str(clase_mayor_frecuencia) + ". Y la clase cercana detectada fue: " +str(clase_cercana))
        print("Se añade esta extensión de clase.")
        class_index = Cj.index(clase_cercana)
        num_cluster[class_index] = num_cluster[class_index] + 1
        globals()['MC_'+str(Cj[class_index])+'_'+str(num_cluster[class_index])] = ShortCluster
        
        #Se calculan las estadísticas de este nuevo microcluster
        microcluster_information(class_index, num_cluster[class_index]-1)
        for j in range(len(aux_index_sc)):    
            #Si la asignación fue correcta
            if int(short_classes.loc[aux_index_sc[j]]) == clase_cercana:
                aciertos_stm = aciertos_stm + 1
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_right_stm.append(aux_index_sc[j])
                new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], 'acierto':'asignada correctamente'}
                clasif_right_stm.append(new_clases)
                # new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": clase_cercana, "GHOS": instancias_stm.at[aux_index_sc[j]], 'acierto':'Bien'}
            else: # Si la asignacion fue incorrecta:
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                print("Se descarta la extensión de clase")
                index_wrong_stm.append(aux_index_sc[j])
                new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]), \
                "Clasificado en": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]),\
                "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], "STM":'YES', \
                'Acierto':'asignada incorrectamente', 'Ventana':n_ventana}
                clasif_wrong_stm.append(new_clases)

    else: # si no coincide, hay error y no se añade al modelo
        print("La clase cercana es : " + str(clase_cercana) + ", pero la clase con mayor repetición es: " + str(clase_mayor_frecuencia))
        print("Se descarta esta extensión")
        
        new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': clase_mayor_frecuencia,\
        'clase propuesta': clase_cercana, 'error': "extension", 'instancias': N, "T": T}
        no_emerging.append(new_emerging_clases)            
            
    short_classes = short_classes.drop(aux_index_sc)    
    return Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, short_classes

# %%
def emerging_class(Cj, clases_originales, num_cluster, ShortCluster, aux_index_sc, short_classes, \
    aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, \
    instancias_stm, n_ventana, n_cluster_stm, N, T):
    """ This function create a cluster in a new class  
    INPUT: 
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - ShortCluster: el cluster a integrar en una nueva clase o extensión de una clase. 
    - aux_index_sc: contiene los índices de las instancias de ese cluster obtenido\
                    del Short Term Memory.
    - short_classes = son las clases originales/correctas de las instancias que están en el\
                      Short Term Memory.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias asignadas.
    - index_wrong_stm = una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias NO asignadas.
    - instancias_stm
    - n_ventana = es un entero que especifica la ventana que se está utilizando

    OUTPUT:
    - Cj, num_cluster, short_classes, aciertos_stm, index_right_stm, clasif_right_stm, 
      index_wrong_stm, clasif_wrong_stm
    """
    # Se añade la nueva clase    
    idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
    idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
    idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

    nueva_clase = idx_clase

    # Se pregunta si el índice de la clase original ya había sido tratado en el modelo 
    if nueva_clase in Cj:  #Si es así, no intervendrá en el modelo
        print("La clase "+str(nueva_clase) + " ya existía.")

        new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': nueva_clase,\
        'clase propuesta': 0, 'error': "emergente", 'instancias': N, 'T': T}
        no_emerging.append(new_emerging_clases) 

    else: # Sí no es así, se crea el microcluster.
        print("La nueva clase es: " + str(nueva_clase))
        # Al 'vector' Cj se le añade como último elemento la nueva clase
        Cj.append(nueva_clase)

        # Sería el primer microcluster de esa clase
        num_cluster.append(1)

        # Se crea el nuevo microcluster
        globals()['MC_'+str(Cj[-1])+'_'+str(num_cluster[-1])] = ShortCluster

        #microcluster_information(clase, clluster)
        microcluster_information(len(Cj)-1, 0)

        # El siguiente ciclo for es para visualizar en un dataframe instancia por instancia
        # su clase original y el MC a la cual fue asignada
        for j in range(len(aux_index_sc)):
            # SABER NUMERO DE VENTANA, CLASE ASIGNADA
            # NUMERO DE ELEMENTOS DE LAS CLASES CORRECTAS EN ESTE MICROCLUSTER  
            # Si la asignación fue correcta
            if int(short_classes.loc[aux_index_sc[j]]) == nueva_clase:
                aciertos_stm = aciertos_stm + 1
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_right_stm.append(aux_index_sc[j])
                new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]),\
                "classified in": 'MC_'+str(nueva_clase)+'_'+str(1), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],\
                "stm":'YES', 'acierto':'Bien'}
                clasif_right_stm.append(new_clases)

            else: # Si la asignación fue incorrecta
                ## ESCRIBIR NUMERO DE VENTANAS, CLASE QUE DETECTÓ
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_wrong_stm.append(aux_index_sc[j])
                new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]),\
                "Clasificado en": 'MC_'+str(nueva_clase)+'_'+str(1),\
                "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],"STM":'YES',\
                'Acierto':'asignado incorrectamente.',
                'Ventana': n_ventana}
                clasif_wrong_stm.append(new_clases) 

    # CONTAR LA FRECUENCIA DE CADA CLASE CORRECTA EN ESTE MICROCLUSTER

    short_classes = short_classes.drop(aux_index_sc)
    
    return Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,index_wrong_stm, clasif_wrong_stm, short_classes

# %%
def analysis_stm(short_term_memory, short_classes, Clusters, n_clusters_stm,\
    Cj, clases_originales, num_cluster, aciertos_stm,index_right_stm, clasif_right_stm, index_wrong_stm,\
    clasif_wrong_stm, instancias_stm, n_ventana):
    """Checa si un cluster es o no es válido.
    Si es válido, hace la asignación como extensión de la clase o clase
    emergente.
    INPUT:
    - short_term_memory: 
    - short_classes: son las clases originales/correctas de las instancias que están en\
                     el Short Term Memory.
    - Clusters: Dataframe con las instancias clasificadas por clusters
    - n_clusters_stm: Es una lista que contiene el número de clusters que deseamos tener
                      de las isntancias del short term memory
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: es una lista que contiene los índices de las instancias de la 
                       short term memory que fueron asignadas correctamente.                       
    - clasif_right_stm: es un diccionario dentro de una lista que de cada instancia
                        de la stm, asignadas correctamente me da información para 
                        visualizarla en un dataframe, la información que me proporciona
                        es clase correcta, en cual se asignó y valor de GHOS. 
    - index_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    - clasif_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    - instancias_stm: Es el dataframe que da la información correcta y el valor de GHOS de
                      todas las instancias que se fueron al STM.
    - n_ventana:  es un entero que especifíaca el número de ventana que se está analizando
    
    OUTPUT:
    - Cj, short_term_memory, num_cluster, ShortCluster,aux_index_sc, short_classes, aciertos_stm,\
    index_right_stm, clasif_right_stm,index_wrong_stm,clasif_wrong_stm
    """
    
    print("Analysis")
    ## Tiempo de ejecución
    
    an_tot_stm = 0.0
    an1_stm = 0.0
    an_ini_stm = timer()
    
    for i in range(n_clusters_stm[-1]):
        n_cluster_stm = i + 1
        #Este es el cluster del short term memory a analizar
        ShortCluster = Clusters[Clusters['CLUSTER']==i+1]
        # Es cohesivo?
        # Calcular Silhouette. Para ello debemos de tener el centroide del microcluster.
        # Centroid LS/N
        N = len(ShortCluster.index)
        print("\n El cluster " + str(i+1) + " tiene: " + str(N) + " instancias.")
        print('LS')
        LS = (ShortCluster.sum(axis=0)).drop(labels=['CLUSTER'])
        print('LS')
        Centroid = LS / N
        Silhouette = 0  
        # - - - - - VALIDACION DEL CLUSTER - - - - - - - -     
        # Se verifica si es representativo, si lo es, se verifica si es cohesivo (Silhouette)
        # ...To identify if a cluster is cohesive, a modified silhouette coefficient will be used...
        
        # - - - - - - REPRESENTATIVO - - - - - - - - 
        if N >= n_representative: #Si es representativo entra a este for
        # Silhouette = b-a / max(a,b)
            clase_cercana, cluster_cercano, b = g_h_o_s(num_cluster, Cj, Centroid, 'novel_detection')
        # a standar deviation of the distance between each instance of the new microcluster
        # and the new microcluster centroid
            a = []
            for i in range(len(ShortCluster)):
            # a es una lista que almacena las distancias euclideanas entre cada instancia de ese
            # microcluster y el centroide.
                a.append(np.linalg.norm(ShortCluster.iloc[[i]].drop(['CLUSTER'], axis=1) - Centroid))
            # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
            # sqrt (((x_prom - x)**2 suma) / N )
            a = math.sqrt(((mean(a) - a)**2).sum() / len(a))
            ##  print("a: " + str(a))
            if max(b,a) != 0:
                Silhouette = (b - a) / max(b, a)
            # Verificar si el cluster es válido, significa que Silhouette > 0,
            # si es representativo y válido: instancias se eliminan del short term memory
                print("Silhouette: " + str(Silhouette))
                # print("b = " + str(b) + ". a = " + str(a))
            # - - - - - - - - - - - COHESIVO - - - - - -
                if Silhouette > 0: # El cluster es válido
                    aux_index_sc = ShortCluster.index.tolist()
                # Borrar estas instancias del short term memory y también sus clases
                    short_term_memory = short_term_memory.drop(aux_index_sc)
                    # - - - - NOVELTY PROCESS - - - - 
                    # - - - - - - Threshold - - - - - -
                    # T = la media de las distancias del centroide del microcluster de la clase 
                    # más cercana con respecto a los demás microclusters de esa clase
                    print("Cálculo de T")
                    Centroide_cercano = globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]
                    # print("Distancia entre el Centroide_"+ str(clase_cercana)+"_"+str(cluster_cercano) + " con respecto a:")
                    T = []
                    print("La clase cercana es: " + str(clase_cercana) + " y el cluster cercano es: " + str(cluster_cercano))
                    class_index = Cj.index(clase_cercana) # class index guarda la posición de Cj donde está la clase más cercana
                    # esta posición la busco en num_cluster para saber cuantos clusters hay en la clase más cercana 
                    for j in range(0, num_cluster[class_index]): # Modifiqué porque estaba malrange(0, cluster_cercano)
                        i = j + 1
                        if i != cluster_cercano: # Si el índice i coincide con cluster cercano no entra en esta sentencia porque
                            # no debe calcular la distancia con respecto a él mismo
                            print("Se compara con clase: "  + str(clase_cercana) + ", cluster: "+ str(i))
                            # la distancia se estaría compárando con respecto al mismo centroide 
                            T.append(np.linalg.norm(globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(i)] - Centroide_cercano))
                            # print("Centroide más cercano vs Centroide_" + str(clase_cercana) + "_"+str(i+1))
                    print("T antes del promedio: " + str(T))
                    if len(T) >= 1: #Significa que hay al menos 2 clusteres de esa clase
                        print("T tiene más de un micro cluster en esa clase.")
                        T = sum(T)/len(T)
                        print("T = " + str(T))
                    else: #Significa que solo hay un cluster de esa clase
                        #Aquí 
                        print("T solo tiene 1 microcluster en esa clase, hay que recalcular")
                        # Se inicializa T = [] para hacer el promedio entre el 
                        # Centroide y sus instancias
                        T = [] 
                        # for que recorre instancia por instancia del microcluster más cercano (mp).
                        for i in range(len(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)])):
                            # T es una lista que almacena las distancia euclideanas
                            # de cada instancia de mp con respecto al centroide mp  
                            T.append( np.linalg.norm(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)].iloc[[i]].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]) )
                        # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
                        # sqrt (((x_prom - x)**2 suma) / N )
                        T = math.sqrt(((mean(T) - T)**2).sum() / len(T))
                        print("T: " + str(T))
                    # ¿Existente o nueva clase?
                    print("b: " +str(b) + ", T: " + str(T))
                    # - - - - - - - EXTENSIÓN DE CLASE - - - - - - 
                    if b < T:  #El nuevo microcluster se considera una extensión de la clase
                    #print("B: " + str(b) + ", T: " + str(T))
                    #print("Clust cerc: " +str(cluster_cercano) + "clase cercana: " + str(clase_cercana))
                        print("EXTENSIÓN de clase")
                        Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                        index_wrong_stm, clasif_wrong_stm, short_classes = class_extension(Cj,\
                        clase_cercana, num_cluster, ShortCluster, aux_index_sc, short_classes,\
                        aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm,\
                        clasif_wrong_stm, cluster_cercano, instancias_stm, n_ventana, n_cluster_stm,\
                        N, T)
                        print("Así quedan las clases y sus respectivos clusters.")
                        print(Cj)
                        print(num_cluster)
                    # - - - - - - - NUEVA CLASE - - - - - - - - 
                    else: #El microcluster se considera una clase emergente
                        print("Clase EMERGENTE")
                        Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                        index_wrong_stm,clasif_wrong_stm, short_classes = emerging_class(Cj,\
                        clases_originales, num_cluster, ShortCluster,aux_index_sc, short_classes,\
                        aciertos_stm, index_right_stm, clasif_right_stm,index_wrong_stm,clasif_wrong_stm,\
                        instancias_stm, n_ventana, n_cluster_stm, N, T)
                        print("Así quedan las clases y sus respectivos clusters.")
                        print(Cj)
                        print(num_cluster)
                        
    an_fin_stm = timer()
    an_tot_stm = an_fin_stm - an_ini_stm
    
    return Cj, short_term_memory, num_cluster, ShortCluster, short_classes,\
    aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, \
    an_tot_stm

# %%
def update_t_s(short_term_memory, short_classes, Time_stamps, ventana_de_olvido):
    """ This function updates the short term memory.
    INPUT:
    - short_memory: Data set for intances didn't recognized
    - Time_stamps
    - ventana_de_olvido
    OUTPUT:
    - short_term_memory: is the dataset of the short memory updated
    - short_classes: is the dataframe of classes correspondind to the short memory updated.
    """
    # Update time stamp
    current_t_s = Time_stamps[-1] #Current time stamp
    update_time = current_t_s - ventana_de_olvido # difference_time_stamp es el factor de olvido
    short_term_memory = short_term_memory.loc[update_time:, :]
    short_term_memory
    # Update short_classes 
    aux_index = short_term_memory.index.tolist()
    short_classes = short_classes.loc[aux_index]
    
    return short_term_memory, short_classes

# %%
# function to get unique values 
def unique(lista): 
    valores = []  
    # insert the list to the set 
    list_set = set(lista) 
    # convert the set to the list 
    unique_list = (list(list_set)) 
    for valor in unique_list: 
        valores.append(valor)
        # print(x) 
    return valores

# %%
def clases_en_ventana(lista_clases):
    """Esta función regresa un diccionario con la clase y número de instancias que hay.
    INPUT:
    - clases_totales: es una lista con todas las etiquetas de clases presentadas en la ventana
    OUTPUT:
    - n_v: el diccionario donde indica clase y número de instancias
    """
    
    # Clases e instancias TOTALES por ventana
    lista_clases = sorted(lista_clases, reverse=False) # La lista se arregla de mayor a menor.
    lista_clases_unique = unique(lista_clases) # Se obtienen los valores únicos (clases)
    n_instancias = [len(list(group)) for key, group in groupby(lista_clases)] # Lista con cantidad de
    # patrones que hay por clase
    C_v_tot = []
    for i in lista_clases_unique:
        C_v_tot.append("clase_"+str(i))
    # using naive method to convert lists to dictionary 
    diccionario_clases = {} 
    for key in C_v_tot: 
        for value in n_instancias: 
            diccionario_clases[key] = value 
            n_instancias.remove(value) 
            break 
    return diccionario_clases

# %%
def clusters_en_ventana(Cj, num_clusters):
    """ Esta función regresa en forma de diccionario las clases detectadas 
    y sus clusters creados.
    INPUT:
    - Cj: es una lista que contiene las etiquetas de clases detectadas
    -num_clusters: es una lista con el número de clusters por cada clase
    OUTPUT:
    - diccionario_clusters: es un diccionario que relaciona la clase y el número total de los clusters creados"""  

    Cluster_v = []
    for i in Cj:
        Cluster_v.append("cluster_clase_"+str(i))
    
    num_c = num_clusters.copy()
    diccionario_clusters = {} 
    for key in Cluster_v: 
        for value in num_c: 
            diccionario_clusters[key] = value 
            num_c.remove(value) 
            break
    return diccionario_clusters

# %% [markdown]
# ---
# # PREPROCESSING.
# ---

# %%
S
# Out:
#        Unnamed: 0  atrib1 atrib2    atrib3 atrib4  atrib5  atrib6  atrib7  \
# 0          256368       0   icmp     ecr_i     SF    1032       0       0
# 1          453300       0    udp  domain_u     SF      46      46       0
# 2          256244       0   icmp     ecr_i     SF    1032       0       0
# 3          453038       0    udp  domain_u     SF      42      42       0
# 4          256453       0   icmp     ecr_i     SF    1032       0       0
# ...           ...     ...    ...       ...    ...     ...     ...     ...
# 97995       59929       0   icmp     ecr_i     SF    1032       0       0
# 97996       22900       0   icmp     ecr_i     SF    1032       0       0
# 97997      350839       0    tcp   private    REJ       0       0       0
# 97998      226133       0   icmp     ecr_i     SF    1032       0       0
# 97999      232417       0   icmp     ecr_i     SF    1032       0       0
#
#        atrib8  atrib9  ...  atrib33  atrib34  atrib35  atrib36  atrib37  \
# 0           0       0  ...      255      1.0     0.00     1.00      0.0
# 1           0       0  ...      255      1.0     0.00     0.01      0.0
# 2           0       0  ...      255      1.0     0.00     1.00      0.0
# 3           0       0  ...      255      1.0     0.00     0.01      0.0
# 4           0       0  ...      255      1.0     0.00     1.00      0.0
# ...       ...     ...  ...      ...      ...      ...      ...      ...
# 97995       0       0  ...      255      1.0     0.00     1.00      0.0
# 97996       0       0  ...      255      1.0     0.00     1.00      0.0
# 97997       0       0  ...        1      0.0     0.06     0.00      0.0
# 97998       0       0  ...      255      1.0     0.00     1.00      0.0
# 97999       0       0  ...      255      1.0     0.00     1.00      0.0
#
#        atrib38  atrib39  atrib40  atrib41     clase
# 0          0.0      0.0      0.0      0.0    smurf.
# 1          0.0      0.0      0.0      0.0   normal.
# 2          0.0      0.0      0.0      0.0    smurf.
# 3          0.0      0.0      0.0      0.0   normal.
# 4          0.0      0.0      0.0      0.0    smurf.
# ...        ...      ...      ...      ...       ...
# 97995      0.0      0.0      0.0      0.0    smurf.
# 97996      0.0      0.0      0.0      0.0    smurf.
# 97997      0.0      0.0      1.0      1.0  neptune.
# 97998      0.0      0.0      0.0      0.0    smurf.
# 97999      0.0      0.0      0.0      0.0    smurf.
#
# [98000 rows x 43 columns]

# %%
# - - - - - - - - - - - - - - - - STREAM DATA SET - - - - - - - - - - - - - - - - -
S
# - - - - - - - - - - - - - - - - Delete attrib0 column - - - - - - - - - - - - - - - - - 
# Here we have a little problem, the first column is unnecessary, 
# so we must to eliminate but not having a name will not be possible so
# we must rename it and after that eliminate.
S.rename( columns={'Unnamed: 0':'attrib0'}, inplace=True )
del S['attrib0']

# - - - - - - - - - - - - - - - - Rearrange our database - - - - - - - - - - - - - - - -
# First columns: categorical
# After categorical columns: numerical
# CLASS column
S1, num_col_names, cat_col_names = preprocessing_label_coding(S, class_type)
clases_originales = S1['CLASS']

rows = S1.shape[0]
attributes = S1.shape[1]
print("Your dataset has " + str(rows) + " instances and " + str(attributes) + " attributes")
# Out:
# Your dataset has 98000 instances and 42 attributes

# %%
#clases_originales

# %% [markdown]
# ---
# ---
# ---
# # Naıve Associative Classifier for Online Data (NACOD)
# ---
# ---
# ---

# %%
# Model train
S1, model_train = create_model_train(S1, InitNumber)

# %%
len(S1)
# Out:
# 96000

# %%
S2 = S1

# %%
# - - - - - - - - - - - - - - - Identify how many classes we have - - - - - - - - - - - - - - - 
# Classes of my model train
Cj = model_train.iloc[:,-1]
# Count classes by label
Cj = Cj.value_counts(sort=True)
Cj
# Out:
# 3    1022
# 2     978
# Name: CLASS, dtype: int64

# %%
# - - - - - - - - - - - - - - - LABEL CLASSES - - - - - - - - - - - - - - -
Cj = Cj.keys()
Cj = Cj.tolist()
#length = len(Cj)
Cj
# Out:
# [3, 2]

# %%
# - - - Obtener un D_# por cada clase - SUBSETS OF THE TRAINING DATASET - - - - - - - - - - - - - - -
j = 0
for i in range(len(Cj)):
    globals()['D_'+str(Cj[i])] = model_train[model_train['CLASS']==Cj[i]]
    globals()['D_'+str(Cj[i])].pop('CLASS') # Eliminate class
    #    model_train[model_train['CLASS'].str.match(Cj[i])] #if the classes were categorical
del model_train # Lo borramos
# D_1
# D_2

# %% [markdown]
# ---
# # CLUSTERING
# ---

# %% [markdown]
# ---
# # K_means
# Apply the K means algorithm in each D_x, we will asked how many clusters do we want for each x.
#
# Result:
#  * Centroid of each cluster (4) in D_x (8 centroids)
#  * MC_x in wich the CLASS colum will be changed by CLUSTER column based in which instance belongs to what cluster.
# ---

# %%
# - A los sets de cada clase se les añade una columna al final la cual
# indica el numero de cluster al que pertenece cada instancia
j = 0
num_cluster = [] # Empty list for number of clusters
for i in range(len(Cj)): # How many Dj
    j = i+1
    # Se hace el Kmeans con n clústers
    num_cluster.append(int(input('Number of clusters for D_'+str(Cj[i])+'? ')))
    globals()['kmeansD_'+str(Cj[i])] = KMeans(n_clusters=int(num_cluster[-1]), random_state=0).fit(globals()['D_'+str(Cj[i])])
    # Obtener los centroides de cada cluster
    globals()['centroidsD_'+str(Cj[i])] = globals()['kmeansD_'+str(Cj[i])].cluster_centers_ 
    # Column_series es el array de a cuál cluster pertenecen las instancias
    column_series = pd.Series(globals()['kmeansD_'+str(Cj[i])].labels_ + 1)
    # Ese array lo pasamos a forma de Dataframe
    globals()['MC_'+str(Cj[i])] = column_series.to_frame()
    # Para poderlo concatenar al model train tenemos que hacer que los índices de las instancias cuadren
    globals()['MC_'+str(Cj[i])].index = globals()['D_'+str(Cj[i])].index
    # Renombramos a la columna con la palabra CLUSTER
    globals()['MC_'+str(Cj[i])].rename( columns={0:'CLUSTER'}, inplace=True )
    globals()['MC_'+str(Cj[i])] = pd.concat([globals()['D_'+str(Cj[i])],globals()['MC_'+str(Cj[i])]], axis=1) 

# del D_1 # Se elimina
# del D_3 # Se elimina
# MC_1
# MC_2
# Out:
# Number of clusters for D_3?  5
# Number of clusters for D_2?  5

# %%
# Se crean los micro clusteres - - MC_j_i -  j es la clase - i el cluster - - - - -
j = 0
n_c = []
for j in range(len(Cj)): # Número de clases
    for i in range(num_cluster[j]): # Número de clusters 
        globals()['MC_'+str(Cj[j])+'_'+str(i+1)] = globals()['MC_'+str(Cj[j])][globals()['MC_'+str(Cj[j])]['CLUSTER']==i+1]
        n_c.append(len(globals()['MC_'+str(Cj[j])+'_'+str(i+1)]))
        # Escribir archivos csv
        #globals()['MC_'+str(Cj[j])+'_'+str(i+1)].to_csv('MC_'+str(Cj[j])+'_'+str(i+1)+'.csv')
    del globals()['MC_'+str(Cj[j])]

# %%
n_c # numero de instancias pertenecientes a cada cluster
# Out:
# [997, 2, 13, 7, 3, 957, 1, 1, 4, 15]

# %% [markdown]
# # Micro clusters información.
# Se llama a la funcion "microcluster_information" para obtener la siguiente información:
# - Timestamp, Number of instances. Número de instancias, LS Linear sum. Suma lineal
# - SS Cuadratic sum. Suma cuadrática, Cj label of the class to which they belong. Etiqueta de la clase perteneciente
# - Centroid. Centroide, Radius. Radio

# %%
# - - MC_j_i - - - INFORMATION - - - - average vector for numeric attributes
# missing to obtain Mode vector for categorical attributes.
for j in range(len(Cj)): # Num of classes
    for i in range(num_cluster[j]): # Num of clusters
        # Time stamp
        microcluster_information(j,i)

# %% [markdown]
# ---
# # Online phase.
#
# Classification
# ---

# %%
#ventana = 0
n_ventana = 0
Time_stamps = [ ]
contador = 0
columns = ['Clase correcta', 'Clasificado en', "Ventana", "GHOS", "STM", 'Acierto']
columns_stm = ['Clase correcta', 'Clasificado en', 'Ventana', "GHOS"]
col_clasif_stm = ['Clase_correcta', 'Clasificado en', 'GHOS', 'Acierto', 'Ventana']
columns_time = ['Ventana', 'TS', 'Accuracy', 'Tiempo transcurrido [sec]', "Instancias clase_1",
                "Instancias clase_2", "Instancias clase_3", "Instancias clase_4", "Instancias clase_5", "Instancias clase_6", 
                "Clasificadas clase_1", "Clasificadas clase_2", "Clasificadas clase_3", "Clasificadas clase_4", 
                "Clasificadas clase_5", "Clasificadas clase_6", "Cluster clase_1", "Cluster clase_2", "Cluster clase_3",
                "Cluster clase_4", "Cluster clase_5", "Cluster clase_6"]
index_no_emerging = []
col_no_emerging = ["Ventana", "Cluster STM", 'clase original', 'clase propuesta', 'error', 'instancias', 'T']
no_emerging = [] 
clases = []
clases_stm = []
clasif_right_stm = []
clasif_wrong_stm = []
index = []
index_stm= []
index_right_stm = []
index_wrong_stm = []
index_time = [] # Para dataframe de tiempo
times = []
ghos_stm = []
accuracy_ventana = []
aciertos_clases =[]
aciertos_stm = 0
short_term_memory = pd.DataFrame()
short_classes = pd.DataFrame()
####### - - - - - - - - - - - 
# para medir el tiempo de STM (S) y de clasificación (C)
tiempos_c_s = []
col_time = ["Ventana", "tiempo tot [sec]", "t clasificacion",
"g_h_o_s", "Correct clas", "Incorrect class", "t mandar a stm", "time todo stm", "Frame stm",
"Clusters stm", "analysis stm", "update stm", "Analysis", 'STM', 'A0', 'A1', 'A2', 'A3', 
'A4', 'A5', 'A6', 'A7', "Extension", "E0", "E1", "E2", "E3"]


#While para recorrer todo el dataset
while S1.size != 0:
    aciertos = 0
    window = S1[:paso] #window contiene las instancias de la ventana
    Time_stamps.append(window.index[-1])
    # Aquí las instancias se borran del dataset y se pasan a la ventana
    aux_index = window.index.tolist()
    S1 = S1.drop(aux_index)
    n_ventana = n_ventana + 1
    c_v_tot = [] # Es una lista vacía para almacenar cuantos patrones
    # y a qué clase pertenecen por ventana.  
    c_v_det = [] # Es una lista vacía que almacena los patrones y sus clases
    # que fueron clasificadas correctamente en la ventana.
    
    print("\n Longitud de ventana: " + str(len(window)))
    ventana_size = len(window)
    TimeInit = timer()
# - - - - - ¿Cuánto se tarda en saber si lo clasifica o se va a la STM?
    t_clasif = 0.0 #Variable de tipo float para ir almacenando el tiempo en cada ventana.
    #################
    ################
    t_ghos = 0.0
    
    t_correct_class = 0.0
    t_c_incorrect = 0.0
    t_sent_stm = 0.0 
    
    ti_stm1 = tf_stm1 = ti_stm2 = tf_stm2 = ti_stm3 = tf_stm3 = ti_stm4 = tf_stm4 = 0.0    
    t_stm = t_stm1 = 0.0
    an_tot_stm = 0.0
## Inicializar variables para calcular el tiempo de ejecución de la función Analysis
    A0 = A1 = A2 = A3 = A4 = A5 = A6 = A7 = 0.0
    E0 = E1 = E2 = E3 = 0.0
    
    # While para recorrer las instancias que hay en la ventana
    while window.size != 0:
        
        # Start nos ayuda a medir el tiempo de inicio de la ventana
        start = timer()
       
        X_test = window.iloc[[0]].drop(['CLASS'], axis=1)
        y_test = window.iloc[[0]]['CLASS']
        c_v_tot.append(int(y_test)) # Aquí se van almacenando las clases que se presentan en la ventana
       # print(c_v_tot[-1])
        indice = X_test.index.tolist()[0]
        # Aquí la instancia a analizar se borra de la ventana
        aux_index = X_test.index.tolist()
        window = window.drop(aux_index)
        
        ###TIEMPO
        ################### FUNCION GHOS #########################################
        start_ghos = timer()
        winning_class, winning_cluster, ghos = g_h_o_s(num_cluster, Cj, X_test, 'classification')
        end_ghos = timer()
        t_ghos = t_ghos + (end_ghos - start_ghos) # El tiempo es acumulativo
        ##########################################################################
        
        start_clasif = timer()
        if winning_class == int(y_test):
            # Se crea una lista donde se almacene la clase que fue detectada correctamente
            aciertos_clases.append(int(y_test))
            #Se actualizan los MC
            # Añade la instancia al final del microcluster
            globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)].append(X_test)
            # Se actualizan las estadísticas
            update_microcluster(winning_class, winning_cluster, X_test)
            # Las siguientes 3 líneas son para llevar un registro de 
            # instancia, clase correcta y cual clase fue asignada.
            index.append(indice)
            new_clases = {"Clase correcta": int(y_test), "Clasificado en": winning_class, "Ventana": n_ventana, "GHOS": ghos,"STM":'no', 'Acierto':'verdaderos positivos'}
            clases.append(new_clases)
            aciertos = aciertos + 1
            c_v_det.append(int(y_test))
            
            # - - - - 
            end = timer() #Nos da el tiempo de fin de la ventana
            t_clasif = t_clasif + (end - start)
            
            t_correct_class = t_correct_class + (end - start_clasif)
            
            # - - - - - 
            
        else:
            # Almacenar las clases correctas del short term memory
            short_classes = short_classes.append(y_test.to_frame())
            # El short term memory
            short_term_memory = short_term_memory.append(X_test)
            # Las siguientes 3 líneas son para llevar un registro de 
            # instancia, clase correcta y cual clase fue asignada.
            new_clases_stm = {"Clase correcta": int(y_test), "Clasificado en":'STM', 'Ventana': n_ventana,"GHOS": ghos}
            index_stm.append(indice) #Indices de las instancias en el short term memory   
            clases_stm.append(new_clases_stm)
            # Guardar el GHOS de cada instancia en el stm
            ghos_stm.append(ghos)
            
            end_inc = timer()
            
            t_c_incorrect = t_c_incorrect + (end_inc - start_clasif) # Hace una clasificación pero es incorrecta

            t_sent_stm = t_sent_stm + (end_inc - start) # No hace clasificación, mide el tiempo en que
            # los patrones se van directo a la STM            
   

    # - - - - - 
    ti_stm = timer() # Tiempo inicial del análisis de la stm


    print("Patrones en STM: " + str(len(short_term_memory)))
    # Si cumple la condición, se analiza la STM
    if len(short_term_memory)>= n_elements_stm:
        
        ti_stm1 = timer()
        # Me da las instancias mandadas al short term memory
        instancias_stm = pd.DataFrame(clases_stm, index_stm, columns_stm)
        tf_stm1 = timer()
        
        
        ti_stm2 = timer()
        # Creación de los clusters en el stm
        Clusters, n_clusters_stm = clusters_stm(short_term_memory, mc_stm)
        tf_stm2 = timer()
        
        
        ti_stm3 = timer()
        # Las siguientes 5 líneas hacen referencia a la función que checa si el cluster
        # es o no válido. Si es válido, hace la asignación como extensión de la clase
        # o clase emergente.
        # - - - REVISAR LOS TIEMPOS DE ESTA FUNCIÓN- - - - - 
        ##Cj, short_term_memory, num_cluster, ShortCluster,short_classes,\
        ##aciertos_stm,index_right_stm, clasif_right_stm,index_wrong_stm, \
        ##clasif_wrong_stm, an_tot_stm = analysis_stm(short_term_memory, short_classes, Clusters,\
        ##n_clusters_stm,Cj, clases_originales, num_cluster, aciertos_stm,index_right_stm, clasif_right_stm,\
        ##index_wrong_stm,clasif_wrong_stm, instancias_stm, n_ventana)
       
        #- - - - REVISAR LOS TIEMPOS DE ESTA FUNCIÓN- - - - - 
        print("Analysis")
        ## Tiempo de ejecución

        an_tot_stm = 0.0
        an1_stm = 0.0
        an_ini_stm = timer()
        
        for i in range(n_clusters_stm[-1]):
            ##
            A0i = timer()
            n_cluster_stm = i + 1
            #Este es el cluster del short term memory a analizar
            ShortCluster = Clusters[Clusters['CLUSTER']==i+1]
            # Es cohesivo?
            # Calcular Silhouette. Para ello debemos de tener el centroide del microcluster.
            # Centroid LS/N
            N = len(ShortCluster.index)
            print("\n El cluster " + str(i+1) + " tiene: " + str(N) + " instancias.")
            LS = (ShortCluster.sum(axis=0)).drop(labels=['CLUSTER'])
            Centroid = LS / N
            Silhouette = 0 
            A0f = timer()
            A0 = A0 +(A0f -A0i)
            ##
            
            # - - - - - VALIDACION DEL CLUSTER - - - - - - - -     
            # Se verifica si es representativo, si lo es, se verifica si es cohesivo (Silhouette)
            # ...To identify if a cluster is cohesive, a modified silhouette coefficient will be used...

            # - - - - - - REPRESENTATIVO - - - - - - - - 
            if N >= n_representative: #Si es representativo entra a este for
                print("Si es representativo")
            # Silhouette = b-a / max(a,b)
            
            ##
                A1i = timer()
                
                clase_cercana, cluster_cercano, b = g_h_o_s(num_cluster, Cj, Centroid, 'novel_detection')
            
                A1f = timer()
                A1 = A1 + (A1f - A1i)
            ##
            
            ##
                A2i = timer() 
            
            # a standar deviation of the distance between each instance of the new microcluster
            # and the new microcluster centroid
                a = []
                for i in range(len(ShortCluster)):
                # a es una lista que almacena las distancias euclideanas entre cada instancia de ese
                # microcluster y el centroide.
                    a.append(np.linalg.norm(ShortCluster.iloc[[i]].drop(['CLUSTER'], axis=1) - Centroid))
                # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
                # sqrt (((x_prom - x)**2 suma) / N )
                a = math.sqrt(((mean(a) - a)**2).sum() / len(a))
                print("a: " + str(a))
              
                A2f = timer()
                A2 = A2 + (A2f -A2i)
            ##
            
            ##                
                if max(b,a) != 0:
                    
                    A3i = timer()
                    
                    Silhouette = (b - a) / max(b, a)
                # Verificar si el cluster es válido, significa que Silhouette > 0,
                # si es representativo y válido: instancias se eliminan del short term memory
                    print("Silhouette: " + str(Silhouette))
                    # print("b = " + str(b) + ". a = " + str(a))
                
                    A3f = timer()
                    A3 = A3 + (A3f - A3i)
             ##   
                # - - - - - - - - - - - COHESIVO - - - - - -
                    if Silhouette > 0: # El cluster es válido
                        
                    ## A4 es para eliminar las instancias del STM
                        A4i = timer()
                        
                        aux_index_sc = ShortCluster.index.tolist()
                    # Borrar estas instancias del short term memory y también sus clases
                        short_term_memory = short_term_memory.drop(aux_index_sc)
                        
                        A4f = timer()
                        A4 = A4 + (A4f - A4i)
                    ##
                    
                    # - - - - NOVELTY PROCESS - - - - 
                    # - - - - - - Threshold - - - - - -
                    # T = la media de las distancias del centroide del microcluster de la clase 
                    # más cercana con respecto a los demás microclusters de esa clase
                        
                    ## A5 es el cálculo del umbral
                        A5i = timer()
                        
                        print("Cálculo de T")
                        Centroide_cercano = globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]
                        # print("Distancia entre el Centroide_"+ str(clase_cercana)+"_"+str(cluster_cercano) + " con respecto a:")
                        T = []
                        print("La clase cercana es: " + str(clase_cercana) + " y el cluster cercano es: " + str(cluster_cercano))
                        class_index = Cj.index(clase_cercana) # class index guarda la posición de Cj donde está la clase más cercana
                        # esta posición la busco en num_cluster para saber cuantos clusters hay en la clase más cercana 
                        for j in range(0, num_cluster[class_index]): # Modifiqué porque estaba malrange(0, cluster_cercano)
                            i = j + 1
                            if i != cluster_cercano: # Si el índice i coincide con cluster cercano no entra en esta sentencia porque
                                # no debe calcular la distancia con respecto a él mismo
                                print("Se compara con clase: "  + str(clase_cercana) + ", cluster: "+ str(i))
                                # la distancia se estaría compárando con respecto al mismo centroide 
                                T.append(np.linalg.norm(globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(i)] - Centroide_cercano))
                                # print("Centroide más cercano vs Centroide_" + str(clase_cercana) + "_"+str(i+1))
                        print("T antes del promedio: " + str(T))
                        
                        
                        if len(T) >= 1: #Significa que hay al menos 2 clusteres de esa clase
                            print("T tiene más de un micro cluster en esa clase.")
                            T = sum(T)/len(T)
                            print("T = " + str(T))
                        else: #Significa que solo hay un cluster de esa clase
                            #Aquí 
                            print("T solo tiene 1 microcluster en esa clase, hay que recalcular")
                            # Se inicializa T = [] para hacer el promedio entre el 
                            # Centroide y sus instancias
                            T = [] 
                            # for que recorre instancia por instancia del microcluster más cercano (mp).
                            for i in range(len(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)])):
                                # T es una lista que almacena las distancia euclideanas
                                # de cada instancia de mp con respecto al centroide mp  
                                T.append( np.linalg.norm(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)].iloc[[i]].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]) )
                            # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
                            # sqrt (((x_prom - x)**2 suma) / N )
                            T = math.sqrt(((mean(T) - T)**2).sum() / len(T))
                            print("T: " + str(T))
                        # ¿Existente o nueva clase?
                        print("b: " +str(b) + ", T: " + str(T))
                        
                        A5f = timer()
                        A5 = A5 + (A5f - A5i)
                        
                        
                        
                        
                        # - - - - - - - EXTENSIÓN DE CLASE - - - - - - 
                        if b < T:  #El nuevo microcluster se considera una extensión de la clase
                        #print("B: " + str(b) + ", T: " + str(T))
                        #print("Clust cerc: " +str(cluster_cercano) + "clase cercana: " + str(clase_cercana))
                            
                            ## A6 es la extensión de clase
                            A6i = timer()
                            
                            print("\n \n \n EXTENSIÓN de clase")
                            
                            #Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                            #index_wrong_stm, clasif_wrong_stm, short_classes = class_extension(Cj,\
                            #clase_cercana, num_cluster, ShortCluster, aux_index_sc, short_classes,\
                            #aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm,\
                            #clasif_wrong_stm, cluster_cercano, instancias_stm, n_ventana, n_cluster_stm,\
                            #N, T)
                            #print("Así quedan las clases y sus respectivos clusters.")
                            #print(Cj)
                            #print(num_cluster)
                            
                 # ---------------------------- Función class_extension - - - - - - - - - - - - - - - - - - -           
                            # Se añade la extensión de clase 
                            
                            ## E se refiere a los tiempos en la función extensión de clase
                            # E0  se refiere a los indices del data frame para saber si la clase calculada en verdad
                            # es la que mas se repite y poder hacer la extensión de esa clase
                            
                            E0i = timer()
                            
                            idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
                            idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
                            idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

                            clase_mayor_frecuencia = idx_clase # la clase original q:e más se repite
                            E0f = timer()
                            E0 = E0 + (E0f - E0i)
                            print("E0: " + str(E0))
                            
                            # Se pregunta si la clase original con mayor repetición es igual a la calculada
                            if clase_mayor_frecuencia == clase_cercana:
                            
                            ## E1 se refiere a ingresar la extensión de clase al modelo                            
                                E1i = timer()
                            
                                print("La mayoría de los patrones son clase: " +str(clase_mayor_frecuencia) + ". Y la clase cercana detectada fue: " +str(clase_cercana))
                                print("Se añade esta extensión de clase.")
                                class_index = Cj.index(clase_cercana)
                                num_cluster[class_index] = num_cluster[class_index] + 1
                                globals()['MC_'+str(Cj[class_index])+'_'+str(num_cluster[class_index])] = ShortCluster
                            
                            #Se calculan las estadísticas de este nuevo microcluster
                                microcluster_information(class_index, num_cluster[class_index]-1)

                                E1f = timer()
                                E1 = E1 + (E1f - E1i)
                                print("E1: " + str(E1))
                            ##
    
                            ## E2 se refiere al tiempo que se tarda en hacer el registro
                            ##
                                E2i = timer()
                                
                                for j in range(len(aux_index_sc)):    
                                #Si la asignación fue correcta
                                    if int(short_classes.loc[aux_index_sc[j]]) == clase_cercana:
                                        aciertos_stm = aciertos_stm + 1
                                    # Las siguientes 3 líneas son para llevar un registro de la asignación.
                                        index_right_stm.append(aux_index_sc[j])
                                        new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], 'acierto':'asignada correctamente'}
                                        clasif_right_stm.append(new_clases)
                                        # new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": clase_cercana, "GHOS": instancias_stm.at[aux_index_sc[j]], 'acierto':'Bien'}
                                    else: # Si la asignacion fue incorrecta:
                                    # Las siguientes 3 líneas son para llevar un registro de la asignación.
                                        print("Se descarta la extensión de clase")
                                        index_wrong_stm.append(aux_index_sc[j])
                                        new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]), \
                                        "Clasificado en": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]),\
                                        "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], "STM":'YES', \
                                        'Acierto':'asignada incorrectamente', 'Ventana':n_ventana}
                                        clasif_wrong_stm.append(new_clases)
                                    
                                E2f = tiemr()
                                E2 = E2 + (E2f - E2i)
                                print("E2: " + str(E2))
                                
                                
                            else: # si no coincide, hay error y no se añade al modelo
                                
                                ## E3 se refiere al tiempo en el cual se lleva a cabo el registro del tiempo 
                                # en el cual hay un error y las instancias no se añaden al modelo como extensión de clase
                                E3i = timer()
                                
                                print("La clase cercana es : " + str(clase_cercana) + ", pero la clase con mayor repetición es: " + str(clase_mayor_frecuencia))
                                print("Se descarta esta extensión")

                                new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': clase_mayor_frecuencia,\
                                'clase propuesta': clase_cercana, 'error': "extension", 'instancias': N, "T": T}
                                no_emerging.append(new_emerging_clases)
                            
                                E3f = timer()
                                E3 = E3 + (E3f - E3i)
                                
                  # ---------------------------- Función class_extension - - - - - - - - - - - - - - - - - - -           
                
                
                            A6f = timer()
                            A6 = A6 + (A6f - A6i)
                            print("\n \n \n ")
                            ##
                            
                        # - - - - - - - NUEVA CLASE - - - - - - - - 
                        else: #El microcluster se considera una clase emergente
                            
                            ## A7 es para la clase emergente
                            A7i = timer() 
                            
                            print("Clase EMERGENTE")
                            Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                            index_wrong_stm,clasif_wrong_stm, short_classes = emerging_class(Cj,\
                            clases_originales, num_cluster, ShortCluster,aux_index_sc, short_classes,\
                            aciertos_stm, index_right_stm, clasif_right_stm,index_wrong_stm,clasif_wrong_stm,\
                            instancias_stm, n_ventana, n_cluster_stm, N, T)
                            print("Así quedan las clases y sus respectivos clusters.")
                            print(Cj)
                            print(num_cluster)
                            
                            A7f = timer()
                            A7 = A7 + (A7f - A7i)
                            ##
                            
        an_fin_stm = timer()
        an_tot_stm = an_fin_stm - an_ini_stm                    
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - 
        
        tf_stm3 = timer() 
    
        
        ti_stm4 = timer()
        # Actualización de la Short Term Memory
        short_term_memory, short_classes = update_t_s(short_term_memory, short_classes,\
        Time_stamps, ventana_de_olvido)
        del Clusters
        tf_stm4 = timer()
    
    tf_stm = timer() #Tiempo final del análisis de la stm
    
        
    # Accuracy por ventana
    accuracy_ventana.append([(aciertos/ventana_size)*100])
    
    # --- CALCULOS DE TIEMPO ----
    TimeFin = timer()
    ElapseTime = TimeFin - TimeInit #Tiempo 
    print("Tiempo transcurrido: " + str(ElapseTime/60))
    t_stm = tf_stm -ti_stm # t_stm = tf_stm - ti_stm
    t_stm1 = tf_stm1 - ti_stm1
    t_stm2 = tf_stm2 - ti_stm2
    t_stm3 = tf_stm3 - ti_stm3
    t_stm4 = tf_stm4 - ti_stm4
    
    # - - - - - - - - 
    # tiempos de clasificación y de ventana STM
    
    tiempo_c_s = {"Ventana": n_ventana, "tiempo tot [sec]": ElapseTime, "t clasificacion": t_clasif, 
    "g_h_o_s": t_ghos, "Correct clas": t_correct_class, "Incorrect class": t_c_incorrect, 
    "t mandar a stm": t_sent_stm, "time todo stm": t_stm, "Frame stm": t_stm1, "Clusters stm": t_stm2,
    "analysis stm": t_stm3, "update stm": t_stm4, "Analysis": an_tot_stm, 'STM':0, 'A0': A0, 'A1': A1,
    'A2': A2, 'A3': A3, 'A4': A4, 'A5': A5, 'A6': A6, 'A7': A7, "Extension": 0, "E0": E0, "E1": E1,
    "E2":E2, "E3": E3}
    ## t_stm, t_stm3, an_tot_stm 
    
    tiempos_c_s.append(tiempo_c_s)
    
    
    # Clases e instancias TOTALES por ventana
    c_v_tot = clases_en_ventana(c_v_tot)
    c_v_det = clases_en_ventana(c_v_det)
    # Clusteres de cada clase por ventana
    cluster_ventana = clusters_en_ventana(Cj, num_cluster)
    
    # Las siguientes 3 líneas son para crear un datarfame donde se almacenen los tiempos por ventana
    new_time = {"Ventana": n_ventana, 'TS': Time_stamps[-1], "Accuracy": accuracy_ventana[-1][0],\
    "Tiempo transcurrido [sec]": ElapseTime,\
    "Instancias clase_1": c_v_tot['clase_1'] if c_v_tot.get('clase_1') else 'False',     # Esta condicion nos da el número de patrones por clase pero si no hay nos manda un False
    "Instancias clase_2": c_v_tot['clase_2'] if c_v_tot.get('clase_2') else 'False',
    "Instancias clase_3": c_v_tot['clase_3'] if c_v_tot.get('clase_3') else 'False',
    "Instancias clase_4": c_v_tot['clase_4'] if c_v_tot.get('clase_4') else 'False',
    "Instancias clase_5": c_v_tot['clase_5'] if c_v_tot.get('clase_5') else 'False',
    "Instancias clase_6": c_v_tot['clase_6'] if c_v_tot.get('clase_6') else 'False',                
    "Clasificadas clase_1": c_v_det['clase_1'] if c_v_det.get('clase_1') else 'False',
    "Clasificadas clase_2": c_v_det['clase_2'] if c_v_det.get('clase_2') else 'False',
    "Clasificadas clase_3": c_v_det['clase_3'] if c_v_det.get('clase_3') else 'False',
    "Clasificadas clase_4": c_v_det['clase_4'] if c_v_det.get('clase_4') else 'False',
    "Clasificadas clase_5": c_v_det['clase_5'] if c_v_det.get('clase_5') else 'False',
    "Clasificadas clase_6": c_v_det['clase_6'] if c_v_det.get('clase_6') else 'False',
    "Cluster clase_1":cluster_ventana['cluster_clase_1'] if cluster_ventana.get('cluster_clase_1') else 'False',
    "Cluster clase_2":cluster_ventana['cluster_clase_2'] if cluster_ventana.get('cluster_clase_2') else 'False',
    "Cluster clase_3":cluster_ventana['cluster_clase_3'] if cluster_ventana.get('cluster_clase_3') else 'False',
    "Cluster clase_4":cluster_ventana['cluster_clase_4'] if cluster_ventana.get('cluster_clase_4') else 'False',
    "Cluster clase_5":cluster_ventana['cluster_clase_5'] if cluster_ventana.get('cluster_clase_5') else 'False',
    "Cluster clase_6":cluster_ventana['cluster_clase_6'] if cluster_ventana.get('cluster_clase_6') else 'False'}
    
    index_time.append(n_ventana) #
    times.append(new_time)
    
    # print(aciertos_ventana)    
    print("Finalizó la ventana: " + str(n_ventana) + " TimeStamp: " +  str(Time_stamps[-1]) + " t: " + str(ElapseTime) + "[sec]" + ' accuracy ' + str(accuracy_ventana[-1][0]))
    print(" - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
# Out:
#  Longitud de ventana: 2000
# Patrones en STM: 0
# Tiempo transcurrido: 4.455719562099936
# Finalizó la ventana: 1 TimeStamp: 3999 t: 267.34317372599617[sec] accuracy 100.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 469
# Analysis
#
#  El cluster 1 tiene: 247 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 17.697733725452462
# Silhouette: 0.9805873101960726
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [32275.109688762113, 125454.97680952304, 3559.949106225116, 1756.608436648143]
# T tiene más de un micro cluster en esa clase.
# T = 40761.6610102896
# b: 911.6579878524642, T: 40761.6610102896
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0019512400031089783
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 118 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.288236895488371
# Silhouette: 0.9912051343709203
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [32275.109688762113, 125454.97680952304, 3559.949106225116, 1756.608436648143]
# T tiene más de un micro cluster en esa clase.
# T = 40761.6610102896
# b: 942.3949432591415, T: 40761.6610102896
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0034222761169075966
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 104 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.463406134193246
# Silhouette: 0.9908972036986728
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [32275.109688762113, 125454.97680952304, 3559.949106225116, 1756.608436648143]
# T tiene más de un micro cluster en esa clase.
# T = 40761.6610102896
# b: 929.75892835912, T: 40761.6610102896
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004837268963456154
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.499268244571673
# Finalizó la ventana: 2 TimeStamp: 5999 t: 269.9560946743004[sec] accuracy 76.55
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 439
# Analysis
#
#  El cluster 1 tiene: 112 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 9.069073078814975
# Silhouette: 0.9922768527408341
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [9522.856808188748, 125438.67169421876, 3294.459578052499, 1611.3028561373628]
# T tiene más de un micro cluster en esa clase.
# T = 34966.82273414935
# b: 1174.271676362461, T: 34966.82273414935
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0012929122895002365
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 222 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 13.63841728224392
# Silhouette: 0.9882415659003574
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [9522.856808188748, 125438.67169421876, 3294.459578052499, 1611.3028561373628]
# T tiene más de un micro cluster en esa clase.
# T = 34966.82273414935
# b: 1159.8838048221385, T: 34966.82273414935
#
#
#
#  EXTENSIÓN de clase
# E0: 0.002915371209383011
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 105 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 7.008196059199237
# Silhouette: 0.9940793600935902
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [9522.856808188748, 125438.67169421876, 3294.459578052499, 1611.3028561373628]
# T tiene más de un micro cluster en esa clase.
# T = 34966.82273414935
# b: 1183.6889542314539, T: 34966.82273414935
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004276736173778772
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.501751596014946
# Finalizó la ventana: 3 TimeStamp: 7999 t: 270.1050957608968[sec] accuracy 78.05
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 443
# Analysis
#
#  El cluster 1 tiene: 228 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 24.522654690467707
# Silhouette: 0.9785670507453694
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [4435.387979505609, 125418.10198922752, 3318.0334003380776, 1560.1361096744877]
# T tiene más de un micro cluster en esa clase.
# T = 33682.91486968643
# b: 1144.1568026467314, T: 33682.91486968643
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0019031642004847527
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 93 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 7.313019459550208
# Silhouette: 0.9937483045219286
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [4435.387979505609, 125418.10198922752, 3318.0334003380776, 1560.1361096744877]
# T tiene más de un micro cluster en esa clase.
# T = 33682.91486968643
# b: 1169.765783570477, T: 33682.91486968643
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0033137723803520203
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 122 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.484527535175744
# Silhouette: 0.9926832011856118
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [4435.387979505609, 125418.10198922752, 3318.0334003380776, 1560.1361096744877]
# T tiene más de un micro cluster en esa clase.
# T = 33682.91486968643
# b: 1159.5955759356634, T: 33682.91486968643
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0047582113184034824
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.500711094945048
# Finalizó la ventana: 4 TimeStamp: 9999 t: 270.0426656967029[sec] accuracy 77.85
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 460
# Analysis
#
#  El cluster 1 tiene: 119 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.677562271679182
# Silhouette: 0.9923373654463359
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3794.4557100152524, 125419.21508964086, 3346.3781075593984, 1528.7728220962274]
# T tiene más de un micro cluster en esa clase.
# T = 33522.20543232793
# b: 1132.4515362056125, T: 33522.20543232793
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0014127600006759167
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 227 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 18.910760190828363
# Silhouette: 0.9830780556235855
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3794.4557100152524, 125419.21508964086, 3346.3781075593984, 1528.7728220962274]
# T tiene más de un micro cluster en esa clase.
# T = 33522.20543232793
# b: 1117.528799892871, T: 33522.20543232793
#
#
#
#  EXTENSIÓN de clase
# E0: 0.002723527140915394
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 114 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 7.140402853280248
# Silhouette: 0.9937491195653133
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3794.4557100152524, 125419.21508964086, 3346.3781075593984, 1528.7728220962274]
# T tiene más de un micro cluster en esa clase.
# T = 33522.20543232793
# b: 1142.303540739233, T: 33522.20543232793
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004179058130830526
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.501297112065368
# Finalizó la ventana: 5 TimeStamp: 11999 t: 270.07782672392204[sec] accuracy 77.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 449
# Analysis
#
#  El cluster 1 tiene: 237 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 13.395799459771593
# Silhouette: 0.9879391401461886
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3858.0649476123613, 125422.39898254992, 3353.128022635063, 1480.9259068136546]
# T tiene más de un micro cluster en esa clase.
# T = 33528.62946490275
# b: 1110.683618095294, T: 33528.62946490275
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0019778218120336533
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 209 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 13.52784766204251
# Silhouette: 0.9880376419751069
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3858.0649476123613, 125422.39898254992, 3353.128022635063, 1480.9259068136546]
# T tiene más de un micro cluster en esa clase.
# T = 33528.62946490275
# b: 1130.8679805345769, T: 33528.62946490275
#
#
#
#  EXTENSIÓN de clase
# E0: 0.003228055778890848
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 3 instancias.
# Tiempo transcurrido: 4.50286583439447
# Finalizó la ventana: 6 TimeStamp: 13999 t: 270.1719500636682[sec] accuracy 77.55
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 454
# Analysis
#
#  El cluster 1 tiene: 118 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.62761037239623
# Silhouette: 0.9925439614730038
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3568.6342096204085, 125344.17285735827, 3361.4807075933404, 1906.011648138716]
# T tiene más de un micro cluster en esa clase.
# T = 33545.07485567768
# b: 1157.130605100577, T: 33545.07485567768
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0013931156136095524
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 234 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 27.157396676090247
# Silhouette: 0.9760236143751496
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3568.6342096204085, 125344.17285735827, 3361.4807075933404, 1906.011648138716]
# T tiene más de un micro cluster en esa clase.
# T = 33545.07485567768
# b: 1132.672668058142, T: 33545.07485567768
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0030025336891412735
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 102 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 10.06361730092376
# Silhouette: 0.9912265726332129
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3568.6342096204085, 125344.17285735827, 3361.4807075933404, 1906.011648138716]
# T tiene más de un micro cluster en esa clase.
# T = 33545.07485567768
# b: 1147.0565470252673, T: 33545.07485567768
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004413530696183443
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.49985371651904
# Finalizó la ventana: 7 TimeStamp: 15999 t: 269.9912229911424[sec] accuracy 77.45
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 444
# Analysis
#
#  El cluster 1 tiene: 110 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 10.333007804042724
# Silhouette: 0.9909494403001177
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3779.3390728087847, 125345.6278810582, 3366.421842704227, 1842.2979791951636]
# T tiene más de un micro cluster en esa clase.
# T = 33583.42169394159
# b: 1141.6982094684395, T: 33583.42169394159
#
#
#
#  EXTENSIÓN de clase
# E0: 0.001361694186925888
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 239 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 14.610580597151776
# Silhouette: 0.9870452767067261
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3779.3390728087847, 125345.6278810582, 3366.421842704227, 1842.2979791951636]
# T tiene más de un micro cluster en esa clase.
# T = 33583.42169394159
# b: 1127.8188091240547, T: 33583.42169394159
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0032418714836239815
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 95 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.403504954798935
# Silhouette: 0.9927061319444768
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3779.3390728087847, 125345.6278810582, 3366.421842704227, 1842.2979791951636]
# T tiene más de un micro cluster en esa clase.
# T = 33583.42169394159
# b: 1152.132845128118, T: 33583.42169394159
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004654414486140013
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.4712106926832345
# Finalizó la ventana: 8 TimeStamp: 17999 t: 268.2726415609941[sec] accuracy 77.8
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 442
# Analysis
#
#  El cluster 1 tiene: 236 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 13.22887627318725
# Silhouette: 0.9882338531230042
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3708.2381706001634, 125323.20680831285, 3381.894779334869, 1741.4229267721576]
# T tiene más de un micro cluster en esa clase.
# T = 33538.69067125501
# b: 1124.3167717930958, T: 33538.69067125501
#
#
#
#  EXTENSIÓN de clase
# E0: 0.001359682995826006
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 112 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.57499626443987
# Silhouette: 0.9924726684316973
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3708.2381706001634, 125323.20680831285, 3381.894779334869, 1741.4229267721576]
# T tiene más de un micro cluster en esa clase.
# T = 33538.69067125501
# b: 1139.1814199535131, T: 33538.69067125501
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0026915469206869602
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 94 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 7.379777766661789
# Silhouette: 0.9935758147900507
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3708.2381706001634, 125323.20680831285, 3381.894779334869, 1741.4229267721576]
# T tiene más de un micro cluster en esa clase.
# T = 33538.69067125501
# b: 1148.749222739193, T: 33538.69067125501
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004625665955245495
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.476092330017127
# Finalizó la ventana: 9 TimeStamp: 19999 t: 268.5655398010276[sec] accuracy 77.9
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 454
# Analysis
#
#  El cluster 1 tiene: 252 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 19.854003592286617
# Silhouette: 0.9823120268359893
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3531.313128869402, 125324.85778460512, 3382.46090582773, 1659.9783519087623]
# T tiene más de un micro cluster en esa clase.
# T = 33474.65254280275
# b: 1122.4578083758593, T: 33474.65254280275
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0020888978615403175
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 103 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 7.130927485535283
# Silhouette: 0.9937857751703519
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3531.313128869402, 125324.85778460512, 3382.46090582773, 1659.9783519087623]
# T tiene más de un micro cluster en esa clase.
# T = 33474.65254280275
# b: 1147.516815213003, T: 33474.65254280275
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0036179679445922375
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 99 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 9.600950297107216
# Silhouette: 0.9915581568759807
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3531.313128869402, 125324.85778460512, 3382.46090582773, 1659.9783519087623]
# T tiene más de un micro cluster en esa clase.
# T = 33474.65254280275
# b: 1137.3049885030262, T: 33474.65254280275
#
#
#
#  EXTENSIÓN de clase
# E0: 0.004985959734767675
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.501167378667742
# Finalizó la ventana: 10 TimeStamp: 21999 t: 270.0700427200645[sec] accuracy 77.3
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 465
# Analysis
#
#  El cluster 1 tiene: 118 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 10.077116928674197
# Silhouette: 0.991075726873864
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3578.8112860803267, 125318.31282681874, 3351.742055006821, 1633.82077389425]
# T tiene más de un micro cluster en esa clase.
# T = 33470.671735450036
# b: 1129.1806947461089, T: 33470.671735450036
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0013087019324302673
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 224 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 15.045289800788957
# Silhouette: 0.9865109292714316
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3578.8112860803267, 125318.31282681874, 3351.742055006821, 1633.82077389425]
# T tiene más de un micro cluster en esa clase.
# T = 33470.671735450036
# b: 1115.3688866738983, T: 33470.671735450036
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0031306641176342964
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 123 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 8.520046996267215
# Silhouette: 0.9925247780204473
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3578.8112860803267, 125318.31282681874, 3351.742055006821, 1633.82077389425]
# T tiene más de un micro cluster en esa clase.
# T = 33470.671735450036
# b: 1139.7717712694496, T: 33470.671735450036
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0045256828889250755
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
# Tiempo transcurrido: 4.52332318451566
# Finalizó la ventana: 11 TimeStamp: 23999 t: 271.3993910709396[sec] accuracy 76.75
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 434
# Analysis
#
#  El cluster 1 tiene: 235 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 19.5466443769885
# Silhouette: 0.9834191921047023
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3522.8033468424933, 125314.51360045027, 3282.0502857496062, 1557.9629239030523]
# T tiene más de un micro cluster en esa clase.
# T = 33419.332539236355
# b: 1178.8716509122555, T: 33419.332539236355
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0015730271115899086
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 2 tiene: 102 instancias.
# Si es representativo
# 5
# class: 2
# clust: 1
# a: 10.848455674230438
# Silhouette: 0.9908971166620502
# Cálculo de T
# La clase cercana es: 2 y el cluster cercano es: 1
# Se compara con clase: 2, cluster: 2
# Se compara con clase: 2, cluster: 3
# Se compara con clase: 2, cluster: 4
# Se compara con clase: 2, cluster: 5
# T antes del promedio: [3522.8033468424933, 125314.51360045027, 3282.0502857496062, 1557.9629239030523]
# T tiene más de un micro cluster en esa clase.
# T = 33419.332539236355
# b: 1191.7603765175609, T: 33419.332539236355
#
#
#
#  EXTENSIÓN de clase
# E0: 0.0028614760376513004
# La clase cercana es : 2, pero la clase con mayor repetición es: 1
# Se descarta esta extensión
#
#
#
#
#
#  El cluster 3 tiene: 97 instancias.
# Si es representativo
# 4
# class: 3
# clust: 5
# a: 7.9404194008596445
# Silhouette: 0.9933495175029535
# Cálculo de T
# La clase cercana es: 3 y el cluster cercano es: 5
# Se compara con clase: 3, cluster: 1
# Se compara con clase: 3, cluster: 2
# Se compara con clase: 3, cluster: 3
# Se compara con clase: 3, cluster: 4
# T antes del promedio: [5.487901935015522, 1.6970562748476978, 4.525483399593888, 3.111269837220793]
# T tiene más de un micro cluster en esa clase.
# T = 3.7054278616694756
# b: 1193.9614012044867, T: 3.7054278616694756
# Clase EMERGENTE
# La nueva clase es: 1
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 4.531514682527631
# Finalizó la ventana: 12 TimeStamp: 25999 t: 271.8908809516579[sec] accuracy 78.3
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 50
# Tiempo transcurrido: 4.918483451668483
# Finalizó la ventana: 13 TimeStamp: 27999 t: 295.109007100109[sec] accuracy 97.5
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 96
# Tiempo transcurrido: 4.917977917854054
# Finalizó la ventana: 14 TimeStamp: 29999 t: 295.0786750712432[sec] accuracy 97.7
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 141
# Analysis
#
#  El cluster 1 tiene: 22 instancias.
#
#  El cluster 2 tiene: 63 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.189024529779916
# Silhouette: 0.8002647486564947
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.12885260684475
# b: 66.03253277057932, T: 24.12885260684475
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 56 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.680717356081361
# Silhouette: 0.7692010527643344
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.12885260684475
# b: 59.275475559739746, T: 24.12885260684475
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 5.260994387146396
# Finalizó la ventana: 15 TimeStamp: 31999 t: 315.65966322878376[sec] accuracy 97.75
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 54
# Tiempo transcurrido: 4.913263932134336
# Finalizó la ventana: 16 TimeStamp: 33999 t: 294.7958359280601[sec] accuracy 97.65
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 91
# Tiempo transcurrido: 4.9160692114150155
# Finalizó la ventana: 17 TimeStamp: 35999 t: 294.9641526849009[sec] accuracy 98.15
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 146
# Analysis
#
#  El cluster 1 tiene: 76 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.644478315964815
# Silhouette: 0.7894364887374469
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.00529245202975
# b: 64.79982326544425, T: 24.00529245202975
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 22 instancias.
#
#  El cluster 3 tiene: 48 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 9.73759532174286
# Silhouette: 0.8434998754812517
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.00529245202975
# b: 62.22100686300936, T: 24.00529245202975
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 5.568236021798414
# Finalizó la ventana: 18 TimeStamp: 37999 t: 334.09416130790487[sec] accuracy 97.25
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 39
# Tiempo transcurrido: 4.88019788635429
# Finalizó la ventana: 19 TimeStamp: 39999 t: 292.8118731812574[sec] accuracy 98.3
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 83
# Tiempo transcurrido: 4.92176826998281
# Finalizó la ventana: 20 TimeStamp: 41999 t: 295.3060961989686[sec] accuracy 97.8
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 122
# Analysis
#
#  El cluster 1 tiene: 72 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 15.23621205773542
# Silhouette: 0.7755509160051084
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.318542294294595
# b: 67.8827099070816, T: 24.318542294294595
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 39 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 24.974530238021398
# Silhouette: 0.6761729040424362
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.318542294294595
# b: 77.1230405045976, T: 24.318542294294595
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 11 instancias.
# Tiempo transcurrido: 5.85194759919929
# Finalizó la ventana: 21 TimeStamp: 43999 t: 351.1168559519574[sec] accuracy 98.05
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 43
# Tiempo transcurrido: 4.924627272621729
# Finalizó la ventana: 22 TimeStamp: 45999 t: 295.4776363573037[sec] accuracy 97.95
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 88
# Tiempo transcurrido: 4.940961178299039
# Finalizó la ventana: 23 TimeStamp: 47999 t: 296.4576706979424[sec] accuracy 97.75
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 128
# Analysis
#
#  El cluster 1 tiene: 67 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 14.404655643790948
# Silhouette: 0.7962658351380713
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.38419160759024
# b: 70.70319135503378, T: 24.38419160759024
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 45 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 9.638712128051264
# Silhouette: 0.8436211732418794
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.38419160759024
# b: 61.636938502934086, T: 24.38419160759024
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 16 instancias.
# Tiempo transcurrido: 6.206972730004539
# Finalizó la ventana: 24 TimeStamp: 49999 t: 372.41836380027235[sec] accuracy 98.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 39
# Tiempo transcurrido: 4.9504077622511735
# Finalizó la ventana: 25 TimeStamp: 51999 t: 297.0244657350704[sec] accuracy 98.2
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 82
# Tiempo transcurrido: 4.922265547164716
# Finalizó la ventana: 26 TimeStamp: 53999 t: 295.33593282988295[sec] accuracy 97.85000000000001
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 121
# Analysis
#
#  El cluster 1 tiene: 64 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 14.147002238602807
# Silhouette: 0.7995568533474944
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.446954779885235
# b: 70.5786277798187, T: 24.446954779885235
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 45 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.097449681241118
# Silhouette: 0.7132405430314206
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.446954779885235
# b: 45.67399387520886, T: 24.446954779885235
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 12 instancias.
# Tiempo transcurrido: 6.486311960616149
# Finalizó la ventana: 27 TimeStamp: 55999 t: 389.17871763696894[sec] accuracy 98.05
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 44
# Tiempo transcurrido: 4.95698312492265
# Finalizó la ventana: 28 TimeStamp: 57999 t: 297.41898749535903[sec] accuracy 97.89999999999999
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 85
# Tiempo transcurrido: 4.954914973381286
# Finalizó la ventana: 29 TimeStamp: 59999 t: 297.29489840287715[sec] accuracy 97.95
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 120
# Analysis
#
#  El cluster 1 tiene: 72 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.991364724777796
# Silhouette: 0.7880251270095748
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.466472554350734
# b: 66.00482655040807, T: 24.466472554350734
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 15 instancias.
#
#  El cluster 3 tiene: 33 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 17.344281585870345
# Silhouette: 0.7327122834514004
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.466472554350734
# b: 64.88993138117786, T: 24.466472554350734
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 6.780415366698677
# Finalizó la ventana: 30 TimeStamp: 61999 t: 406.82492200192064[sec] accuracy 98.25
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 43
# Tiempo transcurrido: 4.9344879982604954
# Finalizó la ventana: 31 TimeStamp: 63999 t: 296.06927989562973[sec] accuracy 98.15
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 86
# Tiempo transcurrido: 4.927356162240418
# Finalizó la ventana: 32 TimeStamp: 65999 t: 295.6413697344251[sec] accuracy 97.85000000000001
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 119
# Analysis
#
#  El cluster 1 tiene: 6 instancias.
#
#  El cluster 2 tiene: 71 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 15.240517148865951
# Silhouette: 0.7801597400038442
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.58476087043611
# b: 69.32541450384225, T: 24.58476087043611
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 42 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 23.613530129294894
# Silhouette: 0.7396578483890581
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.58476087043611
# b: 90.70190894244125, T: 24.58476087043611
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 7.0964829791802915
# Finalizó la ventana: 33 TimeStamp: 67999 t: 425.7889787508175[sec] accuracy 98.35000000000001
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 35
# Tiempo transcurrido: 4.948375487032657
# Finalizó la ventana: 34 TimeStamp: 69999 t: 296.9025292219594[sec] accuracy 98.3
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 64
# Tiempo transcurrido: 4.936237799779822
# Finalizó la ventana: 35 TimeStamp: 71999 t: 296.17426798678935[sec] accuracy 98.55000000000001
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 86
# Tiempo transcurrido: 4.945427738161137
# Finalizó la ventana: 36 TimeStamp: 73999 t: 296.7256642896682[sec] accuracy 98.9
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 113
# Analysis
#
#  El cluster 1 tiene: 67 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 14.278621605026864
# Silhouette: 0.7671492182085519
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.635607883405125
# b: 61.320909018100075, T: 24.635607883405125
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 9 instancias.
#
#  El cluster 3 tiene: 37 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 26.65424844827321
# Silhouette: 0.6189462446033228
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.635607883405125
# b: 69.9487882504297, T: 24.635607883405125
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 7.567891343628677
# Finalizó la ventana: 37 TimeStamp: 75999 t: 454.07348061772063[sec] accuracy 98.65
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 28
# Tiempo transcurrido: 5.008469735916393
# Finalizó la ventana: 38 TimeStamp: 77999 t: 300.5081841549836[sec] accuracy 98.6
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 58
# Tiempo transcurrido: 5.000431994884275
# Finalizó la ventana: 39 TimeStamp: 79999 t: 300.0259196930565[sec] accuracy 98.5
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 97
# Tiempo transcurrido: 4.997672879338885
# Finalizó la ventana: 40 TimeStamp: 81999 t: 299.8603727603331[sec] accuracy 98.05
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 124
# Analysis
#
#  El cluster 1 tiene: 79 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 12.537401333966226
# Silhouette: 0.8207549816753338
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.537680653740995
# b: 69.94560546869567, T: 24.537680653740995
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 10 instancias.
#
#  El cluster 3 tiene: 35 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 14.358899781010704
# Silhouette: 0.7423609236530735
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.537680653740995
# b: 55.73261628090758, T: 24.537680653740995
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
# Tiempo transcurrido: 8.020427826209925
# Finalizó la ventana: 41 TimeStamp: 83999 t: 481.2256695725955[sec] accuracy 98.65
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 23
# Tiempo transcurrido: 5.018211782079501
# Finalizó la ventana: 42 TimeStamp: 85999 t: 301.09270692477[sec] accuracy 99.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 54
# Tiempo transcurrido: 5.024612713853518
# Finalizó la ventana: 43 TimeStamp: 87999 t: 301.4767628312111[sec] accuracy 98.45
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 86
# Tiempo transcurrido: 5.024206038129827
# Finalizó la ventana: 44 TimeStamp: 89999 t: 301.4523622877896[sec] accuracy 98.4
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 110
# Analysis
#
#  El cluster 1 tiene: 37 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 28.23779200905621
# Silhouette: 0.6413411053813713
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.543642753744788
# b: 78.73160942817879, T: 24.543642753744788
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 66 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 13.125725204590951
# Silhouette: 0.8061180034204868
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.543642753744788
# b: 67.69955661771795, T: 24.543642753744788
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 7 instancias.
# Tiempo transcurrido: 8.463574793213047
# Finalizó la ventana: 45 TimeStamp: 91999 t: 507.8144875927828[sec] accuracy 98.8
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 45
# Tiempo transcurrido: 5.014800788050828
# Finalizó la ventana: 46 TimeStamp: 93999 t: 300.8880472830497[sec] accuracy 97.75
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 77
# Tiempo transcurrido: 5.038539113205236
# Finalizó la ventana: 47 TimeStamp: 95999 t: 302.3123467923142[sec] accuracy 98.4
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  Longitud de ventana: 2000
# Patrones en STM: 115
# Analysis
#
#  El cluster 1 tiene: 39 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 27.036676025174373
# Silhouette: 0.6492559931461869
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.647376749548645
# b: 77.08378617127165, T: 24.647376749548645
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 2 tiene: 69 instancias.
# Si es representativo
# 10
# class: 1
# clust: 1
# a: 14.077823832216497
# Silhouette: 0.805813860546543
# Cálculo de T
# La clase cercana es: 1 y el cluster cercano es: 1
# T antes del promedio: []
# T solo tiene 1 microcluster en esa clase, hay que recalcular
# T: 24.647376749548645
# b: 72.4965431201165, T: 24.647376749548645
# Clase EMERGENTE
# La clase 1 ya existía.
# Así quedan las clases y sus respectivos clusters.
# [3, 2, 1]
# [5, 5, 1]
#
#  El cluster 3 tiene: 7 instancias.
# Tiempo transcurrido: 8.80257410882817
# Finalizó la ventana: 48 TimeStamp: 97999 t: 528.1544465296902[sec] accuracy 98.1
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
#index_no_emerging[-1]

# %%
Cj
# Out:
# [3, 2, 1]

# %%
# la clase cercana es 2 y el microcluster cercano es 1
num_cluster
# Out:
# [5, 5, 1]

# %% [markdown]
# ---
# ---
# # Guardar y graficar información
# ---
# ---

# %% [markdown]
# # Guardar el accuracy

# %%
# Importing library 
import csv
# opening the csv file in 'w+' mode 
file = open('accuracy_' + str(cadena) +'.csv', 'w+', newline ='')# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(accuracy_ventana)

# %%
## accuracy_ventana

# %% [markdown]
# # Guardar tiempos

# %%
# Dataframe de tiempo
Tiempos = pd.DataFrame(times, index_time, columns_time)
Tiempos.to_csv('Tiempos_' + str(cadena) +'.csv')

# %%
Tiempos
# Out:
#     Ventana     TS  Accuracy  Tiempo transcurrido [sec] Instancias clase_1  \
# 1         1   3999    100.00                 267.343174              False
# 2         2   5999     76.55                 269.956095                469
# 3         3   7999     78.05                 270.105096                439
# 4         4   9999     77.85                 270.042666                443
# 5         5  11999     77.00                 270.077827                460
# 6         6  13999     77.55                 270.171950                449
# 7         7  15999     77.45                 269.991223                451
# 8         8  17999     77.80                 268.272642                444
# 9         9  19999     77.90                 268.565540                442
# 10       10  21999     77.30                 270.070043                454
# 11       11  23999     76.75                 271.399391                465
# 12       12  25999     78.30                 271.890881                434
# 13       13  27999     97.50                 295.109007                451
# 14       14  29999     97.70                 295.078675                445
# 15       15  31999     97.75                 315.659663                443
# 16       16  33999     97.65                 294.795836                430
# 17       17  35999     98.15                 294.964153                426
# 18       18  37999     97.25                 334.094161                472
# 19       19  39999     98.30                 292.811873                429
# 20       20  41999     97.80                 295.306096                433
# 21       21  43999     98.05                 351.116856                451
# 22       22  45999     97.95                 295.477636                463
# 23       23  47999     97.75                 296.457671                410
# 24       24  49999     98.00                 372.418364                442
# 25       25  51999     98.20                 297.024466                415
# 26       26  53999     97.85                 295.335933                437
# 27       27  55999     98.05                 389.178718                459
# 28       28  57999     97.90                 297.418987                443
# 29       29  59999     97.95                 297.294898                465
# 30       30  61999     98.25                 406.824922                443
# 31       31  63999     98.15                 296.069280                416
# 32       32  65999     97.85                 295.641370                444
# 33       33  67999     98.35                 425.788979                449
# 34       34  69999     98.30                 296.902529                424
# 35       35  71999     98.55                 296.174268                459
# 36       36  73999     98.90                 296.725664                421
# 37       37  75999     98.65                 454.073481                449
# 38       38  77999     98.60                 300.508184                418
# 39       39  79999     98.50                 300.025920                459
# 40       40  81999     98.05                 299.860373                448
# 41       41  83999     98.65                 481.225670                411
# 42       42  85999     99.00                 301.092707                440
# 43       43  87999     98.45                 301.476763                454
# 44       44  89999     98.40                 301.452362                484
# 45       45  91999     98.80                 507.814488                416
# 46       46  93999     97.75                 300.888047                463
# 47       47  95999     98.40                 302.312347                410
# 48       48  97999     98.10                 528.154447                444
#
#     Instancias clase_2  Instancias clase_3 Instancias clase_4  \
# 1                 1022                 978              False
# 2                  364                1167              False
# 3                  350                1211              False
# 4                  395                1162              False
# 5                  384                1156              False
# 6                  398                1153              False
# 7                  412                1137              False
# 8                  381                1175              False
# 9                  451                1107              False
# 10                 403                1143              False
# 11                 383                1152              False
# 12                 407                1159              False
# 13                 395                1154              False
# 14                 389                1166              False
# 15                 409                1148              False
# 16                 398                1172              False
# 17                 392                1182              False
# 18                 369                1159              False
# 19                 383                1188              False
# 20                 420                1147              False
# 21                 390                1159              False
# 22                 387                1150              False
# 23                 415                1175              False
# 24                 358                1200              False
# 25                 409                1176              False
# 26                 387                1176              False
# 27                 365                1176              False
# 28                 386                1171              False
# 29                 382                1153              False
# 30                 382                1175              False
# 31                 392                1192              False
# 32                 422                1134              False
# 33                 380                1171              False
# 34                 408                1168              False
# 35                 371                1170              False
# 36                 413                1166              False
# 37                 386                1165              False
# 38                 384                1198              False
# 39                 415                1126              False
# 40                 397                1155              False
# 41                 395                1194              False
# 42                 381                1179              False
# 43                 412                1134              False
# 44                 411                1105              False
# 45                 402                1182              False
# 46                 427                1110              False
# 47                 420                1170              False
# 48                 366                1190              False
#
#    Instancias clase_5 Instancias clase_6  ... Clasificadas clase_3  \
# 1               False              False  ...                  978
# 2               False              False  ...                 1167
# 3               False              False  ...                 1211
# 4               False              False  ...                 1162
# 5               False              False  ...                 1156
# 6               False              False  ...                 1153
# 7               False              False  ...                 1137
# 8               False              False  ...                 1175
# 9               False              False  ...                 1107
# 10              False              False  ...                 1143
# 11              False              False  ...                 1152
# 12              False              False  ...                 1159
# 13              False              False  ...                 1154
# 14              False              False  ...                 1166
# 15              False              False  ...                 1148
# 16              False              False  ...                 1172
# 17              False              False  ...                 1182
# 18              False              False  ...                 1159
# 19              False              False  ...                 1188
# 20              False              False  ...                 1147
# 21              False              False  ...                 1159
# 22              False              False  ...                 1150
# 23              False              False  ...                 1175
# 24              False              False  ...                 1200
# 25              False              False  ...                 1176
# 26              False              False  ...                 1176
# 27              False              False  ...                 1176
# 28              False              False  ...                 1171
# 29              False              False  ...                 1153
# 30              False              False  ...                 1175
# 31              False              False  ...                 1192
# 32              False              False  ...                 1134
# 33              False              False  ...                 1171
# 34              False              False  ...                 1168
# 35              False              False  ...                 1170
# 36              False              False  ...                 1166
# 37              False              False  ...                 1165
# 38              False              False  ...                 1198
# 39              False              False  ...                 1126
# 40              False              False  ...                 1155
# 41              False              False  ...                 1194
# 42              False              False  ...                 1179
# 43              False              False  ...                 1134
# 44              False              False  ...                 1105
# 45              False              False  ...                 1182
# 46              False              False  ...                 1110
# 47              False              False  ...                 1170
# 48              False              False  ...                 1190
#
#     Clasificadas clase_4  Clasificadas clase_5 Clasificadas clase_6  \
# 1                  False                 False                False
# 2                  False                 False                False
# 3                  False                 False                False
# 4                  False                 False                False
# 5                  False                 False                False
# 6                  False                 False                False
# 7                  False                 False                False
# 8                  False                 False                False
# 9                  False                 False                False
# 10                 False                 False                False
# 11                 False                 False                False
# 12                 False                 False                False
# 13                 False                 False                False
# 14                 False                 False                False
# 15                 False                 False                False
# 16                 False                 False                False
# 17                 False                 False                False
# 18                 False                 False                False
# 19                 False                 False                False
# 20                 False                 False                False
# 21                 False                 False                False
# 22                 False                 False                False
# 23                 False                 False                False
# 24                 False                 False                False
# 25                 False                 False                False
# 26                 False                 False                False
# 27                 False                 False                False
# 28                 False                 False                False
# 29                 False                 False                False
# 30                 False                 False                False
# 31                 False                 False                False
# 32                 False                 False                False
# 33                 False                 False                False
# 34                 False                 False                False
# 35                 False                 False                False
# 36                 False                 False                False
# 37                 False                 False                False
# 38                 False                 False                False
# 39                 False                 False                False
# 40                 False                 False                False
# 41                 False                 False                False
# 42                 False                 False                False
# 43                 False                 False                False
# 44                 False                 False                False
# 45                 False                 False                False
# 46                 False                 False                False
# 47                 False                 False                False
# 48                 False                 False                False
#
#    Cluster clase_1 Cluster clase_2 Cluster clase_3  Cluster clase_4  \
# 1            False               5               5            False
# 2            False               5               5            False
# 3            False               5               5            False
# 4            False               5               5            False
# 5            False               5               5            False
# 6            False               5               5            False
# 7            False               5               5            False
# 8            False               5               5            False
# 9            False               5               5            False
# 10           False               5               5            False
# 11           False               5               5            False
# 12               1               5               5            False
# 13               1               5               5            False
# 14               1               5               5            False
# 15               1               5               5            False
# 16               1               5               5            False
# 17               1               5               5            False
# 18               1               5               5            False
# 19               1               5               5            False
# 20               1               5               5            False
# 21               1               5               5            False
# 22               1               5               5            False
# 23               1               5               5            False
# 24               1               5               5            False
# 25               1               5               5            False
# 26               1               5               5            False
# 27               1               5               5            False
# 28               1               5               5            False
# 29               1               5               5            False
# 30               1               5               5            False
# 31               1               5               5            False
# 32               1               5               5            False
# 33               1               5               5            False
# 34               1               5               5            False
# 35               1               5               5            False
# 36               1               5               5            False
# 37               1               5               5            False
# 38               1               5               5            False
# 39               1               5               5            False
# 40               1               5               5            False
# 41               1               5               5            False
# 42               1               5               5            False
# 43               1               5               5            False
# 44               1               5               5            False
# 45               1               5               5            False
# 46               1               5               5            False
# 47               1               5               5            False
# 48               1               5               5            False
#
#     Cluster clase_5 Cluster clase_6
# 1             False           False
# 2             False           False
# 3             False           False
# 4             False           False
# 5             False           False
# 6             False           False
# 7             False           False
# 8             False           False
# 9             False           False
# 10            False           False
# 11            False           False
# 12            False           False
# 13            False           False
# 14            False           False
# 15            False           False
# 16            False           False
# 17            False           False
# 18            False           False
# 19            False           False
# 20            False           False
# 21            False           False
# 22            False           False
# 23            False           False
# 24            False           False
# 25            False           False
# 26            False           False
# 27            False           False
# 28            False           False
# 29            False           False
# 30            False           False
# 31            False           False
# 32            False           False
# 33            False           False
# 34            False           False
# 35            False           False
# 36            False           False
# 37            False           False
# 38            False           False
# 39            False           False
# 40            False           False
# 41            False           False
# 42            False           False
# 43            False           False
# 44            False           False
# 45            False           False
# 46            False           False
# 47            False           False
# 48            False           False
#
# [48 rows x 22 columns]

# %% [markdown]
# # Desglose de tiempos por sección del programa

# %%
# #Dataframe de tiempo por sección
T_desglose = pd.DataFrame(tiempos_c_s, index_time, col_time)
T_desglose.to_csv('T_desglose' + str(cadena) +'.csv')

# %%
T_desglose
# Out:
#     Ventana  tiempo tot [sec]  t clasificacion     g_h_o_s  Correct clas  \
# 1         1        267.343174       267.311008  257.635510      6.808177
# 2         2        269.956095       204.479873  257.218061      5.348340
# 3         3        270.105096       208.692524  257.399134      5.591699
# 4         4        270.042666       208.206747  257.201728      5.682227
# 5         5        270.077827       205.885449  256.940613      5.792245
# 6         6        270.171950       207.543383  256.973182      6.001176
# 7         7        269.991223       207.099191  256.559728      6.153286
# 8         8        268.272642       206.824724  254.804724      6.332659
# 9         9        268.565540       207.346385  254.987369      6.458787
# 10       10        270.070043       206.862368  256.096113      6.666585
# 11       11        271.399391       206.388421  257.156782      6.814295
# 12       12        271.890881       211.146396  257.563975      7.150304
# 13       13        295.109007       287.836815  283.419544      8.642677
# 14       14        295.078675       288.388182  283.186129      8.848628
# 15       15        315.659663       288.324486  282.806205      9.006913
# 16       16        294.795836       287.971282  282.503714      9.250109
# 17       17        294.964153       289.585412  282.439499      9.497868
# 18       18        334.094161       287.023456  282.359698      9.589559
# 19       19        292.811873       287.915098  279.944814      9.861853
# 20       20        295.306096       288.916274  282.189102     10.070754
# 21       21        351.116856       288.822415  281.192427     10.253895
# 22       22        295.477636       289.529610  281.959380     10.483058
# 23       23        296.457671       289.924796  282.699005     10.704100
# 24       24        372.418364       291.103079  282.822006     11.047128
# 25       25        297.024466       291.797647  282.787491     11.191905
# 26       26        295.335933       289.117667  280.959544     11.338801
# 27       27        389.178718       289.772890  280.868535     11.504487
# 28       28        297.418987       291.320204  282.611686     11.753495
# 29       29        297.294898       291.349345  282.327247     11.914897
# 30       30        406.824922       290.327113  280.144456     12.188557
# 31       31        296.069280       290.721134  280.494540     12.538733
# 32       32        295.641370       289.460514  280.218193     12.382673
# 33       33        425.788979       291.065872  280.081035     12.724370
# 34       34        296.902529       291.989056  280.848790     13.015661
# 35       35        296.174268       291.989021  279.820215     13.332471
# 36       36        296.725664       293.550957  280.235878     13.476501
# 37       37        454.073481       294.326542  281.289999     13.915538
# 38       38        300.508184       296.422403  283.146762     14.310072
# 39       39        300.025920       295.659071  282.787576     14.190137
# 40       40        299.860373       294.190265  282.238993     14.560257
# 41       41        481.225670       296.616726  282.427516     15.079403
# 42       42        301.092707       298.165401  282.909061     15.149472
# 43       43        301.476763       296.956531  283.274779     15.150871
# 44       44        301.452362       296.789392  283.169420     15.228635
# 45       45        507.814488       298.127251  282.683352     15.901204
# 46       46        300.888047       294.348902  282.109945     15.703724
# 47       47        302.312347       297.636516  283.040191     16.209608
# 48       48        528.154447       297.323116  283.071289     16.706361
#
#     Incorrect class  t mandar a stm  time todo stm  Frame stm  Clusters stm  \
# 1          0.000000        0.000000       0.000048   0.000000      0.000000
# 2          0.809898       61.762243       3.681231   0.001097      0.022381
# 3          0.757157       57.928020       3.451266   0.001532      0.021318
# 4          0.763638       58.310808       3.491457   0.001844      0.022561
# 5          0.792289       60.519621       3.638881   0.002237      0.021567
# 6          0.773623       59.096450       3.498026   0.002633      0.019179
# 7          0.779638       59.281051       3.576975   0.002997      0.020425
# 8          0.760043       57.950562       3.463473   0.003335      0.022580
# 9          0.758981       57.740949       3.444371   0.003686      0.024392
# 10         0.781260       59.580957       3.592459   0.004009      0.021361
# 11         0.804560       61.303068       3.673278   0.005702      0.025677
# 12         0.751167       57.245823       3.463783   0.004818      0.021268
# 13         0.085190        7.238019       0.000049   0.000000      0.000000
# 14         0.079389        6.656474       0.000052   0.000000      0.000000
# 15         0.076677        6.494322      20.806836   0.005212      0.015846
# 16         0.079907        6.790409       0.000073   0.000000      0.000000
# 17         0.063077        5.344393       0.000054   0.000000      0.000000
# 18         0.094221        7.948525      39.087875   0.005130      0.015321
# 19         0.057219        4.862712       0.000062   0.000000      0.000000
# 20         0.075147        6.355407       0.000067   0.000000      0.000000
# 21         0.067092        5.613715      56.646563   0.005096      0.017139
# 22         0.069529        5.913507       0.000068   0.000000      0.000000
# 23         0.077267        6.498454       0.000056   0.000000      0.000000
# 24         0.068113        5.779328      75.501528   0.005230      0.015444
# 25         0.060768        5.192062       0.000052   0.000000      0.000000
# 26         0.073454        6.184009       0.000051   0.000000      0.000000
# 27         0.066547        5.598450      93.773146   0.005421      0.018040
# 28         0.070860        6.063935       0.000060   0.000000      0.000000
# 29         0.070149        5.910863       0.000050   0.000000      0.000000
# 30         0.059394        4.996200     111.467249   0.005191      0.015297
# 31         0.062693        5.313643       0.000072   0.000000      0.000000
# 32         0.072816        6.146306       0.000067   0.000000      0.000000
# 33         0.056319        4.728949     129.959742   0.005556      0.016421
# 34         0.057542        4.878733       0.000052   0.000000      0.000000
# 35         0.049888        4.150726       0.000050   0.000000      0.000000
# 36         0.037255        3.140096       0.000052   0.000000      0.000000
# 37         0.045918        3.875846     155.836309   0.005658      0.016795
# 38         0.047459        4.050787       0.000070   0.000000      0.000000
# 39         0.051280        4.331957       0.000054   0.000000      0.000000
# 40         0.066303        5.635295       0.000051   0.000000      0.000000
# 41         0.046573        3.899927     180.674240   0.005908      0.014743
# 42         0.033343        2.892424       0.000052   0.000000      0.000000
# 43         0.052903        4.485329       0.000049   0.000000      0.000000
# 44         0.054285        4.628223       0.000050   0.000000      0.000000
# 45         0.040905        3.464854     206.187849   0.005908      0.015120
# 46         0.076760        6.504116       0.000057   0.000000      0.000000
# 47         0.054598        4.640837       0.000056   0.000000      0.000000
# 48         0.064941        5.490682     225.305885   0.006026      0.015773
#
#     ...        A3        A4          A5        A6        A7  Extension  \
# 1   ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 2   ...  0.000071  0.001527    0.003673  0.005074  0.000000          0
# 3   ...  0.000070  0.001675    0.003459  0.005141  0.000000          0
# 4   ...  0.000041  0.001581    0.003479  0.005252  0.000000          0
# 5   ...  0.000066  0.001594    0.003571  0.004998  0.000000          0
# 6   ...  0.000041  0.001055    0.002027  0.004130  0.000000          0
# 7   ...  0.000269  0.001488    0.003715  0.005082  0.000000          0
# 8   ...  0.000254  0.001479    0.002952  0.005077  0.000000          0
# 9   ...  0.000060  0.001672    0.003008  0.005319  0.000000          0
# 10  ...  0.000052  0.001669    0.003665  0.005244  0.000000          0
# 11  ...  0.000065  0.001580    0.002823  0.004856  0.000000          0
# 12  ...  0.000048  0.001622    0.003835  0.003221  0.030443          0
# 13  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 14  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 15  ...  0.000049  0.001010   19.844539  0.000000  0.003840          0
# 16  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 17  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 18  ...  0.000026  0.001038   38.088569  0.000000  0.003947          0
# 19  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 20  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 21  ...  0.000040  0.001016   55.744801  0.000000  0.003902          0
# 22  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 23  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 24  ...  0.000027  0.001009   74.591350  0.000000  0.004097          0
# 25  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 26  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 27  ...  0.000025  0.000964   92.875051  0.000000  0.003841          0
# 28  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 29  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 30  ...  0.000027  0.001006  110.613949  0.000000  0.003899          0
# 31  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 32  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 33  ...  0.000027  0.001007  129.048376  0.000000  0.003856          0
# 34  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 35  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 36  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 37  ...  0.000040  0.001003  154.988344  0.000000  0.004233          0
# 38  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 39  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 40  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 41  ...  0.000038  0.001000  179.749541  0.000000  0.004317          0
# 42  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 43  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 44  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 45  ...  0.000040  0.000949  205.341754  0.000000  0.004028          0
# 46  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 47  ...  0.000000  0.000000    0.000000  0.000000  0.000000          0
# 48  ...  0.000026  0.000974  224.424224  0.000000  0.005332          0
#
#           E0   E1   E2        E3
# 1   0.000000  0.0  0.0  0.000000
# 2   0.004837  0.0  0.0  0.000110
# 3   0.004277  0.0  0.0  0.000239
# 4   0.004758  0.0  0.0  0.000098
# 5   0.004179  0.0  0.0  0.000160
# 6   0.003228  0.0  0.0  0.000212
# 7   0.004414  0.0  0.0  0.000443
# 8   0.004654  0.0  0.0  0.000228
# 9   0.004626  0.0  0.0  0.000108
# 10  0.004986  0.0  0.0  0.000106
# 11  0.004526  0.0  0.0  0.000090
# 12  0.002861  0.0  0.0  0.000081
# 13  0.000000  0.0  0.0  0.000000
# 14  0.000000  0.0  0.0  0.000000
# 15  0.000000  0.0  0.0  0.000000
# 16  0.000000  0.0  0.0  0.000000
# 17  0.000000  0.0  0.0  0.000000
# 18  0.000000  0.0  0.0  0.000000
# 19  0.000000  0.0  0.0  0.000000
# 20  0.000000  0.0  0.0  0.000000
# 21  0.000000  0.0  0.0  0.000000
# 22  0.000000  0.0  0.0  0.000000
# 23  0.000000  0.0  0.0  0.000000
# 24  0.000000  0.0  0.0  0.000000
# 25  0.000000  0.0  0.0  0.000000
# 26  0.000000  0.0  0.0  0.000000
# 27  0.000000  0.0  0.0  0.000000
# 28  0.000000  0.0  0.0  0.000000
# 29  0.000000  0.0  0.0  0.000000
# 30  0.000000  0.0  0.0  0.000000
# 31  0.000000  0.0  0.0  0.000000
# 32  0.000000  0.0  0.0  0.000000
# 33  0.000000  0.0  0.0  0.000000
# 34  0.000000  0.0  0.0  0.000000
# 35  0.000000  0.0  0.0  0.000000
# 36  0.000000  0.0  0.0  0.000000
# 37  0.000000  0.0  0.0  0.000000
# 38  0.000000  0.0  0.0  0.000000
# 39  0.000000  0.0  0.0  0.000000
# 40  0.000000  0.0  0.0  0.000000
# 41  0.000000  0.0  0.0  0.000000
# 42  0.000000  0.0  0.0  0.000000
# 43  0.000000  0.0  0.0  0.000000
# 44  0.000000  0.0  0.0  0.000000
# 45  0.000000  0.0  0.0  0.000000
# 46  0.000000  0.0  0.0  0.000000
# 47  0.000000  0.0  0.0  0.000000
# 48  0.000000  0.0  0.0  0.000000
#
# [48 rows x 27 columns]

# %% [markdown]
# # Crear DataFrame de tiempos de la función analysis_stm

# %% [markdown]
# ---
# Graficas
# ---
# ---

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
DataChunk = list(range(1, n_ventana + 1))

# %%
plt.plot(DataChunk, accuracy_ventana, label = "STM =" +str(n_clusters_stm[-1])+ ", MC = " +str(num_cluster))
plt.xlabel('Data Chunk')
plt.ylabel('Accuracy (%)')
plt.title("Accuracy del banco:")
plt.legend()
plt.savefig('Accuracy.jpg')
plt.show()

# %%
tiempos = Tiempos['Tiempo transcurrido [sec]']

# %%
tiempos = tiempos/60

# %%
plt.plot(DataChunk, tiempos, label = "STM =" +str(n_clusters_stm[-1])+ ", MC = " +str(num_cluster))
plt.xlabel('Data Chunk')
plt.ylabel('Tiempo [min])')
locs, labels = plt.xticks()  # Get the current locations and labels.
#plt.xticks(np.arange(0, 250, step=20))  # Set label locations.
plt.grid(True)
plt.title("Tiempos")
plt.legend()
plt.savefig('Tiempo_x_ventana.jpg')
plt.show()

# %% [markdown]
# # Guardar microclusteres creados

# %%
# Se guardan los micro clusteres creados- - MC_j_i -  j es la clase - i el cluster - - - - -
j = 0
n_c = []
for j in range(len(Cj)): # Número de clases
    for i in range(num_cluster[j]): # Número de clusters 
        # Escribir archivos csv
        globals()['MC_'+str(Cj[j])+'_'+str(i+1)].to_csv('MC_'+str(Cj[j])+'_'+str(i+1)+'.csv')

# %% [markdown]
# # Guardar los patrones clasificados por el NACOD

# %%
# Dataframe de las instancias clasificadas correctamente
patrones_clasificaciones_NACOD = pd.DataFrame(clases, index, columns)
patrones_clasificaciones_NACOD.to_csv('patrones_clasificaciones_NACOD.csv')
patrones_clasificaciones_NACOD
# Out:
#        Clase correcta  Clasificado en  Ventana  GHOS STM               Acierto
# 2000                3               3        1    41  no  verdaderos positivos
# 2001                3               3        1    41  no  verdaderos positivos
# 2002                2               2        1    36  no  verdaderos positivos
# 2003                2               2        1    34  no  verdaderos positivos
# 2004                3               3        1    41  no  verdaderos positivos
# ...               ...             ...      ...   ...  ..                   ...
# 97995               3               3       48    41  no  verdaderos positivos
# 97996               3               3       48    41  no  verdaderos positivos
# 97997               1               1       48    34  no  verdaderos positivos
# 97998               3               3       48    41  no  verdaderos positivos
# 97999               3               3       48    41  no  verdaderos positivos
#
# [89720 rows x 6 columns]

# %% [markdown]
# # Guardar los patrones mandados a STM

# %% [markdown]
# Son todas las instancias que NACOD no pudo clasificar y se fueron a la memoria corta.

# %%
# Dataframe del histórico de la información de las instancias que llegaron al
# short term memory durante la ejecución del programa.
patrones_mandados_a_STM = pd.DataFrame(clases_stm, index_stm, columns_stm)
patrones_mandados_a_STM.to_csv('patrones_mandados_a_STM.csv')
patrones_mandados_a_STM
# Out:
#        Clase correcta Clasificado en  Ventana  GHOS
# 4003                1            STM        2    29
# 4005                1            STM        2    28
# 4014                1            STM        2    30
# 4017                1            STM        2    29
# 4019                1            STM        2    30
# ...               ...            ...      ...   ...
# 97846               1            STM       48    30
# 97895               1            STM       48    30
# 97936               1            STM       48    30
# 97940               1            STM       48    30
# 97954               1            STM       48    30
#
# [6280 rows x 4 columns]

# %% [markdown]
# # Patrones que se detectaron en extensión o en nueva clase pero que son erroneos.

# %%
index_no_emerging = list(range(1,len(no_emerging)+1))
Clases_no_emerging = pd.DataFrame(no_emerging, index_no_emerging, col_no_emerging)
Clases_no_emerging.to_csv('Clusters_desechados.csv')
Clases_no_emerging
# Out:
#     Ventana  Cluster STM  clase original  clase propuesta      error  \
# 1         2            1               1                2  extension
# 2         2            2               1                2  extension
# 3         2            3               1                2  extension
# 4         3            1               1                2  extension
# 5         3            2               1                2  extension
# 6         3            3               1                2  extension
# 7         4            1               1                2  extension
# 8         4            2               1                2  extension
# 9         4            3               1                2  extension
# 10        5            1               1                2  extension
# 11        5            2               1                2  extension
# 12        5            3               1                2  extension
# 13        6            1               1                2  extension
# 14        6            2               1                2  extension
# 15        7            1               1                2  extension
# 16        7            2               1                2  extension
# 17        7            3               1                2  extension
# 18        8            1               1                2  extension
# 19        8            2               1                2  extension
# 20        8            3               1                2  extension
# 21        9            1               1                2  extension
# 22        9            2               1                2  extension
# 23        9            3               1                2  extension
# 24       10            1               1                2  extension
# 25       10            2               1                2  extension
# 26       10            3               1                2  extension
# 27       11            1               1                2  extension
# 28       11            2               1                2  extension
# 29       11            3               1                2  extension
# 30       12            1               1                2  extension
# 31       12            2               1                2  extension
# 32       15            2               1                0  emergente
# 33       15            3               1                0  emergente
# 34       18            1               1                0  emergente
# 35       18            3               1                0  emergente
# 36       21            1               1                0  emergente
# 37       21            2               1                0  emergente
# 38       24            1               1                0  emergente
# 39       24            2               1                0  emergente
# 40       27            1               1                0  emergente
# 41       27            2               1                0  emergente
# 42       30            1               1                0  emergente
# 43       30            3               1                0  emergente
# 44       33            2               1                0  emergente
# 45       33            3               1                0  emergente
# 46       37            1               1                0  emergente
# 47       37            3               1                0  emergente
# 48       41            1               1                0  emergente
# 49       41            3               1                0  emergente
# 50       45            1               1                0  emergente
# 51       45            2               1                0  emergente
# 52       48            1               1                0  emergente
# 53       48            2               1                0  emergente
#
#     instancias             T
# 1          247  40761.661010
# 2          118  40761.661010
# 3          104  40761.661010
# 4          112  34966.822734
# 5          222  34966.822734
# 6          105  34966.822734
# 7          228  33682.914870
# 8           93  33682.914870
# 9          122  33682.914870
# 10         119  33522.205432
# 11         227  33522.205432
# 12         114  33522.205432
# 13         237  33528.629465
# 14         209  33528.629465
# 15         118  33545.074856
# 16         234  33545.074856
# 17         102  33545.074856
# 18         110  33583.421694
# 19         239  33583.421694
# 20          95  33583.421694
# 21         236  33538.690671
# 22         112  33538.690671
# 23          94  33538.690671
# 24         252  33474.652543
# 25         103  33474.652543
# 26          99  33474.652543
# 27         118  33470.671735
# 28         224  33470.671735
# 29         123  33470.671735
# 30         235  33419.332539
# 31         102  33419.332539
# 32          63     24.128853
# 33          56     24.128853
# 34          76     24.005292
# 35          48     24.005292
# 36          72     24.318542
# 37          39     24.318542
# 38          67     24.384192
# 39          45     24.384192
# 40          64     24.446955
# 41          45     24.446955
# 42          72     24.466473
# 43          33     24.466473
# 44          71     24.584761
# 45          42     24.584761
# 46          67     24.635608
# 47          37     24.635608
# 48          79     24.537681
# 49          35     24.537681
# 50          37     24.543643
# 51          66     24.543643
# 52          39     24.647377
# 53          69     24.647377

# %% [markdown]
# ---
# ---

# %%
# Como queda STM al final del análisis
short_term_memory # STM Actualizado
short_term_memory.to_csv('STM_actualizada.csv')

# %%
# Clases correctas de la STM
short_classes # Clases de la STM Actualizadas
short_classes.to_csv('STM_clases_actualizadas.csv')

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
