# %% [markdown]
# ---
# # Banco de datos
# ---

# %%
# CAMBIOS: 

#Cambio 1
# se añadela variable mc_st en la ceda de parámetros de usuario, esta nos permite introducir el número de clusteres que deseamos crear una vez que se pueda analizar la stm.

#Cambio 2:
# Se agrega la cadena= base2 para identificar más facilmente los archivos de tiempo que se generen en esta versión.
# De la biblioteca timeit se importa default_timer como timer
# Se crea un data frame para guardar los tiempos que lleva cada proceso y saber en cuál tarda más.

#Cambio 3:
# Se eliminan las siguientes funciones: matrix_similarity_clusters y values
# Se crea la funcion g_h_o_s que reemplaza a las funciones eliminadas

# Cambio 4: 
# Ya no se mide el tiempo de la matriz GHOS porque ya no se hace.
# Se miden los tiempos en la STM para ver dónde se tarda más.
# Se tarda más en la función Analysis.
# Se miden los tiempos dentro de la función de Analysis para saber donde se tarda más.
# Se tarda más en A6

# Cambio 5 
# La siguiente línea se cambia ya que el método de append está obsoleto y será removido en futuras versiones. Este:
# globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)].append(X_test)
# Por este: globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = pd.concat((globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)], X_test), axis = 0)

# short_classes = short_classes.append(y_test.to_frame())  -- short_classes = pd.concat((short_classes, y_test.to_frame()), axis = 0)
# short_term_memory = short_term_memory.append(X_test) -- short_term_memory = pd.concat((short_term_memory, X_test), axis = 0)

# %% [markdown]
# Importing libraries.

# %%
import pandas as pd
import numpy as np
import math
# Bibliotecas para hacer clustering
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from sklearn.model_selection import LeaveOneOut
from statistics import mean 
from datetime import datetime #Ayuda a contar el tiempo de análisis en la ventana

# import collections
from itertools import groupby
# importar un "cronómetro"
from timeit import default_timer as timer
# Para mostrar barra de progreso:
#!pip install tqdm -q # Este ya esta instalado 
import time
from tqdm.notebook import tqdm_notebook

# %%
#S = pd.read_csv('C:/Users/super/OneDrive - Instituto Politecnico Nacional/TESIS Karen/Bancos/normal2000_smurf2000_neptune.csv')
S = pd.read_csv('C:/Users/Karen Pamela/OneDrive - Instituto Politecnico Nacional/TESIS Karen/Bancos/normal2000_smurf2000_neptune.csv')

cadena = 'base6_recurrent'

# %%
# S = S[:round(len(S.index)*.1)]
S = S[:36000] # 42000 #62000 # 980S

# %% [markdown]
# # Parámetros de usuario

# %%
# Preguntar si la clase es numérica o categórica. 
# class_type lo usa preprocessing_label_coding function
class_type = 'c' #input('Is the class numeric "n" or categorical "c"? ')
# Introduce the instances for training the model
InitNumber = 2000 #int(input("Introduce the InitNumber: "))
# Introduce the instances for the step window
paso = 2000 #int(input("Window size: "))
# Introduce the instances for the short term memory
n_elements_stm = 100 # 50 o 100
# Introduce el numero de instancias para determinar si un cluster es válido
n_representative = 20
# Al Timestamp actual se le resta ventana_de_olvido para que instancias mas viejas
# que esa diferencia se eliminen 
ventana_de_olvido = 2000 # más grande
#paso * 0.5 # Ventana para no tener instancias viejas en el short_term_memory
mc_stm = 10 # Número de clústeres que se harán en la stm
opc_clasif = 2 #input("Como realizar la clasificación? \n '1': si la clasificación es correcta se añade al mc, \n '2': si cumple con un umbral de similitud se añade al mc\n ")

# %% [markdown]
# ---
# # Modulos
# ---

# %% [markdown]
# # LABEL CODING
#
# The following function is for convert categoric attributes to label coding.
#
# Ordenate the dataframe as follows: label coding columns, numeric columns and CLASS columns.
#
# The function returns:
# - Preprocessed Dataframe.
# - Categoric columns names.
# - Numeric columns names.

# %%
def preprocessing_label_coding(S, class_type):
    """ Returns a preprocessed dataframe, for categoric attributes we use label
        coding
    INPUT: 
    - S: is the dataframe.
    - class_type: is a letter c indicates categoric and n numeric.
    OUTPUT:
    - S1: is the preprocessed dataframe.
    - num_col_names: names of the numeric attributes.
    - cat_col_names: names of the categoric attributes.
    """
    # Ask if the class is numeric or categoric.
    # class_type = input('Is the class numeric "n" or categorical "c"?')
    #Rename the last column
    S.columns = [*S.columns[:-1], 'CLASS']

    # Numeric columns
    S_numeric = S.select_dtypes(exclude='object') #This is a dataframe only with numeric attributes
    # Numeric colum names
    num_col_names = list(S_numeric.columns)

    # Categorical columns
    S_categorical = S.select_dtypes(include='object')
    # Numeric colum names
    cat_col_names = list(S_categorical.columns)
    # How many colums are categorical
    len_categorical = len(cat_col_names)

    # Label coding for categoric attributes
    aux_data = pd.DataFrame(columns = cat_col_names)
    # To do label coding:
    # 1. Convert object type to category type
    # 2 .cat.codes is for transform the categories to numbers
    # +1 because the labels starts at 0 and NaN -1 but I want that Nan = 0
    for i in range(len_categorical):
        aux_data[cat_col_names[i]] = S_categorical[cat_col_names[i]].astype('category').cat.codes + 1

    # S_categorical = label coding, zeros are replaced by NaN
    S_categorical = aux_data.replace(0,np.NaN)

    # ORDER my final dataframe with the following order:
    # Categoric columns, Numeric colums, Class column
    if class_type == 'c':
        class_colum = S_categorical['CLASS'] 
        S_categorical.drop("CLASS", axis=1, inplace=True) #Delete class_col
        cat_col_names.pop() #Eliminate CLASS for this list
        S1 = pd.concat([S_categorical,S_numeric,class_colum], axis=1) 
    else:
        print('numeric')
        A = S_numeric.shape
        if A[1] == 1: #If numeric columns only has the class column
            print(A[1])
            class_colum = S_numeric['CLASS']
            S1 = pd.concat([S_categorical,class_colum], axis=1) #Numeric columns will be empty
            num_col_names.pop() #Eliminate CLASS for this list
        else:
            print(A[1])
            class_colum = S_numeric['CLASS']
            S_numeric.drop("CLASS", axis=1, inplace=True)
            S1 = pd.concat([S_categorical,S_numeric,class_colum], axis=1)
            num_col_names.pop() #Eliminate CLASS for this list
    #print(S1)
    return S1, num_col_names, cat_col_names

# %% [markdown]
# # Modelo inicial de entrenamiento
#
#
# This first phase is the initial training of the algorithm. A set of labeled instances will be needed to create the initial model.
# As suggestion the Initial Number will be 2,000.

# %%
# - - - - - - - - - - MODEL TRAIN - - - - - - - - - -
def create_model_train(S1, InitNumber):
    """ Create the model train  
    INPUT: 
    - S1 is the preprocessed dataframe.
    OUTPUT:
    - Model Train: son los elementos utilizads para el entrenamiento
    """
    # InitNumber = input("Introduce the InitNumber: ")
    #InitNumber = int(InitNumber)

    # Take the first window
    model_train = S1[:InitNumber]
    # Delete the model train instances from S1
    aux_index = model_train.index.tolist()
    S1 = S1.drop(aux_index)
   
    # To convert NaN to zeros
    model_train = model_train.fillna(0)
    return S1, model_train

# %% [markdown]
# ---
# # Microcluster information
# - Timestamp
# - Number of instances. Número de instancias
# - LS Linear sum. Suma lineal
# - SS Cuadratic sum. Suma cuadrática
# - Cj label of the class to which they belong. Etiqueta de la clase perteneciente
# - Centroid. Centroide
# - Radius. Radio

# %%
def microcluster_information(j, i):
    """Cálculo de la información del microcluster por 1era vez.
    Para actualizaciones del mc se usa la función update"""   
    # Time stamp
    globals()['T_'+str(Cj[j])+'_'+str(i+1)] = globals()['MC_'+str(Cj[j])+'_'+str(i+1)].index[-1]
    # Instance number
    globals()['N_'+str(Cj[j])+'_'+str(i+1)] = len(globals()['MC_'+str(Cj[j])+'_'+str(i+1)].index)
    # Lineal Sum
    globals()['LS_'+str(Cj[j])+'_'+str(i+1)] = (globals()['MC_'+str(Cj[j])+'_'+str(i+1)].sum(axis=0)).drop(labels=['CLUSTER'])
    # Square Sum
    globals()['SS_'+str(Cj[j])+'_'+str(i+1)] = np.square(globals()['MC_'+str(Cj[j])+'_'+str(i+1)]).sum(axis=0).drop(labels=['CLUSTER'])
    # Centroid LS/N
    globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)] = globals()['LS_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]
    # Radius ( (SS/N) - pow(LS / N,2) ) ** 0.5
    globals()['Radius_MC_'+str(Cj[j])+'_'+str(i+1)] = ((globals()['SS_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]) - np.square(globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)])) ** 0.5
    # Standard deviation
    globals()['SD_'+str(Cj[j])+'_'+str(i+1)] = np.square(globals()['MC_'+str(Cj[j])+'_'+str(i+1)].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(Cj[j])+'_'+str(i+1)]).sum(axis=0)
    # Sigma
    globals()['sigma_'+str(Cj[j])+'_'+str(i+1)] = (globals()['SD_'+str(Cj[j])+'_'+str(i+1)] / globals()['N_'+str(Cj[j])+'_'+str(i+1)]) ** 0.5

# %% [markdown]
# # GHOS SIMILARITY
#
# It recives the instance and returns the max value of similarity and says in which class and cluster is.

# %%
def g_h_o_s(num_cluster, Cj, X_test, option):
    """ This function applies the GHOS numeric similarity &
        applies clostest clusters centroid 4 short term memory
    INPUT: 
    - Cj: a list with class labels
    - num_cluster: a list with the number of cluster for each class
    - instance: the instance to compare
    - option: 'similarity' means compute similarity function
            : 'euclidean' means euclidean distance
    OUTPUT: 
    - matrix (option 'similarity'): a dataframe with the clusters and classes and their similarity
    - matrix (option 'euclidean'): a dataframe with the euclidean distances between one short term
                         memory cluster and the microclusters centroids 
                         
    
    After similarity function, this function returns the cluster, class and max
        value corresponding to the X_test
    INPUT:
    - matrix: is a matrix of whom we will get the max/min cluster/class
              with classes as rows and cluster as columns
    - option: 1 maximo means class max, cluster max, and max value
              2 minimo means class min, cluster min, and min value
    OUTPUT
    - winning_class: The majority class 
    - winning_cluster: The majority cluster
    - winning_value: The majority value
    """
    instance = X_test
    # print("y test: " + str(int(y_test)))
    # Matrix similarity clusters
    k = 0 
    columns = []   
    class_ghos = []
    index =[]
    G = []
    i_class = [] 
    i_clust = []
    
    if option == 'classification':
        # Hacer un vector con los clusteres de cada clase
        for k in range(len(Cj)): # Num of classes
            for i in range(num_cluster[k]): # Num clusters
                i_class.append('Clas_' + str(Cj[k]))
                i_clust.append('Clust_' + str(i+1))
                #index.append('Clas_' + str(Cj[k]) + '_Clust_' + str(i+1))
                #print('Centroid_MC_'+str(Cj[k])+'_'+str(i+1))
                #print('sigma_'+str(Cj[k])+'_'+str(i+1))
                # - - - - GHOS numeric - - - -
                GHOS = (abs( instance - globals()['Centroid_MC_'+str(Cj[k])+'_'+str(i+1)] ) <= globals()['sigma_'+str(Cj[k])+'_'+str(i+1)]).sum(axis=1)
                G.append(GHOS.iloc[0])
        #print(i_class)
        #print(i_clust)
        #print(G)
        # Values winning_class, winning_cluster y ghos
        # Quiero saber el máximo de la lista
        ghos = max(G)
        #print("GHOS: " +str(ghos))
        # Quiero saber la posición de ese valor máximo
        max_index = G.index(ghos) 
        # Quiero saber la clase donde se encuentra este minimo
        winning_class = int(i_class[max_index].replace('Clas_', ''))
        #print("class: " +str(winning_class))
        # Cluster donde se encuentra el mínimo
        winning_cluster = int(i_clust[max_index].replace('Clust_', ''))
        #print("clust: " +str(winning_cluster))
        
    else: #option == novel_detection
        # Hacer un vector con los clusteres de cada clase
        for k in range(len(Cj)): # Num of classes
            for i in range(num_cluster[k]): # Num clusters
                i_class.append('Clas_' + str(Cj[k]))
                i_clust.append('Clust_' + str(i+1))
                #index.append('Clas_' + str(Cj[k]) + '_Clust_' + str(i+1))
                #print('Centroid_MC_'+str(Cj[k])+'_'+str(i+1))
                #print('sigma_'+str(Cj[k])+'_'+str(i+1))
                # - - - - GHOS numeric - - - -
                GHOS = math.sqrt((np.square(instance - globals()['Centroid_MC_'+str(Cj[k])+'_'+str(i+1)])).sum())
                G.append(GHOS)
            ##print(i_class)
            ##print(i_clust)
            ##print(G)
        # Quiero saber el mínimo de la lista
        ghos = min(G) #ghos = b
        ##print("GHOS: " +str(ghos))
        # Quiero saber la posición de ese valor máximo
        min_index = G.index(ghos) 
        # print(min_index)
        # Quiero saber la clase donde se encuentra este minimo
        winning_class = int(i_class[min_index].replace('Clas_', ''))
        # print("class: " +str(winning_class))
        # Cluster donde se encuentra el mínimo
        winning_cluster = int(i_clust[min_index].replace('Clust_', ''))
        # print("clust: " +str(winning_cluster))

    return winning_class, winning_cluster, ghos

# %% [markdown]
# # MICROCLUSTER UPDATE
#
# After calculating the GHOS similarity value and the threshold comparision if that value is equal or bigger than the threshold, the instant test is added to its respective cluster. And it must to be updated.

# %%
# - - - - - - - - - - MICROCLUSTER UPDATE - - - - - - - - - -
def update_microcluster(winning_class, winning_cluster, X_test):
    """ This function refresh cluster statistics  
    INPUT: 
    - winning_class: Class of the microcluster to be updated
    - winning_cluster: Cluster of the microcluster to be updated
    OUTPUT:
    - Microcluster updated
    """
    # Actualización del microcluster
    # Time stamp
    globals()['T_'+str(winning_class)+'_'+str(winning_cluster)] = X_test.index[-1]
    # Instance number
    globals()['N_'+str(winning_class)+'_'+str(winning_cluster)] = 1 + globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]   
    # Lineal Sum
    globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] = X_test.iloc[0] + globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] 
    # Square Sum
    globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)] = np.square(X_test.iloc[0]) + globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)]
    # Centroid LS/N
    globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)] = globals()['LS_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]
    # Radius ( (SS/N) - pow(LS / N,2) ) ** 0.5
    globals()['Radius_MC_'+str(winning_class)+'_'+str(winning_cluster)] = ((globals()['SS_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]) - np.square(globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)]))**0.5
    # Standard deviation
    globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)] = np.square(X_test.iloc[0] - globals()['Centroid_MC_'+str(winning_class)+'_'+str(winning_cluster)]) + globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)]
    # Sigma
    globals()['sigma_'+str(winning_class)+'_'+str(winning_cluster)] = (globals()['SD_'+str(winning_class)+'_'+str(winning_cluster)] / globals()['N_'+str(winning_class)+'_'+str(winning_cluster)]) ** 0.5

# %% [markdown]
# # CLASIFICATION

# %%
# - - - - - - - - - - - - ¿CÓMO SE DESEA CLASIFICAR? - - - - - - - - - 
def clasification_original(winning_class, aciertos_clases, winning_cluster, y_test, X_test, \
    index, indice,n_ventana, ghos, clases, aciertos, c_v_det, short_classes, \
    short_term_memory, index_stm, clases_stm, ghos_stm, clasificados):
    """ This function classify when the ghos coefficient determines a winning class and this winning class is equal to the real label
    INPUT: 
    - winning_class: Class of the microcluster to be updated
    - winning_cluster: Cluster of the microcluster to be updated
    - y_test: the real class, the real label
    - X_test: the instance that will be classified
    - index: variable que ayuda para llevar un registro de como se ha realizado la clasificación
    - indice : guarda el número de instancia que se esta analizando
    - n_ventana: es el número de ventana en el ue se está trabajando
    - ghos: número de atributos iguales entre la instancia a clasificar y los micro clusters del modelo
    - clases: lista que ayuda a llevar un registro de las instancias y su clasificación, contiene la siguiente
            información: clase correcta, clasificado en, número de ventana, ghos, stm, aciertos.
    - aciertos: contador para saber cuantos patrones ha clasificado (correctamente).
    - c_v_det: Lista que almacena los patrones y sus clases que fueron clasificadas correctamente en la ventana.
    - short_classes: son las clases originales/correctas de las instancias que están en
                     el Short Term Memory.
    - short_term_memory: data set of the instances belonging to short term memory.
    - index_stm: índices de las instancias en el short term memory
    - clases_stm: lista que ayuda a llevar un registro de las instancias y su clasificación, contiene la siguiente
            información: clase correcta, donde fue clasificado, en que número de ventana, valor de ghos
    - ghos_stm: lista que almacena los valores que la instancia mandada a la STM tuvo de ghos 
    - aciertos
    
    OUTPUT:
    - aciertos_clases: es una lista con las clases que fueron correctamente clasificadas
    - update_microcluster: es una función que actualiza las estadís This function refresh cluster statistics
    - index: variable que ayuda para llevar un registro de como se ha realizado la clasificación
    - clases: lista que ayuda a llevar un registro de las instancias y su clasificación, contiene la siguiente
             información: clase correcta, clasificado en, número de ventana, ghos, stm, aciertos.
    - aciertos: contador para saber cuantos patrones ha clasificado (correctamente).
    - c_v_det: Lista que almacena los patrones y sus clases que fueron clasificadas correctamente en la ventana.
    - short_clases: son las clases originales/correctas de las instancias que están en
                    el Short Term Memory.
    - short_term_memory: data set of the instances belonging to short term memory.
    - index_stm: índices de las instancias en el short term memory
    - clases_stm: lista que ayuda a llevar un registro de las instancias y su clasificación, contiene la siguiente
            información: clase correcta, donde fue clasificado, en que número de ventana, valor de ghos
    - ghos_stm: lista que almacena los valores que la instancia mandada a la STM tuvo de ghos
    """
    if winning_class == int(y_test):
        # Se crea una lista donde se almacene la clase que fue detectada correctamente
        aciertos_clases.append(int(y_test))
        #Se actualizan los MC
        # Añade la instancia al final del microcluster
        # La siguiente línea se cambia ya que el método de append está obsoleto y será removido en futuras versiones 
        # globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)].append(X_test)
        globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = pd.concat((globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)], X_test), axis = 0)
        # Se actualizan las estadísticas
        update_microcluster(winning_class, winning_cluster, X_test)
        # Las siguientes 3 líneas son para llevar un registro de 
        # instancia, clase correcta y cual clase fue asignada.
        index.append(indice)
        new_clases = {"Clase correcta": int(y_test), "Clasificado en": winning_class, "Ventana": n_ventana, "GHOS": ghos,"STM":'no', 'Acierto':'verdaderos positivos'}
        clases.append(new_clases)
        aciertos = aciertos + 1
        c_v_det.append(int(y_test))
        clasificados = clasificados + 1
    else:
        #print("ERROR index: " +str(index))
        # Almacenar las clases correctas del short term memory
        # La siguiente lpinea es cambiada de append por concat ya que append está obsoleto y será retirado en futuras versiones
        # short_classes = short_classes.append(y_test.to_frame())
        short_classes = pd.concat((short_classes, y_test.to_frame()), axis = 0)
        # El short term memory
        # La siguiente linea se cambia append por concate ya que apend en futuras versiones será removido.
        # short_term_memory = short_term_memory.append(X_test)
        short_term_memory = pd.concat((short_term_memory, X_test), axis = 0)
        # Las siguientes 3 líneas son para llevar un registro de 
        # instancia, clase correcta y cual clase fue asignada.
        new_clases_stm = {"Clase correcta": int(y_test), "Clasificado en":'STM', 'Ventana': n_ventana,"GHOS": ghos}
        index_stm.append(indice) #Indices de las instancias en el short term memory   
        clases_stm.append(new_clases_stm)
        # Guardar el GHOS de cada instancia en el stm
        ghos_stm.append(ghos)
              
    return aciertos_clases, index, clases, aciertos, c_v_det, \
    short_classes, short_term_memory, index_stm, clases_stm, ghos_stm, \
    clasificados

# %% [markdown]
# ---
# # Short Term Memory

# %%
# - - - - - - - - - - CLUSTERS SHORT TERM MEMORY - - - - - - - - - -
def clusters_stm(short_term_memory, mc_stm):
    """ Returns the clusters obteined of short term memory  
    INPUT: 
    - short term memory: data set of the instances belonging to short term memory
    OUTPUT:
    - Clusters: Is the same dataset as short term memory only with the difference of adding a
      column wich indicates the number of what cluster of whats belongs that instance.
    """
    n_clusters_stm = []
    #n_clusters_stm.append(int(input("Introduce number of clusters: ")))
    n_clusters_stm.append(mc_stm) ###PARÁMETRO QUE CAMBIA
    kmeans_stm = KMeans(n_clusters = n_clusters_stm[-1], random_state=0).fit(short_term_memory) ##Apply k-means clustering
    centroides = kmeans_stm.cluster_centers_
    labels2 = pd.Series(kmeans_stm.labels_ + 1)
    # Ese array lo pasamos a forma de Dataframe
    labels2 = labels2.to_frame()
    # Para poderlo concatenar al model train tenemos que hacer que los índices de las instancias cuadren
    labels2.index = short_term_memory.index
    # Renombramos a la columna con la palabra CLUSTER
    labels2.rename( columns={0:'CLUSTER'}, inplace=True )
    Clusters = pd.concat([short_term_memory,labels2], axis=1)
    return Clusters, n_clusters_stm

# %%
def class_extension(Cj, clase_cercana, num_cluster, ShortCluster, aux_index_sc, \
    short_classes, aciertos_stm, index_right_stm, clasif_right_stm,\
    index_wrong_stm, clasif_wrong_stm, cluster_cercano, instancias_stm, n_ventana,\
    n_cluster_stm, N, T):
    """ This function create a cluster in a new class  
    INPUT: 
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - clase_cercana = La clase donde está la menor distancia de su centroide al 
                      centroide del n uevo microcluster.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, se debe 
                   de leer con Cj para entenderlo.
    - ShortCluster: el cluster a integrar como extensión de una clase. 
    - aux_index_sc: contiene los índices de las instancias de ese cluster obtenido del
                    Short Term Memory.
    - aciertos_stm: contador de instancias que son asignadas correctamente.
    - short_classes = son las clases originales/correctas de las instancias que están en
                      el Short Term Memory.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias asignadas.
    - index_wrong_stm = una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm = es un diccionario que almacena clases correctas, asignadas y el
                         ghos de las instancias NO asignadas.
    - n_ventana = es un entero que especifica que ventana se está analizando.

    OUTPUT:
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, se debe 
                   de leer con Cj para entenderlo.
    - aciertos_stm: contador de instancias que son asignadas correctamente.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias asignadas.
    - index_wrong_stm: una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias NO asignadas.
   """
    # Se añade la extensión de clase    
    idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
    idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
    idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

    clase_mayor_frecuencia = idx_clase # la clase original q:e más se repite
    
    # Se pregunta si la clase original con mayor repetición es igual a la calculada
    if clase_mayor_frecuencia == clase_cercana:
        print("La mayoría de los patrones son clase: " +str(clase_mayor_frecuencia) + ". Y la clase cercana detectada fue: " +str(clase_cercana))
        print("Se añade esta extensión de clase.")
        class_index = Cj.index(clase_cercana)
        num_cluster[class_index] = num_cluster[class_index] + 1
        globals()['MC_'+str(Cj[class_index])+'_'+str(num_cluster[class_index])] = ShortCluster
        
        #Se calculan las estadísticas de este nuevo microcluster
        microcluster_information(class_index, num_cluster[class_index]-1)
        for j in range(len(aux_index_sc)):    
            #Si la asignación fue correcta
            if int(short_classes.loc[aux_index_sc[j]]) == clase_cercana:
                aciertos_stm = aciertos_stm + 1
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_right_stm.append(aux_index_sc[j])
                new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], 'acierto':'asignada correctamente'}
                clasif_right_stm.append(new_clases)
                # new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]), "classified in": clase_cercana, "GHOS": instancias_stm.at[aux_index_sc[j]], 'acierto':'Bien'}
            else: # Si la asignacion fue incorrecta:
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                print("Se descarta la extensión de clase")
                index_wrong_stm.append(aux_index_sc[j])
                new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]), \
                "Clasificado en": 'MC_'+str(clase_cercana)+'_'+str(num_cluster[class_index]),\
                "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'], "STM":'YES', \
                'Acierto':'asignada incorrectamente', 'Ventana':n_ventana}
                clasif_wrong_stm.append(new_clases)

    else: # si no coincide, hay error y no se añade al modelo
        #print("La clase cercana es : " + str(clase_cercana) + ", pero la clase con mayor repetición es: " + str(clase_mayor_frecuencia))
        #print("Se descarta esta extensión")
        
        new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': clase_mayor_frecuencia,\
        'clase propuesta': clase_cercana, 'error': "extension", 'instancias': N, "T": T}
        no_emerging.append(new_emerging_clases)            
            
    short_classes = short_classes.drop(aux_index_sc)    
    return Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, short_classes

# %%
def emerging_class(Cj, clases_originales, num_cluster, ShortCluster, aux_index_sc, short_classes, \
    aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, \
    instancias_stm, n_ventana, n_cluster_stm, N, T):
    """ This function create a cluster in a new class  
    INPUT: 
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - ShortCluster: el cluster a integrar en una nueva clase o extensión de una clase. 
    - aux_index_sc: contiene los índices de las instancias de ese cluster obtenido\
                    del Short Term Memory.
    - short_classes: son las clases originales/correctas de las instancias que están en el\
                     Short Term Memory.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias asignadas.
    - index_wrong_stm: una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias NO asignadas.
    - instancias_stm: Es el dataframe que da la información correcta y el valor de GHOS de
                      todas las instancias que se fueron al STM.
    - n_ventana = es un entero que especifica la ventana que se está utilizando

    OUTPUT:
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - short_classes: son las clases originales/correctas de las instancias que están en el\
                     Short Term Memory.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: una lista que va acumulando los indices de las instancias en la
                       stm que fueron asignadas correctamente.
    - clasif_right_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias asignadas.
    - index_wrong_stm: una lista que va acumulando los indices de las instancias en la
                       stm que NO fueron asignadas correctamente.
    - clasif_wrong_stm: es un diccionario que almacena clases correctas, asignadas y el
                        ghos de las instancias NO asignadas.
    """
    # Se añade la nueva clase    
    idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
    idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
    idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

    nueva_clase = idx_clase

    # Se pregunta si el índice de la clase original ya había sido tratado en el modelo 
    if nueva_clase in Cj:  #Si es así, no intervendrá en el modelo
        print("La clase "+str(nueva_clase) + " ya existía.")

        new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': nueva_clase,\
        'clase propuesta': 0, 'error': "emergente", 'instancias': N, 'T': T}
        no_emerging.append(new_emerging_clases) 

    else: # Sí no es así, se crea el microcluster.
        print("La nueva clase es: " + str(nueva_clase))
        # Al 'vector' Cj se le añade como último elemento la nueva clase
        Cj.append(nueva_clase)

        # Sería el primer microcluster de esa clase
        num_cluster.append(1)

        # Se crea el nuevo microcluster
        globals()['MC_'+str(Cj[-1])+'_'+str(num_cluster[-1])] = ShortCluster

        #microcluster_information(clase, clluster)
        microcluster_information(len(Cj)-1, 0)

        # El siguiente ciclo for es para visualizar en un dataframe instancia por instancia
        # su clase original y el MC a la cual fue asignada
        for j in range(len(aux_index_sc)):
            # SABER NUMERO DE VENTANA, CLASE ASIGNADA
            # NUMERO DE ELEMENTOS DE LAS CLASES CORRECTAS EN ESTE MICROCLUSTER  
            # Si la asignación fue correcta
            if int(short_classes.loc[aux_index_sc[j]]) == nueva_clase:
                aciertos_stm = aciertos_stm + 1
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_right_stm.append(aux_index_sc[j])
                new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]),\
                "classified in": 'MC_'+str(nueva_clase)+'_'+str(1), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],\
                "stm":'YES', 'acierto':'Bien'}
                clasif_right_stm.append(new_clases)

            else: # Si la asignación fue incorrecta
                ## ESCRIBIR NUMERO DE VENTANAS, CLASE QUE DETECTÓ
                # Las siguientes 3 líneas son para llevar un registro de la asignación.
                index_wrong_stm.append(aux_index_sc[j])
                new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]),\
                "Clasificado en": 'MC_'+str(nueva_clase)+'_'+str(1),\
                "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],"STM":'YES',\
                'Acierto':'asignado incorrectamente.',
                'Ventana': n_ventana}
                clasif_wrong_stm.append(new_clases) 

    # CONTAR LA FRECUENCIA DE CADA CLASE CORRECTA EN ESTE MICROCLUSTER

    short_classes = short_classes.drop(aux_index_sc)
    
    return Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,index_wrong_stm, clasif_wrong_stm, short_classes

# %%
def analysis_stm(short_term_memory, short_classes, Clusters, n_clusters_stm,\
    Cj, clases_originales, num_cluster, aciertos_stm,index_right_stm, clasif_right_stm, index_wrong_stm,\
    clasif_wrong_stm, instancias_stm, n_ventana):
    """Checa si un cluster es o no es válido.
    Si es válido, hace la asignación como extensión de la clase o clase
    emergente.
    INPUT:
    - short_term_memory: data set of the instances belonging to short term memory.
    - short_classes: son las clases originales/correctas de las instancias que están en\
                     el Short Term Memory.
    - Clusters: Dataframe con las instancias clasificadas por clusters
    - n_clusters_stm: Es una lista que contiene el número de clusters que deseamos tener
                      de las isntancias del short term memory
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: es una lista que contiene los índices de las instancias de la 
                       short term memory que fueron asignadas correctamente.                       
    - clasif_right_stm: es un diccionario dentro de una lista que de cada instancia
                        de la stm, asignadas correctamente me da información para 
                        visualizarla en un dataframe, la información que me proporciona
                        es clase correcta, en cual se asignó y valor de GHOS. 
    - index_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    - clasif_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    - instancias_stm: Es el dataframe que da la información correcta y el valor de GHOS de
                      todas las instancias que se fueron al STM.
    - n_ventana:  es un entero que especifíaca el número de ventana que se está analizando
    
    OUTPUT:
    - Cj: es una lista que contiene las etiquetas de las clases que se han registrado.
    - short_term_memory: data set of the instances belonging to short term memory.
    - num_cluster: es una lista que me indica cuantos clusters hay por clase, \
                   se debe de leer con Cj para entenderlo.
    - ShortCluster: el cluster a integrar como extensión de una clase.
    - aux_index_sc: cuando un cluster va a ser añadido al modelo se crea esta 
                    lista que contiene los índices de esas instancias para poder
                    borrarlos de la Short Term Memory.
    - short_classes: son las clases originales/correctas de las instancias que están en\
                     el Short Term Memory.
    - aciertos_stm: una variable que va acumulando los aciertos que se tiene en el STM.
    - index_right_stm: es una lista que contiene los índices de las instancias de la 
                       short term memory que fueron asignadas correctamente.                       
    - clasif_right_stm: es un diccionario dentro de una lista que de cada instancia
                        de la stm, asignadas correctamente me da información para 
                        visualizarla en un dataframe, la información que me proporciona
                        es clase correcta, en cual se asignó y valor de GHOS. 
    - index_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    - clasif_wrong_stm: cumple la misma función que index_right_stm pero con las instancias
                       que fueron asignadas erroneamente.
    """
    
    print("Analysis")
    ## Tiempo de ejecución
    
    an_tot_stm = 0.0
    an1_stm = 0.0
    an_ini_stm = timer()
    
    for i in range(n_clusters_stm[-1]):
        n_cluster_stm = i + 1
        #Este es el cluster del short term memory a analizar
        ShortCluster = Clusters[Clusters['CLUSTER']==i+1]
        # Es cohesivo?
        # Calcular Silhouette. Para ello debemos de tener el centroide del microcluster.
        # Centroid LS/N
        N = len(ShortCluster.index)
        LS = (ShortCluster.sum(axis=0)).drop(labels=['CLUSTER'])
        Centroid = LS / N
        Silhouette = 0  
        # - - - - - VALIDACION DEL CLUSTER - - - - - - - -     
        # Se verifica si es representativo, si lo es, se verifica si es cohesivo (Silhouette)
        # ...To identify if a cluster is cohesive, a modified silhouette coefficient will be used...
        
        # - - - - - - REPRESENTATIVO - - - - - - - - 
        if N >= n_representative: #Si es representativo entra a este for
        # Silhouette = b-a / max(a,b)
            clase_cercana, cluster_cercano, b = g_h_o_s(num_cluster, Cj, Centroid, 'novel_detection')
        # a standar deviation of the distance between each instance of the new microcluster
        # and the new microcluster centroid
            a = []
            for i in range(len(ShortCluster)):
            # a es una lista que almacena las distancias euclideanas entre cada instancia de ese
            # microcluster y el centroide.
                a.append(np.linalg.norm(ShortCluster.iloc[[i]].drop(['CLUSTER'], axis=1) - Centroid))
            # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
            # sqrt (((x_prom - x)**2 suma) / N )
            a = math.sqrt(((mean(a) - a)**2).sum() / len(a))
            ##  print("a: " + str(a))
            if max(b,a) != 0:
                Silhouette = (b - a) / max(b, a)
            # Verificar si el cluster es válido, significa que Silhouette > 0,
            # si es representativo y válido: instancias se eliminan del short term memory
                # print("Silhouette: " + str(Silhouette))
                # print("b = " + str(b) + ". a = " + str(a))
            # - - - - - - - - - - - COHESIVO - - - - - -
                if Silhouette > 0: # El cluster es válido
                    aux_index_sc = ShortCluster.index.tolist()
                # Borrar estas instancias del short term memory y también sus clases
                    short_term_memory = short_term_memory.drop(aux_index_sc)
                    # - - - - NOVELTY PROCESS - - - - 
                    # - - - - - - Threshold - - - - - -
                    # T = la media de las distancias del centroide del microcluster de la clase 
                    # más cercana con respecto a los demás microclusters de esa clase
                    # print("Cálculo de T")
                    Centroide_cercano = globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]
                    # print("Distancia entre el Centroide_"+ str(clase_cercana)+"_"+str(cluster_cercano) + " con respecto a:")
                    T = []
                    # print("La clase cercana es: " + str(clase_cercana) + " y el cluster cercano es: " + str(cluster_cercano))
                    class_index = Cj.index(clase_cercana) # class index guarda la posición de Cj donde está la clase más cercana
                    # esta posición la busco en num_cluster para saber cuantos clusters hay en la clase más cercana 
                    for j in range(0, num_cluster[class_index]): # Modifiqué porque estaba malrange(0, cluster_cercano)
                        i = j + 1
                        if i != cluster_cercano: # Si el índice i coincide con cluster cercano no entra en esta sentencia porque
                            # no debe calcular la distancia con respecto a él mismo
                            #print("Se compara con clase: "  + str(clase_cercana) + ", cluster: "+ str(i))
                            # la distancia se estaría compárando con respecto al mismo centroide 
                            T.append(np.linalg.norm(globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(i)] - Centroide_cercano))
                            # print("Centroide más cercano vs Centroide_" + str(clase_cercana) + "_"+str(i+1))
                    #print("T antes del promedio: " + str(T))
                    if len(T) >= 1: #Significa que hay al menos 2 clusteres de esa clase
                        #print("T tiene más de un micro cluster en esa clase.")
                        T = sum(T)/len(T)
                        #print("T = " + str(T))
                    else: #Significa que solo hay un cluster de esa clase
                        #print("T solo tiene 1 microcluster en esa clase, hay que recalcular")
                        # Se inicializa T = [] para hacer el promedio entre el 
                        # Centroide y sus instancias
                        T = [] 
                        # for que recorre instancia por instancia del microcluster más cercano (mp).
                        for i in range(len(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)])):
                            # T es una lista que almacena las distancia euclideanas
                            # de cada instancia de mp con respecto al centroide mp  
                            T.append( np.linalg.norm(globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)].iloc[[i]].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]) )
                        
                        ## - - - - - - - OTRA MANERA DE CALCULAR T
                        #T = [] 
                        ## for que recorre instancia por instancia del microcluster más cercano (mp).
                        ## DISTANCIA EUCLIDEANA
                        ## Se restan las distancias
                        #d_euc = globals()['MC_'+str(clase_cercana)+'_'+str(cluster_cercano)].drop(['CLUSTER'], axis=1) - globals()['Centroid_MC_'+str(clase_cercana)+'_'+str(cluster_cercano)]
                        ## Se elevan al cuadrado
                        #d_euc = d_euc * d_euc
                        ## Se hace la sumatoria 
                        #d_euc = np.sum(d_euc, axis=1)
                        ## Se obtiene la raÍz cuadrada
                        #d_euc = d_euc **(1/2)
                        ## CÁlculo de desviaciÓn estÁndar
                        #T = math.sqrt(((mean(d_euc) - d_euc)**2).sum() / len(d_euc))
                        
                        # Ya obtenidas las distancias euclideanas calculamos la desviación estándar
                        # sqrt (((x_prom - x)**2 suma) / N )
                        T = math.sqrt(((mean(T) - T)**2).sum() / len(T))
                        print("T: " + str(T))
                    # ¿Existente o nueva clase?
                    # print("b: " +str(b) + ", T: " + str(T))
                    # - - - - - - - EXTENSIÓN DE CLASE - - - - - - 
                    if b < T:  #El nuevo microcluster se considera una extensión de la clase
                    #print("B: " + str(b) + ", T: " + str(T))
                    #print("Clust cerc: " +str(cluster_cercano) + "clase cercana: " + str(clase_cercana))
                        #print("EXTENSIÓN de clase")
                        Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                        index_wrong_stm, clasif_wrong_stm, short_classes = class_extension(Cj,\
                        clase_cercana, num_cluster, ShortCluster, aux_index_sc, short_classes,\
                        aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm,\
                        clasif_wrong_stm, cluster_cercano, instancias_stm, n_ventana, n_cluster_stm,\
                        N, T)
                    # - - - - - - - NUEVA CLASE - - - - - - - - 
                    else: #El microcluster se considera una clase emergente
                        #print("Clase EMERGENTE")
                        """
                        Cj, num_cluster, aciertos_stm, index_right_stm, clasif_right_stm,\
                        index_wrong_stm,clasif_wrong_stm, short_classes = emerging_class(Cj,\
                        clases_originales, num_cluster, ShortCluster,aux_index_sc, short_classes,\
                        aciertos_stm, index_right_stm, clasif_right_stm,index_wrong_stm,clasif_wrong_stm,\
                        instancias_stm, n_ventana, n_cluster_stm, N, T)
                        """
                        # Se añade la nueva clase    
                        idx_clase = pd.Index(clases_originales[aux_index_sc].tolist(), name ='CLASS')
                        idx_clase = idx_clase.value_counts() #Esto queda en forma de core series  2 100
                        idx_clase = idx_clase[idx_clase == idx_clase.max()].index[0]

                        nueva_clase = idx_clase

                        # Se pregunta si el índice de la clase original ya había sido tratado en el modelo 
                        if nueva_clase in Cj:  #Si es así, no intervendrá en el modelo
                            print("La clase "+str(nueva_clase) + " ya existía.")

                            new_emerging_clases = {"Ventana": n_ventana, "Cluster STM": n_cluster_stm, 'clase original': nueva_clase,\
                            'clase propuesta': 0, 'error': "emergente", 'instancias': N, 'T': T}
                            no_emerging.append(new_emerging_clases) 

                        else: # Sí no es así, se crea el microcluster.
                            print("La nueva clase es: " + str(nueva_clase))
                            # Al 'vector' Cj se le añade como último elemento la nueva clase
                            Cj.append(nueva_clase)

                            # Sería el primer microcluster de esa clase
                            num_cluster.append(1)

                            # Se crea el nuevo microcluster
                            globals()['MC_'+str(Cj[-1])+'_'+str(num_cluster[-1])] = ShortCluster

                            #microcluster_information(clase, clluster)
                            microcluster_information(len(Cj)-1, 0)

                            # El siguiente ciclo for es para visualizar en un dataframe instancia por instancia
                            # su clase original y el MC a la cual fue asignada
                            for j in range(len(aux_index_sc)):
                                # SABER NUMERO DE VENTANA, CLASE ASIGNADA
                                # NUMERO DE ELEMENTOS DE LAS CLASES CORRECTAS EN ESTE MICROCLUSTER  
                                # Si la asignación fue correcta
                                if int(short_classes.loc[aux_index_sc[j]]) == nueva_clase:
                                    aciertos_stm = aciertos_stm + 1
                                    # Las siguientes 3 líneas son para llevar un registro de la asignación.
                                    index_right_stm.append(aux_index_sc[j])
                                    new_clases = {"correct Class": int(short_classes.loc[aux_index_sc[j]]),\
                                    "classified in": 'MC_'+str(nueva_clase)+'_'+str(1), "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],\
                                    "stm":'YES', 'acierto':'Bien'}
                                    clasif_right_stm.append(new_clases)

                                else: # Si la asignación fue incorrecta
                                    ## ESCRIBIR NUMERO DE VENTANAS, CLASE QUE DETECTÓ
                                    # Las siguientes 3 líneas son para llevar un registro de la asignación.
                                    index_wrong_stm.append(aux_index_sc[j])
                                    new_clases = {"Clase_correcta": int(short_classes.loc[aux_index_sc[j]]),\
                                    "Clasificado en": 'MC_'+str(nueva_clase)+'_'+str(1),\
                                    "GHOS": instancias_stm.at[aux_index_sc[j], 'GHOS'],"STM":'YES',\
                                    'Acierto':'asignado incorrectamente.',
                                    'Ventana': n_ventana}
                                    clasif_wrong_stm.append(new_clases) 

                        # CONTAR LA FRECUENCIA DE CADA CLASE CORRECTA EN ESTE MICROCLUSTER

                        short_classes = short_classes.drop(aux_index_sc)
                        #print("Así quedan las clases y sus respectivos clusters.")
                        #print(Cj)
                        #print(num_cluster)
                        
    an_fin_stm = timer()
    an_tot_stm = an_fin_stm - an_ini_stm
    
    return Cj, short_term_memory, num_cluster, ShortCluster, short_classes,\
    aciertos_stm, index_right_stm, clasif_right_stm, index_wrong_stm, clasif_wrong_stm, \
    an_tot_stm

# %%
def update_t_s(short_term_memory, short_classes, Time_stamps, ventana_de_olvido):
    """ This function updates the short term memory.
    INPUT:
    - short_memory: Data set for intances didn't recognized
    - Time_stamps: lista que contiene los índices de la última instancia de cada
                   ventana.
    - ventana_de_olvido: es un número que el usuario define. Al Timestamp actual 
                         se le resta este número para que instancias mas viejas
                         que esa diferencia se eliminen 
    OUTPUT:
    - short_term_memory: is the dataset of the short memory updated
    - short_classes: is the dataframe of classes correspondind to the short memory updated.
    """
    # Update time stamp
    current_t_s = Time_stamps[-1] #Current time stamp
    update_time = current_t_s - ventana_de_olvido # difference_time_stamp es el factor de olvido
    short_term_memory = short_term_memory.loc[update_time:, :]
    short_term_memory
    # Update short_classes 
    aux_index = short_term_memory.index.tolist()
    short_classes = short_classes.loc[aux_index]
    
    return short_term_memory, short_classes

# %%
# function to get unique values 
def unique(lista): 
    valores = []  
    # insert the list to the set 
    list_set = set(lista) 
    # convert the set to the list 
    unique_list = (list(list_set)) 
    for valor in unique_list: 
        valores.append(valor)
        # print(x)
    return valores

# %%
def clases_en_ventana(lista_clases):
    """Esta función regresa un diccionario con la clase y número de instancias que hay.
    INPUT:
    - clases_totales: es una lista con todas las etiquetas de clases presentadas en la ventana
    OUTPUT:
    - n_v: el diccionario donde indica clase y número de instancias
    """
    
    # Clases e instancias TOTALES por ventana
    lista_clases = sorted(lista_clases, reverse=False) # La lista se arregla de mayor a menor.
    lista_clases_unique = unique(lista_clases) # Se obtienen los valores únicos (clases)
    n_instancias = [len(list(group)) for key, group in groupby(lista_clases)] # Lista con cantidad de
    # patrones que hay por clase
    C_v_tot = []
    for i in lista_clases_unique:
        C_v_tot.append("clase_"+str(i))
    # using naive method to convert lists to dictionary 
    diccionario_clases = {} 
    for key in C_v_tot: 
        for value in n_instancias: 
            diccionario_clases[key] = value 
            n_instancias.remove(value) 
            break 
    return diccionario_clases

# %%
def clusters_en_ventana(Cj, num_clusters):
    """ Esta función regresa en forma de diccionario las clases detectadas 
    y sus clusters creados.
    INPUT:
    - Cj: es una lista que contiene las etiquetas de clases detectadas
    -num_clusters: es una lista con el número de clusters por cada clase
    OUTPUT:
    - diccionario_clusters: es un diccionario que relaciona la clase y el número total de los clusters creados"""  

    Cluster_v = []
    for i in Cj:
        Cluster_v.append("cluster_clase_"+str(i))
    
    num_c = num_clusters.copy()
    diccionario_clusters = {} 
    for key in Cluster_v: 
        for value in num_c: 
            diccionario_clusters[key] = value 
            num_c.remove(value) 
            break
    return diccionario_clusters

# %% [markdown]
# ---
# # PREPROCESSING.
# ---

# %%
S
# Out:
#        Unnamed: 0  atrib1 atrib2    atrib3 atrib4  atrib5  atrib6  atrib7  \
# 0          256368       0   icmp     ecr_i     SF    1032       0       0
# 1          453300       0    udp  domain_u     SF      46      46       0
# 2          256244       0   icmp     ecr_i     SF    1032       0       0
# 3          453038       0    udp  domain_u     SF      42      42       0
# 4          256453       0   icmp     ecr_i     SF    1032       0       0
# ...           ...     ...    ...       ...    ...     ...     ...     ...
# 35995      252105       0   icmp     ecr_i     SF    1032       0       0
# 35996      164573       0   icmp     ecr_i     SF    1032       0       0
# 35997      139950       0   icmp     ecr_i     SF    1032       0       0
# 35998      456598       0    tcp      http     SF     326     849       0
# 35999        8782       0   icmp     ecr_i     SF    1032       0       0
#
#        atrib8  atrib9  ...  atrib33  atrib34  atrib35  atrib36  atrib37  \
# 0           0       0  ...      255      1.0      0.0     1.00     0.00
# 1           0       0  ...      255      1.0      0.0     0.01     0.00
# 2           0       0  ...      255      1.0      0.0     1.00     0.00
# 3           0       0  ...      255      1.0      0.0     0.01     0.00
# 4           0       0  ...      255      1.0      0.0     1.00     0.00
# ...       ...     ...  ...      ...      ...      ...      ...      ...
# 35995       0       0  ...      255      1.0      0.0     1.00     0.00
# 35996       0       0  ...      255      1.0      0.0     1.00     0.00
# 35997       0       0  ...      255      1.0      0.0     1.00     0.00
# 35998       0       0  ...      255      1.0      0.0     0.01     0.02
# 35999       0       0  ...      255      1.0      0.0     1.00     0.00
#
#        atrib38  atrib39  atrib40  atrib41    clase
# 0          0.0      0.0      0.0      0.0   smurf.
# 1          0.0      0.0      0.0      0.0  normal.
# 2          0.0      0.0      0.0      0.0   smurf.
# 3          0.0      0.0      0.0      0.0  normal.
# 4          0.0      0.0      0.0      0.0   smurf.
# ...        ...      ...      ...      ...      ...
# 35995      0.0      0.0      0.0      0.0   smurf.
# 35996      0.0      0.0      0.0      0.0   smurf.
# 35997      0.0      0.0      0.0      0.0   smurf.
# 35998      0.0      0.0      0.0      0.0  normal.
# 35999      0.0      0.0      0.0      0.0   smurf.
#
# [36000 rows x 43 columns]

# %%
# - - - - - - - - - - - - - - - - STREAM DATA SET - - - - - - - - - - - - - - - - -
S
# - - - - - - - - - - - - - - - - Delete attrib0 column - - - - - - - - - - - - - - - - - 
# Here we have a little problem, the first column is unnecessary, 
# so we must to eliminate but not having a name will not be possible so
# we must rename it and after that eliminate.
S.rename( columns={'Unnamed: 0':'attrib0'}, inplace=True )
del S['attrib0']

# - - - - - - - - - - - - - - - - Rearrange our database - - - - - - - - - - - - - - - -
# First columns: categorical
# After categorical columns: numerical
# CLASS column
S1, num_col_names, cat_col_names = preprocessing_label_coding(S, class_type)
clases_originales = S1['CLASS']

rows = S1.shape[0]
attributes = S1.shape[1]
print("Your dataset has " + str(rows) + " instances and " + str(attributes) + " attributes")
# - - - - - - - - NÚMERO TOTAL DE CLASES - - - - - - - - - - - - 
C_tot = clases_originales.value_counts(sort=True)
C_tot = C_tot.keys()
C_tot = C_tot.tolist()
print("The total classes that your stream has are the following ones: ")
print(C_tot)
# Out:
# Your dataset has 36000 instances and 42 attributes
# The total classes that your stream has are the following ones:
# [3, 2, 1]

# %% [markdown]
# ---
# ---
# ---
# # Naıve Associative Classifier for Online Data (NACOD)
# ---
# ---
# ---

# %%
# Model train
S1, model_train = create_model_train(S1, InitNumber)

# %%
len(S1)
# Out:
# 34000

# %%
# - - - - - - - - - - - - - - - Identify how many classes we have - - - - - - - - - - - - - - - 
# Classes of my model train
Cj = model_train.iloc[:,-1]
# Count classes by label
Cj = Cj.value_counts(sort=True)
Cj
# Out:
# 3    1022
# 2     978
# Name: CLASS, dtype: int64

# %%
# - - - - - - - - - - - - - - - LABEL CLASSES - - - - - - - - - - - - - - -
Cj = Cj.keys()
Cj = Cj.tolist()
#length = len(Cj)
Cj
# Out:
# [3, 2]

# %%
# - - - Obtener un D_# por cada clase - SUBSETS OF THE TRAINING DATASET - - - - - - - - - - - - - - -
j = 0
for i in range(len(Cj)):
    globals()['D_'+str(Cj[i])] = model_train[model_train['CLASS']==Cj[i]]
    globals()['D_'+str(Cj[i])].pop('CLASS') # Eliminate class
    #    model_train[model_train['CLASS'].str.match(Cj[i])] #if the classes were categorical
del model_train # Lo borramos
# D_1
# D_2

# %% [markdown]
# ---
# # CLUSTERING
# ---

# %% [markdown]
# ---
# # K_means
# Apply the K means algorithm in each D_x, we will asked how many clusters do we want for each x.
#
# Result:
#  * Centroid of each cluster (4) in D_x (8 centroids)
#  * MC_x in wich the CLASS colum will be changed by CLUSTER column based in which instance belongs to what cluster.
# ---

# %%
##### - A los sets de cada clase se les añade una columna al final la cual
# indica el numero de cluster al que pertenece cada instancia
j = 0
num_cluster = [] # Empty list for number of clusters
for i in range(len(Cj)): # How many Dj
    j = i+1
    # Se hace el Kmeans con n clústers
    num_cluster.append(int(input('Number of clusters for D_'+str(Cj[i])+'? ')))
    globals()['kmeansD_'+str(Cj[i])] = KMeans(n_clusters=int(num_cluster[-1]), random_state=0).fit(globals()['D_'+str(Cj[i])])
    # Obtener los centroides de cada cluster
    globals()['centroidsD_'+str(Cj[i])] = globals()['kmeansD_'+str(Cj[i])].cluster_centers_ 
    # Column_series es el array de a cuál cluster pertenecen las instancias
    column_series = pd.Series(globals()['kmeansD_'+str(Cj[i])].labels_ + 1)
    # Ese array lo pasamos a forma de Dataframe
    globals()['MC_'+str(Cj[i])] = column_series.to_frame()
    # Para poderlo concatenar al model train tenemos que hacer que los índices de las instancias cuadren
    globals()['MC_'+str(Cj[i])].index = globals()['D_'+str(Cj[i])].index
    # Renombramos a la columna con la palabra CLUSTER
    globals()['MC_'+str(Cj[i])].rename( columns={0:'CLUSTER'}, inplace=True )
    globals()['MC_'+str(Cj[i])] = pd.concat([globals()['D_'+str(Cj[i])],globals()['MC_'+str(Cj[i])]], axis=1) 

# del D_1 # Se elimina
# del D_3 # Se elimina
# MC_1
# MC_2
# Out:
# Number of clusters for D_3?  5
# Number of clusters for D_2?  5

# %%
# Se crean los micro clusteres - - MC_j_i -  j es la clase - i el cluster - - - - -
j = 0
n_c = []
for j in range(len(Cj)): # Número de clases
    for i in range(num_cluster[j]): # Número de clusters 
        globals()['MC_'+str(Cj[j])+'_'+str(i+1)] = globals()['MC_'+str(Cj[j])][globals()['MC_'+str(Cj[j])]['CLUSTER']==i+1]
        n_c.append(len(globals()['MC_'+str(Cj[j])+'_'+str(i+1)]))
        # Escribir archivos csv
        #globals()['MC_'+str(Cj[j])+'_'+str(i+1)].to_csv('MC_'+str(Cj[j])+'_'+str(i+1)+'.csv')
    del globals()['MC_'+str(Cj[j])]

# %%
n_c # numero de instancias pertenecientes a cada cluster
# Out:
# [997, 3, 7, 13, 2, 957, 1, 1, 4, 15]

# %% [markdown]
# # Micro clusters información.
# Se llama a la funcion "microcluster_information" para obtener la siguiente información:
# - Timestamp, Number of instances. Número de instancias, LS Linear sum. Suma lineal
# - SS Cuadratic sum. Suma cuadrática, Cj label of the class to which they belong. Etiqueta de la clase perteneciente
# - Centroid. Centroide, Radius. Radio

# %%
# - - MC_j_i - - - INFORMATION - - - - average vector for numeric attributes
# missing to obtain Mode vector for categorical attributes.
for j in range(len(Cj)): # Num of classes
    for i in range(num_cluster[j]): # Num of clusters
        # Time stamp
        microcluster_information(j,i)

# %% [markdown]
# # Online phase.
#
# Classification
# ---

# %%
S2 = S1
S2
# Out:
#        atrib2  atrib3  atrib4  atrib1  atrib5  atrib6  atrib7  atrib8  atrib9  \
# 2000        1      14       6       0    1032       0       0       0       0
# 2001        1      14       6       0    1032       0       0       0       0
# 2002        2      22       6       0     304    2698       0       0       0
# 2003        2      48       6       2     812     332       0       0       0
# 2004        1      14       6       0    1032       0       0       0       0
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 35995       1      14       6       0    1032       0       0       0       0
# 35996       1      14       6       0    1032       0       0       0       0
# 35997       1      14       6       0    1032       0       0       0       0
# 35998       2      22       6       0     326     849       0       0       0
# 35999       1      14       6       0    1032       0       0       0       0
#
#        atrib10  ...  atrib33  atrib34  atrib35  atrib36  atrib37  atrib38  \
# 2000         0  ...      255     1.00     0.00     1.00     0.00      0.0
# 2001         0  ...      255     1.00     0.00     1.00     0.00      0.0
# 2002         0  ...      250     0.98     0.01     0.00     0.00      0.0
# 2003         0  ...      139     0.60     0.02     0.01     0.01      0.0
# 2004         0  ...      255     1.00     0.00     1.00     0.00      0.0
# ...        ...  ...      ...      ...      ...      ...      ...      ...
# 35995        0  ...      255     1.00     0.00     1.00     0.00      0.0
# 35996        0  ...      255     1.00     0.00     1.00     0.00      0.0
# 35997        0  ...      255     1.00     0.00     1.00     0.00      0.0
# 35998        0  ...      255     1.00     0.00     0.01     0.02      0.0
# 35999        0  ...      255     1.00     0.00     1.00     0.00      0.0
#
#        atrib39  atrib40  atrib41  CLASS
# 2000       0.0     0.00     0.00      3
# 2001       0.0     0.00     0.00      3
# 2002       0.0     0.02     0.02      2
# 2003       0.0     0.01     0.04      2
# 2004       0.0     0.00     0.00      3
# ...        ...      ...      ...    ...
# 35995      0.0     0.00     0.00      3
# 35996      0.0     0.00     0.00      3
# 35997      0.0     0.00     0.00      3
# 35998      0.0     0.00     0.00      2
# 35999      0.0     0.00     0.00      3
#
# [34000 rows x 42 columns]

# %%
total = len(S1)
#ventana = 0
n_ventana = 0
Time_stamps = [ ]
cero = 0
columns = ['Clase correcta', 'Clasificado en', "Ventana", "GHOS", "STM", 'Acierto']
columns_stm = ['Clase correcta', 'Clasificado en', 'Ventana', "GHOS"]
col_clasif_stm = ['Clase_correcta', 'Clasificado en', 'GHOS', 'Acierto', 'Ventana']
index_no_emerging = []
col_no_emerging = ["Ventana", "Cluster STM", 'clase original', 'clase propuesta', 'error', 'instancias', 'T']
no_emerging = [] 
clases = []
clases_stm = []
clasif_right_stm = []
clasif_wrong_stm = []
index = []
index_stm= []
index_right_stm = []
index_wrong_stm = []
index_time = [] # Para dataframe de tiempo
clasificaciones = []
ghos_stm = []
accuracy_ventana = []
aciertos_clases =[]
aciertos_stm = 0
short_term_memory = pd.DataFrame()
short_classes = pd.DataFrame()
####### - - - - - - - - - - - 
# para medir el tiempo de STM (S) y de clasificación (C)
tiempos_c_s = []
col_time = ["Ventana", "tiempo tot [sec]", "t clasificacion",
"g_h_o_s", "Correct clas", "Incorrect class", "t mandar a stm", "time todo stm", "Frame stm",
"Clusters stm", "analysis stm", "update stm", "Analysis", 'STM', 'A0', 'A1', 'A2', 'A3', 
'A4', 'Calculo_Umbral', 'A6', 'A7', "Extension", "E0", "E1", "E2", "E3", "Umbral", "U0",
"U1", "U2", "U3", "U4"]


#While para recorrer todo el dataset
print("Así comienzan las clases y sus respectivos clusters.")
print(Cj)
print(num_cluster)

while S1.size != 0:
    for i in tqdm_notebook(range(0, math.ceil(total/paso))):
        clasificados = 0
        error = 0
        print("clasificados: " + str(clasificados))
        aciertos = 0
        window = S1[:paso] #window contiene las instancias de la ventana
        Time_stamps.append(window.index[-1])
        # Aquí las instancias se borran del dataset y se pasan a la ventana
        aux_index = window.index.tolist()
        S1 = S1.drop(aux_index)
        n_ventana = n_ventana + 1
        c_v_tot = [] # Es una lista vacía para almacenar cuantos patrones
        # y a qué clase pertenecen por ventana.  
        c_v_det = [] # Es una lista vacía que almacena los patrones y sus clases
        # que fueron clasificadas correctamente en la ventana.

        print("\n Longitud de ventana: " + str(len(window)))
        ventana_size = len(window)
        TimeInit = timer()

        while window.size != 0:
            # Start nos ayuda a medir el tiempo de inicio de la ventana
            start = timer()
            X_test = window.iloc[[0]].drop(['CLASS'], axis=1)
            y_test = window.iloc[[0]]['CLASS']
            c_v_tot.append(int(y_test)) # Aquí se van almacenando las clases que se presentan en la ventana
           # print(c_v_tot[-1])
            indice = X_test.index.tolist()[0]
            # print("indice" + str(indice))
            # Aquí la instancia a analizar se borra de la ventana
            aux_index = X_test.index.tolist()
            window = window.drop(aux_index)

            ###TIEMPO
            ################### FUNCION GHOS #########################################
            winning_class, winning_cluster, ghos = g_h_o_s(num_cluster, Cj, X_test, 'classification')
            ##########################################################################
            # Tiempo desde que inicia la clasificación
            start_clasif = timer()
            
            if opc_clasif == 1:            
                aciertos_clases, index, clases, aciertos, c_v_det, short_classes, \
                short_term_memory, index_stm, clases_stm, ghos_stm, clasificados = clasification_original(winning_class, \
                aciertos_clases, winning_cluster, y_test, X_test, index, indice,n_ventana, ghos, clases, \
                aciertos, c_v_det, short_classes, short_term_memory, index_stm, clases_stm, ghos_stm, clasificados)
        
                
            else: # Aqui la clasificación debe ser con un umbral de similitud (si se elige el número 2)
                # umbral = 36
                Umbral_similarity = 30 # round(attributes/len(Cj)) + 1
                # print("Umbral de similitud propuesto: " + str(Umbral_similarity))
                # si se cumple la siguiente condición entonces se clasifica
                if ghos >= Umbral_similarity:
                    ## Para calcular el accuracy se van acumulando las instancias que se clasifcaron bien o mal
                    clasificados = clasificados + 1
                    # print("clasificados " + str(clasificados))
                    ##    print("Se procede a clasificar")
                    # Se añade esa instancia al microcluster perteneciente
                    globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)] = pd.concat((globals()['MC_'+str(winning_class)+'_'+str(winning_cluster)], X_test), axis = 0)   
                    # Se actualizan las estadísticas
                    update_microcluster(winning_class, winning_cluster, X_test)
                    # Las siguientes 3 líneas son para llevar un registro de 
                    # instancia, clase correcta y cual clase fue asignada.
                    index.append(indice)
                    new_clases = {"Clase correcta": int(y_test), "Clasificado en": winning_class, "Ventana": n_ventana, "GHOS": ghos,"STM":'no', 'Acierto':'pasó el umbral'}
                    clases.append(new_clases)
                    c_v_det.append(int(y_test))
                    # ¿SE CLASIFICÓ DE MANERA CORRECTA?
                    if winning_class == int(y_test):
                        aciertos = aciertos + 1
                        
                        # print("aciertos: " + str(aciertos))
                        aciertos_clases.append(int(y_test))
                    else:
                        error = error + 1
                        print("ERROR en la instancia: " +str(indice))
                # Si no cumplió con la conición del umnbral entonces se manda la instancia al STM        
                else:
                    # Almacenar las clases correctas del short term memory
                    # La siguiente lpinea es cambiada de append por concat ya que append está obsoleto y será retirado en futuras versiones
                    # short_classes = short_classes.append(y_test.to_frame())
                    short_classes = pd.concat((short_classes, y_test.to_frame()), axis = 0)
                    # El short term memory
                    # La siguiente linea se cambia append por concate ya que apend en futuras versiones será removido.
                    # short_term_memory = short_term_memory.append(X_test)
                    short_term_memory = pd.concat((short_term_memory, X_test), axis = 0)
                    # Las siguientes 3 líneas son para llevar un registro de 
                    # instancia, clase correcta y cual clase fue asignada.
                    new_clases_stm = {"Clase correcta": int(y_test), "Clasificado en":'STM', 'Ventana': n_ventana,"GHOS": ghos}
                    index_stm.append(indice) #Indices de las instancias en el short term memory   
                    clases_stm.append(new_clases_stm)
                    # Guardar el GHOS de cada instancia en el stm
                    ghos_stm.append(ghos)


        # - - - - - 
        ti_stm = timer() # Tiempo inicial del análisis de la stm

        print("Patrones en STM: " + str(len(short_term_memory)))
        # Si cumple la condición, se analiza la STM
        if len(short_term_memory)>= n_elements_stm:
            # Me da las instancias mandadas al short term memory
            instancias_stm = pd.DataFrame(clases_stm, index_stm, columns_stm)   
           # Creación de los clusters en el stm
            Clusters, n_clusters_stm = clusters_stm(short_term_memory, mc_stm)          
            # - - - - - - ANÁLISIS DE LA SHORT TERM MEMORY - - - - - - - - - 
            # Las siguientes 5 líneas hacen referencia a la función que checa si el cluster
            # es o no válido. Si es válido, hace la asignación como extensión de la clase
            # o clase emergente.
            Cj, short_term_memory, num_cluster, ShortCluster,short_classes,\
            aciertos_stm,index_right_stm, clasif_right_stm,index_wrong_stm, \
            clasif_wrong_stm, an_tot_stm = analysis_stm(short_term_memory, short_classes, Clusters,\
            n_clusters_stm,Cj, clases_originales, num_cluster, aciertos_stm,index_right_stm, clasif_right_stm,\
            index_wrong_stm,clasif_wrong_stm, instancias_stm, n_ventana)
            #- - - - - - - - - - - ACTUALIZACIÓN DE LA SHORT TERM MEMORY - - - - - - - - - -
            short_term_memory, short_classes = update_t_s(short_term_memory, short_classes,\
            Time_stamps, ventana_de_olvido)
            # Se eliminan los clusteres que se realizaron en este análisis de la STM
            del Clusters
#- - - - - - - - - - - - ACCURACY - - - - - - - - - - - - - - - - 
        if opc_clasif == 1:
            accuracy_ventana.append([(aciertos/ventana_size)*100])
        else:
            print("Se calculará este accuracy como en MINAS")
            print("aciertos: " + str(aciertos) + ", clasificados: " + str(clasificados))
            accuracy_ventana.append([(aciertos/clasificados)*100])

        # --- CALCULOS DE TIEMPO ----
        TimeFin = timer()
        ElapseTime = TimeFin - TimeInit #Tiempo 
        print("Tiempo transcurrido: " + str(ElapseTime/60))

        # Clases e instancias TOTALES por ventana
        c_v_tot = clases_en_ventana(c_v_tot)
        c_v_det = clases_en_ventana(c_v_det)
        # Clusteres de cada clase por ventana
        cluster_ventana = clusters_en_ventana(Cj, num_cluster)
        # Las siguientes líneas son para crear un datarfame donde se almacenen los tiempos por ventana
        clasificacion = {"Ventana": n_ventana, 'TS': Time_stamps[-1], "Accuracy": \
        accuracy_ventana[-1][0], "Tiempo transcurrido [sec]": ElapseTime} 
        for clase in range(len(C_tot)):
            aux_clasificacion = {"Instancias presentadas clase_" + str(C_tot[clase]): c_v_tot['clase_' + str(C_tot[clase])] 
            if c_v_tot.get('clase_' + str(C_tot[clase])) else cero,\
            "Clasificadas en clase_" + str(C_tot[clase]): c_v_det['clase_' + str(C_tot[clase])]\
            if c_v_det.get('clase_' + str(C_tot[clase])) else cero,\
            "Numero de clusters en clase_" + str(C_tot[clase]):cluster_ventana['cluster_clase_' + str(C_tot[clase])] 
            if cluster_ventana.get('cluster_clase_' + str(C_tot[clase])) else cero}
            clasificacion = {**clasificacion, **aux_clasificacion}

        index_time.append(n_ventana) #
        clasificaciones.append(clasificacion)
        
        print("Así quedan las clases y sus respectivos clusters.")
        print(Cj)
        print(num_cluster)
        # print(aciertos_ventana)    
        print("Finalizó la ventana: " + str(n_ventana) + " TimeStamp: " +  str(Time_stamps[-1]) + " t: " + str(ElapseTime) + "[sec]" + ' accuracy ' + str(accuracy_ventana[-1][0]))
        print(" - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
    time.sleep(0.1)
# Out:
# Así comienzan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
#   0%|          | 0/17 [00:00<?, ?it/s]
# clasificados: 0
#
#  Longitud de ventana: 2000
# Patrones en STM: 0
# Se calculará este accuracy como en MINAS
# aciertos: 2000, clasificados: 2000
# Tiempo transcurrido: 1.0212572149999999
# Así quedan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
# Finalizó la ventana: 1 TimeStamp: 3999 t: 61.2754329[sec] accuracy 100.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# clasificados: 0
#
#  Longitud de ventana: 2000
# ERROR en la instancia: 4014
# ERROR en la instancia: 4019
# ERROR en la instancia: 4025
# ERROR en la instancia: 4045
# ERROR en la instancia: 4058
# ERROR en la instancia: 4089
# ERROR en la instancia: 4143
# ERROR en la instancia: 4161
# ERROR en la instancia: 4216
# ERROR en la instancia: 4224
# ERROR en la instancia: 4233
# ERROR en la instancia: 4241
# ERROR en la instancia: 4266
# ERROR en la instancia: 4319
# ERROR en la instancia: 4349
# ERROR en la instancia: 4432
# ERROR en la instancia: 4441
# ERROR en la instancia: 4443
# ERROR en la instancia: 4462
# ERROR en la instancia: 4481
# ERROR en la instancia: 4545
# ERROR en la instancia: 4644
# ERROR en la instancia: 4662
# ERROR en la instancia: 4669
# ERROR en la instancia: 4673
# ERROR en la instancia: 4687
# ERROR en la instancia: 4723
# ERROR en la instancia: 4739
# ERROR en la instancia: 4766
# ERROR en la instancia: 4795
# ERROR en la instancia: 4802
# ERROR en la instancia: 4819
# ERROR en la instancia: 4820
# ERROR en la instancia: 4828
# ERROR en la instancia: 4841
# ERROR en la instancia: 4859
# ERROR en la instancia: 4879
# ERROR en la instancia: 4898
# ERROR en la instancia: 4900
# ERROR en la instancia: 4916
# ERROR en la instancia: 4923
# ERROR en la instancia: 4933
# ERROR en la instancia: 4954
# ERROR en la instancia: 4958
# ERROR en la instancia: 4962
# ERROR en la instancia: 4969
# ERROR en la instancia: 4981
# ERROR en la instancia: 4989
# ERROR en la instancia: 5001
# ERROR en la instancia: 5007
# ERROR en la instancia: 5031
# ERROR en la instancia: 5065
# ERROR en la instancia: 5087
# ERROR en la instancia: 5096
# ERROR en la instancia: 5097
# ERROR en la instancia: 5115
# ERROR en la instancia: 5130
# ERROR en la instancia: 5142
# ERROR en la instancia: 5175
# ERROR en la instancia: 5180
# ERROR en la instancia: 5191
# ERROR en la instancia: 5201
# ERROR en la instancia: 5212
# ERROR en la instancia: 5219
# ERROR en la instancia: 5222
# ERROR en la instancia: 5227
# ERROR en la instancia: 5246
# ERROR en la instancia: 5254
# ERROR en la instancia: 5260
# ERROR en la instancia: 5261
# ERROR en la instancia: 5265
# ERROR en la instancia: 5294
# ERROR en la instancia: 5304
# ERROR en la instancia: 5324
# ERROR en la instancia: 5334
# ERROR en la instancia: 5345
# ERROR en la instancia: 5351
# ERROR en la instancia: 5376
# ERROR en la instancia: 5381
# ERROR en la instancia: 5388
# ERROR en la instancia: 5402
# ERROR en la instancia: 5404
# ERROR en la instancia: 5419
# ERROR en la instancia: 5424
# ERROR en la instancia: 5431
# ERROR en la instancia: 5448
# ERROR en la instancia: 5449
# ERROR en la instancia: 5453
# ERROR en la instancia: 5461
# ERROR en la instancia: 5463
# ERROR en la instancia: 5471
# ERROR en la instancia: 5476
# ERROR en la instancia: 5484
# ERROR en la instancia: 5498
# ERROR en la instancia: 5504
# ERROR en la instancia: 5534
# ERROR en la instancia: 5546
# ERROR en la instancia: 5555
# ERROR en la instancia: 5559
# ERROR en la instancia: 5564
# ERROR en la instancia: 5571
# ERROR en la instancia: 5582
# ERROR en la instancia: 5597
# ERROR en la instancia: 5609
# ERROR en la instancia: 5627
# ERROR en la instancia: 5631
# ERROR en la instancia: 5636
# ERROR en la instancia: 5641
# ERROR en la instancia: 5659
# ERROR en la instancia: 5663
# ERROR en la instancia: 5667
# ERROR en la instancia: 5669
# ERROR en la instancia: 5679
# ERROR en la instancia: 5684
# ERROR en la instancia: 5692
# ERROR en la instancia: 5693
# ERROR en la instancia: 5720
# ERROR en la instancia: 5738
# ERROR en la instancia: 5744
# ERROR en la instancia: 5762
# ERROR en la instancia: 5763
# ERROR en la instancia: 5764
# ERROR en la instancia: 5767
# ERROR en la instancia: 5776
# ERROR en la instancia: 5812
# ERROR en la instancia: 5815
# ERROR en la instancia: 5821
# ERROR en la instancia: 5838
# ERROR en la instancia: 5841
# ERROR en la instancia: 5850
# ERROR en la instancia: 5861
# ERROR en la instancia: 5867
# ERROR en la instancia: 5878
# ERROR en la instancia: 5889
# ERROR en la instancia: 5908
# ERROR en la instancia: 5925
# ERROR en la instancia: 5938
# ERROR en la instancia: 5939
# ERROR en la instancia: 5947
# ERROR en la instancia: 5952
# ERROR en la instancia: 5964
# ERROR en la instancia: 5968
# ERROR en la instancia: 5977
# ERROR en la instancia: 5982
# ERROR en la instancia: 5983
# ERROR en la instancia: 5984
# ERROR en la instancia: 5988
# ERROR en la instancia: 5990
# Patrones en STM: 322
# Analysis
# Se calculará este accuracy como en MINAS
# aciertos: 1530, clasificados: 1678
# Tiempo transcurrido: 1.0311745700000001
# Así quedan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
# Finalizó la ventana: 2 TimeStamp: 5999 t: 61.870474200000004[sec] accuracy 91.17997616209773
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# clasificados: 0
#
#  Longitud de ventana: 2000
# ERROR en la instancia: 6016
# ERROR en la instancia: 6018
# ERROR en la instancia: 6028
# ERROR en la instancia: 6033
# ERROR en la instancia: 6037
# ERROR en la instancia: 6046
# ERROR en la instancia: 6050
# ERROR en la instancia: 6060
# ERROR en la instancia: 6071
# ERROR en la instancia: 6072
# ERROR en la instancia: 6075
# ERROR en la instancia: 6079
# ERROR en la instancia: 6081
# ERROR en la instancia: 6086
# ERROR en la instancia: 6093
# ERROR en la instancia: 6095
# ERROR en la instancia: 6097
# ERROR en la instancia: 6104
# ERROR en la instancia: 6115
# ERROR en la instancia: 6142
# ERROR en la instancia: 6144
# ERROR en la instancia: 6155
# ERROR en la instancia: 6160
# ERROR en la instancia: 6161
# ERROR en la instancia: 6169
# ERROR en la instancia: 6172
# ERROR en la instancia: 6181
# ERROR en la instancia: 6192
# ERROR en la instancia: 6201
# ERROR en la instancia: 6207
# ERROR en la instancia: 6208
# ERROR en la instancia: 6215
# ERROR en la instancia: 6220
# ERROR en la instancia: 6226
# ERROR en la instancia: 6227
# ERROR en la instancia: 6238
# ERROR en la instancia: 6239
# ERROR en la instancia: 6241
# ERROR en la instancia: 6251
# ERROR en la instancia: 6258
# ERROR en la instancia: 6259
# ERROR en la instancia: 6264
# ERROR en la instancia: 6277
# ERROR en la instancia: 6280
# ERROR en la instancia: 6290
# ERROR en la instancia: 6293
# ERROR en la instancia: 6301
# ERROR en la instancia: 6310
# ERROR en la instancia: 6312
# ERROR en la instancia: 6315
# ERROR en la instancia: 6321
# ERROR en la instancia: 6323
# ERROR en la instancia: 6327
# ERROR en la instancia: 6332
# ERROR en la instancia: 6338
# ERROR en la instancia: 6345
# ERROR en la instancia: 6346
# ERROR en la instancia: 6357
# ERROR en la instancia: 6359
# ERROR en la instancia: 6363
# ERROR en la instancia: 6367
# ERROR en la instancia: 6368
# ERROR en la instancia: 6374
# ERROR en la instancia: 6376
# ERROR en la instancia: 6379
# ERROR en la instancia: 6390
# ERROR en la instancia: 6391
# ERROR en la instancia: 6404
# ERROR en la instancia: 6407
# ERROR en la instancia: 6409
# ERROR en la instancia: 6411
# ERROR en la instancia: 6412
# ERROR en la instancia: 6413
# ERROR en la instancia: 6414
# ERROR en la instancia: 6418
# ERROR en la instancia: 6422
# ERROR en la instancia: 6424
# ERROR en la instancia: 6427
# ERROR en la instancia: 6428
# ERROR en la instancia: 6433
# ERROR en la instancia: 6441
# ERROR en la instancia: 6442
# ERROR en la instancia: 6443
# ERROR en la instancia: 6450
# ERROR en la instancia: 6453
# ERROR en la instancia: 6462
# ERROR en la instancia: 6467
# ERROR en la instancia: 6476
# ERROR en la instancia: 6479
# ERROR en la instancia: 6480
# ERROR en la instancia: 6488
# ERROR en la instancia: 6495
# ERROR en la instancia: 6499
# ERROR en la instancia: 6500
# ERROR en la instancia: 6503
# ERROR en la instancia: 6505
# ERROR en la instancia: 6508
# ERROR en la instancia: 6523
# ERROR en la instancia: 6524
# ERROR en la instancia: 6546
# ERROR en la instancia: 6555
# ERROR en la instancia: 6559
# ERROR en la instancia: 6561
# ERROR en la instancia: 6565
# ERROR en la instancia: 6567
# ERROR en la instancia: 6571
# ERROR en la instancia: 6586
# ERROR en la instancia: 6590
# ERROR en la instancia: 6593
# ERROR en la instancia: 6594
# ERROR en la instancia: 6598
# ERROR en la instancia: 6622
# ERROR en la instancia: 6628
# ERROR en la instancia: 6629
# ERROR en la instancia: 6631
# ERROR en la instancia: 6643
# ERROR en la instancia: 6647
# ERROR en la instancia: 6649
# ERROR en la instancia: 6654
# ERROR en la instancia: 6658
# ERROR en la instancia: 6659
# ERROR en la instancia: 6664
# ERROR en la instancia: 6665
# ERROR en la instancia: 6670
# ERROR en la instancia: 6675
# ERROR en la instancia: 6682
# ERROR en la instancia: 6690
# ERROR en la instancia: 6694
# ERROR en la instancia: 6697
# ERROR en la instancia: 6700
# ERROR en la instancia: 6707
# ERROR en la instancia: 6713
# ERROR en la instancia: 6714
# ERROR en la instancia: 6715
# ERROR en la instancia: 6721
# ERROR en la instancia: 6726
# ERROR en la instancia: 6733
# ERROR en la instancia: 6737
# ERROR en la instancia: 6743
# ERROR en la instancia: 6746
# ERROR en la instancia: 6748
# ERROR en la instancia: 6749
# ERROR en la instancia: 6754
# ERROR en la instancia: 6764
# ERROR en la instancia: 6765
# ERROR en la instancia: 6768
# ERROR en la instancia: 6772
# ERROR en la instancia: 6773
# ERROR en la instancia: 6780
# ERROR en la instancia: 6785
# ERROR en la instancia: 6790
# ERROR en la instancia: 6793
# ERROR en la instancia: 6802
# ERROR en la instancia: 6803
# ERROR en la instancia: 6812
# ERROR en la instancia: 6822
# ERROR en la instancia: 6835
# ERROR en la instancia: 6841
# ERROR en la instancia: 6842
# ERROR en la instancia: 6856
# ERROR en la instancia: 6859
# ERROR en la instancia: 6860
# ERROR en la instancia: 6866
# ERROR en la instancia: 6870
# ERROR en la instancia: 6872
# ERROR en la instancia: 6876
# ERROR en la instancia: 6879
# ERROR en la instancia: 6881
# ERROR en la instancia: 6888
# ERROR en la instancia: 6890
# ERROR en la instancia: 6910
# ERROR en la instancia: 6911
# ERROR en la instancia: 6917
# ERROR en la instancia: 6920
# ERROR en la instancia: 6921
# ERROR en la instancia: 6926
# ERROR en la instancia: 6928
# ERROR en la instancia: 6931
# ERROR en la instancia: 6935
# ERROR en la instancia: 6936
# ERROR en la instancia: 6939
# ERROR en la instancia: 6941
# ERROR en la instancia: 6943
# ERROR en la instancia: 6945
# ERROR en la instancia: 6949
# ERROR en la instancia: 6961
# ERROR en la instancia: 6964
# ERROR en la instancia: 6967
# ERROR en la instancia: 6971
# ERROR en la instancia: 6982
# ERROR en la instancia: 6983
# ERROR en la instancia: 6986
# ERROR en la instancia: 6988
# ERROR en la instancia: 7007
# ERROR en la instancia: 7009
# ERROR en la instancia: 7013
# ERROR en la instancia: 7016
# ERROR en la instancia: 7019
# ERROR en la instancia: 7021
# ERROR en la instancia: 7037
# ERROR en la instancia: 7038
# ERROR en la instancia: 7040
# ERROR en la instancia: 7046
# ERROR en la instancia: 7048
# ERROR en la instancia: 7058
# ERROR en la instancia: 7061
# ERROR en la instancia: 7070
# ERROR en la instancia: 7077
# ERROR en la instancia: 7080
# ERROR en la instancia: 7087
# ERROR en la instancia: 7088
# ERROR en la instancia: 7089
# ERROR en la instancia: 7093
# ERROR en la instancia: 7098
# ERROR en la instancia: 7100
# ERROR en la instancia: 7101
# ERROR en la instancia: 7105
# ERROR en la instancia: 7111
# ERROR en la instancia: 7113
# ERROR en la instancia: 7120
# ERROR en la instancia: 7121
# ERROR en la instancia: 7124
# ERROR en la instancia: 7126
# ERROR en la instancia: 7134
# ERROR en la instancia: 7139
# ERROR en la instancia: 7144
# ERROR en la instancia: 7146
# ERROR en la instancia: 7147
# ERROR en la instancia: 7148
# ERROR en la instancia: 7154
# ERROR en la instancia: 7156
# ERROR en la instancia: 7160
# ERROR en la instancia: 7165
# ERROR en la instancia: 7169
# ERROR en la instancia: 7170
# ERROR en la instancia: 7172
# ERROR en la instancia: 7173
# ERROR en la instancia: 7174
# ERROR en la instancia: 7180
# ERROR en la instancia: 7181
# ERROR en la instancia: 7188
# ERROR en la instancia: 7191
# ERROR en la instancia: 7193
# ERROR en la instancia: 7198
# ERROR en la instancia: 7214
# ERROR en la instancia: 7217
# ERROR en la instancia: 7232
# ERROR en la instancia: 7234
# ERROR en la instancia: 7237
# ERROR en la instancia: 7238
# ERROR en la instancia: 7242
# ERROR en la instancia: 7251
# ERROR en la instancia: 7253
# ERROR en la instancia: 7255
# ERROR en la instancia: 7256
# ERROR en la instancia: 7257
# ERROR en la instancia: 7263
# ERROR en la instancia: 7270
# ERROR en la instancia: 7274
# ERROR en la instancia: 7277
# ERROR en la instancia: 7280
# ERROR en la instancia: 7282
# ERROR en la instancia: 7290
# ERROR en la instancia: 7291
# ERROR en la instancia: 7297
# ERROR en la instancia: 7298
# ERROR en la instancia: 7300
# ERROR en la instancia: 7301
# ERROR en la instancia: 7303
# ERROR en la instancia: 7305
# ERROR en la instancia: 7309
# ERROR en la instancia: 7311
# ERROR en la instancia: 7314
# ERROR en la instancia: 7315
# ERROR en la instancia: 7319
# ERROR en la instancia: 7324
# ERROR en la instancia: 7329
# ERROR en la instancia: 7332
# ERROR en la instancia: 7346
# ERROR en la instancia: 7351
# ERROR en la instancia: 7368
# ERROR en la instancia: 7378
# ERROR en la instancia: 7380
# ERROR en la instancia: 7382
# ERROR en la instancia: 7391
# ERROR en la instancia: 7395
# ERROR en la instancia: 7396
# ERROR en la instancia: 7399
# ERROR en la instancia: 7401
# ERROR en la instancia: 7403
# ERROR en la instancia: 7408
# ERROR en la instancia: 7411
# ERROR en la instancia: 7413
# ERROR en la instancia: 7418
# ERROR en la instancia: 7421
# ERROR en la instancia: 7422
# ERROR en la instancia: 7426
# ERROR en la instancia: 7427
# ERROR en la instancia: 7431
# ERROR en la instancia: 7432
# ERROR en la instancia: 7434
# ERROR en la instancia: 7442
# ERROR en la instancia: 7443
# ERROR en la instancia: 7458
# ERROR en la instancia: 7463
# ERROR en la instancia: 7467
# ERROR en la instancia: 7468
# ERROR en la instancia: 7469
# ERROR en la instancia: 7476
# ERROR en la instancia: 7483
# ERROR en la instancia: 7485
# ERROR en la instancia: 7488
# ERROR en la instancia: 7493
# ERROR en la instancia: 7497
# ERROR en la instancia: 7498
# ERROR en la instancia: 7499
# ERROR en la instancia: 7510
# ERROR en la instancia: 7515
# ERROR en la instancia: 7525
# ERROR en la instancia: 7527
# ERROR en la instancia: 7535
# ERROR en la instancia: 7541
# ERROR en la instancia: 7544
# ERROR en la instancia: 7551
# ERROR en la instancia: 7553
# ERROR en la instancia: 7555
# ERROR en la instancia: 7560
# ERROR en la instancia: 7569
# ERROR en la instancia: 7573
# ERROR en la instancia: 7575
# ERROR en la instancia: 7579
# ERROR en la instancia: 7588
# ERROR en la instancia: 7606
# ERROR en la instancia: 7607
# ERROR en la instancia: 7608
# ERROR en la instancia: 7611
# ERROR en la instancia: 7621
# ERROR en la instancia: 7624
# ERROR en la instancia: 7625
# ERROR en la instancia: 7629
# ERROR en la instancia: 7632
# ERROR en la instancia: 7636
# ERROR en la instancia: 7638
# ERROR en la instancia: 7640
# ERROR en la instancia: 7643
# ERROR en la instancia: 7655
# ERROR en la instancia: 7656
# ERROR en la instancia: 7662
# ERROR en la instancia: 7663
# ERROR en la instancia: 7664
# ERROR en la instancia: 7671
# ERROR en la instancia: 7675
# ERROR en la instancia: 7677
# ERROR en la instancia: 7681
# ERROR en la instancia: 7684
# ERROR en la instancia: 7686
# ERROR en la instancia: 7688
# ERROR en la instancia: 7689
# ERROR en la instancia: 7694
# ERROR en la instancia: 7703
# ERROR en la instancia: 7708
# ERROR en la instancia: 7711
# ERROR en la instancia: 7712
# ERROR en la instancia: 7714
# ERROR en la instancia: 7724
# ERROR en la instancia: 7725
# ERROR en la instancia: 7754
# ERROR en la instancia: 7758
# ERROR en la instancia: 7761
# ERROR en la instancia: 7763
# ERROR en la instancia: 7765
# ERROR en la instancia: 7770
# ERROR en la instancia: 7774
# ERROR en la instancia: 7778
# ERROR en la instancia: 7783
# ERROR en la instancia: 7785
# ERROR en la instancia: 7786
# ERROR en la instancia: 7787
# ERROR en la instancia: 7790
# ERROR en la instancia: 7793
# ERROR en la instancia: 7796
# ERROR en la instancia: 7801
# ERROR en la instancia: 7802
# ERROR en la instancia: 7807
# ERROR en la instancia: 7808
# ERROR en la instancia: 7816
# ERROR en la instancia: 7820
# ERROR en la instancia: 7821
# ERROR en la instancia: 7822
# ERROR en la instancia: 7823
# ERROR en la instancia: 7824
# ERROR en la instancia: 7826
# ERROR en la instancia: 7831
# ERROR en la instancia: 7841
# ERROR en la instancia: 7842
# ERROR en la instancia: 7850
# ERROR en la instancia: 7854
# ERROR en la instancia: 7864
# ERROR en la instancia: 7866
# ERROR en la instancia: 7871
# ERROR en la instancia: 7873
# ERROR en la instancia: 7875
# ERROR en la instancia: 7883
# ERROR en la instancia: 7887
# ERROR en la instancia: 7888
# ERROR en la instancia: 7889
# ERROR en la instancia: 7898
# ERROR en la instancia: 7901
# ERROR en la instancia: 7904
# ERROR en la instancia: 7907
# ERROR en la instancia: 7908
# ERROR en la instancia: 7931
# ERROR en la instancia: 7933
# ERROR en la instancia: 7952
# ERROR en la instancia: 7957
# ERROR en la instancia: 7959
# ERROR en la instancia: 7966
# ERROR en la instancia: 7968
# ERROR en la instancia: 7985
# ERROR en la instancia: 7986
# ERROR en la instancia: 7989
# ERROR en la instancia: 7990
# ERROR en la instancia: 7996
# ERROR en la instancia: 7998
# Patrones en STM: 33
# Se calculará este accuracy como en MINAS
# aciertos: 1561, clasificados: 1985
# Tiempo transcurrido: 1.0596799333333338
# Así quedan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
# Finalizó la ventana: 3 TimeStamp: 7999 t: 63.58079600000002[sec] accuracy 78.639798488665
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# clasificados: 0
#
#  Longitud de ventana: 2000
# ERROR en la instancia: 8008
# ERROR en la instancia: 8014
# ERROR en la instancia: 8015
# ERROR en la instancia: 8016
# ERROR en la instancia: 8019
# ERROR en la instancia: 8023
# ERROR en la instancia: 8026
# ERROR en la instancia: 8027
# ERROR en la instancia: 8029
# ERROR en la instancia: 8031
# ERROR en la instancia: 8037
# ERROR en la instancia: 8042
# ERROR en la instancia: 8046
# ERROR en la instancia: 8052
# ERROR en la instancia: 8056
# ERROR en la instancia: 8057
# ERROR en la instancia: 8063
# ERROR en la instancia: 8065
# ERROR en la instancia: 8066
# ERROR en la instancia: 8072
# ERROR en la instancia: 8074
# ERROR en la instancia: 8077
# ERROR en la instancia: 8079
# ERROR en la instancia: 8083
# ERROR en la instancia: 8085
# ERROR en la instancia: 8092
# ERROR en la instancia: 8096
# ERROR en la instancia: 8099
# ERROR en la instancia: 8101
# ERROR en la instancia: 8106
# ERROR en la instancia: 8118
# ERROR en la instancia: 8120
# ERROR en la instancia: 8122
# ERROR en la instancia: 8123
# ERROR en la instancia: 8125
# ERROR en la instancia: 8127
# ERROR en la instancia: 8130
# ERROR en la instancia: 8137
# ERROR en la instancia: 8140
# ERROR en la instancia: 8141
# ERROR en la instancia: 8143
# ERROR en la instancia: 8153
# ERROR en la instancia: 8158
# ERROR en la instancia: 8161
# ERROR en la instancia: 8164
# ERROR en la instancia: 8171
# ERROR en la instancia: 8176
# ERROR en la instancia: 8179
# ERROR en la instancia: 8183
# ERROR en la instancia: 8185
# ERROR en la instancia: 8194
# ERROR en la instancia: 8199
# ERROR en la instancia: 8219
# ERROR en la instancia: 8220
# ERROR en la instancia: 8226
# ERROR en la instancia: 8234
# ERROR en la instancia: 8235
# ERROR en la instancia: 8247
# ERROR en la instancia: 8248
# ERROR en la instancia: 8250
# ERROR en la instancia: 8260
# ERROR en la instancia: 8261
# ERROR en la instancia: 8264
# ERROR en la instancia: 8265
# ERROR en la instancia: 8266
# ERROR en la instancia: 8267
# ERROR en la instancia: 8270
# ERROR en la instancia: 8288
# ERROR en la instancia: 8295
# ERROR en la instancia: 8301
# ERROR en la instancia: 8302
# ERROR en la instancia: 8308
# ERROR en la instancia: 8310
# ERROR en la instancia: 8313
# ERROR en la instancia: 8315
# ERROR en la instancia: 8317
# ERROR en la instancia: 8320
# ERROR en la instancia: 8321
# ERROR en la instancia: 8328
# ERROR en la instancia: 8333
# ERROR en la instancia: 8337
# ERROR en la instancia: 8348
# ERROR en la instancia: 8351
# ERROR en la instancia: 8356
# ERROR en la instancia: 8359
# ERROR en la instancia: 8360
# ERROR en la instancia: 8365
# ERROR en la instancia: 8367
# ERROR en la instancia: 8374
# ERROR en la instancia: 8381
# ERROR en la instancia: 8386
# ERROR en la instancia: 8390
# ERROR en la instancia: 8395
# ERROR en la instancia: 8398
# ERROR en la instancia: 8408
# ERROR en la instancia: 8415
# ERROR en la instancia: 8416
# ERROR en la instancia: 8420
# ERROR en la instancia: 8426
# ERROR en la instancia: 8428
# ERROR en la instancia: 8433
# ERROR en la instancia: 8445
# ERROR en la instancia: 8451
# ERROR en la instancia: 8459
# ERROR en la instancia: 8461
# ERROR en la instancia: 8468
# ERROR en la instancia: 8473
# ERROR en la instancia: 8480
# ERROR en la instancia: 8485
# ERROR en la instancia: 8486
# ERROR en la instancia: 8489
# ERROR en la instancia: 8493
# ERROR en la instancia: 8494
# ERROR en la instancia: 8496
# ERROR en la instancia: 8500
# ERROR en la instancia: 8501
# ERROR en la instancia: 8503
# ERROR en la instancia: 8508
# ERROR en la instancia: 8509
# ERROR en la instancia: 8512
# ERROR en la instancia: 8513
# ERROR en la instancia: 8516
# ERROR en la instancia: 8518
# ERROR en la instancia: 8523
# ERROR en la instancia: 8527
# ERROR en la instancia: 8529
# ERROR en la instancia: 8534
# ERROR en la instancia: 8535
# ERROR en la instancia: 8536
# ERROR en la instancia: 8537
# ERROR en la instancia: 8538
# ERROR en la instancia: 8543
# ERROR en la instancia: 8550
# ERROR en la instancia: 8554
# ERROR en la instancia: 8561
# ERROR en la instancia: 8562
# ERROR en la instancia: 8567
# ERROR en la instancia: 8571
# ERROR en la instancia: 8574
# ERROR en la instancia: 8578
# ERROR en la instancia: 8580
# ERROR en la instancia: 8591
# ERROR en la instancia: 8596
# ERROR en la instancia: 8597
# ERROR en la instancia: 8603
# ERROR en la instancia: 8604
# ERROR en la instancia: 8607
# ERROR en la instancia: 8611
# ERROR en la instancia: 8613
# ERROR en la instancia: 8618
# ERROR en la instancia: 8623
# ERROR en la instancia: 8627
# ERROR en la instancia: 8633
# ERROR en la instancia: 8635
# ERROR en la instancia: 8658
# ERROR en la instancia: 8659
# ERROR en la instancia: 8660
# ERROR en la instancia: 8661
# ERROR en la instancia: 8665
# ERROR en la instancia: 8666
# ERROR en la instancia: 8667
# ERROR en la instancia: 8670
# ERROR en la instancia: 8671
# ERROR en la instancia: 8672
# ERROR en la instancia: 8673
# ERROR en la instancia: 8686
# ERROR en la instancia: 8690
# ERROR en la instancia: 8693
# ERROR en la instancia: 8695
# ERROR en la instancia: 8698
# ERROR en la instancia: 8700
# ERROR en la instancia: 8715
# ERROR en la instancia: 8718
# ERROR en la instancia: 8720
# ERROR en la instancia: 8722
# ERROR en la instancia: 8725
# ERROR en la instancia: 8726
# ERROR en la instancia: 8738
# ERROR en la instancia: 8739
# ERROR en la instancia: 8750
# ERROR en la instancia: 8752
# ERROR en la instancia: 8753
# ERROR en la instancia: 8757
# ERROR en la instancia: 8761
# ERROR en la instancia: 8762
# ERROR en la instancia: 8766
# ERROR en la instancia: 8772
# ERROR en la instancia: 8774
# ERROR en la instancia: 8777
# ERROR en la instancia: 8782
# ERROR en la instancia: 8788
# ERROR en la instancia: 8792
# ERROR en la instancia: 8794
# ERROR en la instancia: 8797
# ERROR en la instancia: 8798
# ERROR en la instancia: 8799
# ERROR en la instancia: 8801
# ERROR en la instancia: 8809
# ERROR en la instancia: 8815
# ERROR en la instancia: 8818
# ERROR en la instancia: 8822
# ERROR en la instancia: 8823
# ERROR en la instancia: 8827
# ERROR en la instancia: 8830
# ERROR en la instancia: 8832
# ERROR en la instancia: 8836
# ERROR en la instancia: 8839
# ERROR en la instancia: 8841
# ERROR en la instancia: 8845
# ERROR en la instancia: 8846
# ERROR en la instancia: 8850
# ERROR en la instancia: 8851
# ERROR en la instancia: 8853
# ERROR en la instancia: 8856
# ERROR en la instancia: 8861
# ERROR en la instancia: 8863
# ERROR en la instancia: 8864
# ERROR en la instancia: 8866
# ERROR en la instancia: 8878
# ERROR en la instancia: 8881
# ERROR en la instancia: 8885
# ERROR en la instancia: 8892
# ERROR en la instancia: 8893
# ERROR en la instancia: 8909
# ERROR en la instancia: 8918
# ERROR en la instancia: 8920
# ERROR en la instancia: 8932
# ERROR en la instancia: 8941
# ERROR en la instancia: 8943
# ERROR en la instancia: 8952
# ERROR en la instancia: 8954
# ERROR en la instancia: 8956
# ERROR en la instancia: 8957
# ERROR en la instancia: 8969
# ERROR en la instancia: 8988
# ERROR en la instancia: 8990
# ERROR en la instancia: 9000
# ERROR en la instancia: 9008
# ERROR en la instancia: 9019
# ERROR en la instancia: 9020
# ERROR en la instancia: 9025
# ERROR en la instancia: 9027
# ERROR en la instancia: 9029
# ERROR en la instancia: 9035
# ERROR en la instancia: 9036
# ERROR en la instancia: 9037
# ERROR en la instancia: 9043
# ERROR en la instancia: 9048
# ERROR en la instancia: 9052
# ERROR en la instancia: 9066
# ERROR en la instancia: 9077
# ERROR en la instancia: 9090
# ERROR en la instancia: 9091
# ERROR en la instancia: 9094
# ERROR en la instancia: 9107
# ERROR en la instancia: 9108
# ERROR en la instancia: 9114
# ERROR en la instancia: 9121
# ERROR en la instancia: 9122
# ERROR en la instancia: 9127
# ERROR en la instancia: 9133
# ERROR en la instancia: 9136
# ERROR en la instancia: 9137
# ERROR en la instancia: 9138
# ERROR en la instancia: 9145
# ERROR en la instancia: 9148
# ERROR en la instancia: 9149
# ERROR en la instancia: 9153
# ERROR en la instancia: 9156
# ERROR en la instancia: 9160
# ERROR en la instancia: 9162
# ERROR en la instancia: 9166
# ERROR en la instancia: 9167
# ERROR en la instancia: 9171
# ERROR en la instancia: 9174
# ERROR en la instancia: 9187
# ERROR en la instancia: 9194
# ERROR en la instancia: 9195
# ERROR en la instancia: 9197
# ERROR en la instancia: 9199
# ERROR en la instancia: 9202
# ERROR en la instancia: 9210
# ERROR en la instancia: 9213
# ERROR en la instancia: 9214
# ERROR en la instancia: 9218
# ERROR en la instancia: 9229
# ERROR en la instancia: 9231
# ERROR en la instancia: 9243
# ERROR en la instancia: 9249
# ERROR en la instancia: 9252
# ERROR en la instancia: 9253
# ERROR en la instancia: 9272
# ERROR en la instancia: 9275
# ERROR en la instancia: 9276
# ERROR en la instancia: 9277
# ERROR en la instancia: 9283
# ERROR en la instancia: 9286
# ERROR en la instancia: 9291
# ERROR en la instancia: 9295
# ERROR en la instancia: 9301
# ERROR en la instancia: 9306
# ERROR en la instancia: 9307
# ERROR en la instancia: 9309
# ERROR en la instancia: 9315
# ERROR en la instancia: 9325
# ERROR en la instancia: 9328
# ERROR en la instancia: 9331
# ERROR en la instancia: 9333
# ERROR en la instancia: 9335
# ERROR en la instancia: 9341
# ERROR en la instancia: 9355
# ERROR en la instancia: 9358
# ERROR en la instancia: 9360
# ERROR en la instancia: 9365
# ERROR en la instancia: 9372
# ERROR en la instancia: 9374
# ERROR en la instancia: 9377
# ERROR en la instancia: 9378
# ERROR en la instancia: 9387
# ERROR en la instancia: 9394
# ERROR en la instancia: 9399
# ERROR en la instancia: 9401
# ERROR en la instancia: 9403
# ERROR en la instancia: 9405
# ERROR en la instancia: 9409
# ERROR en la instancia: 9410
# ERROR en la instancia: 9414
# ERROR en la instancia: 9424
# ERROR en la instancia: 9427
# ERROR en la instancia: 9429
# ERROR en la instancia: 9436
# ERROR en la instancia: 9452
# ERROR en la instancia: 9460
# ERROR en la instancia: 9462
# ERROR en la instancia: 9469
# ERROR en la instancia: 9475
# ERROR en la instancia: 9482
# ERROR en la instancia: 9486
# ERROR en la instancia: 9496
# ERROR en la instancia: 9507
# ERROR en la instancia: 9508
# ERROR en la instancia: 9509
# ERROR en la instancia: 9514
# ERROR en la instancia: 9522
# ERROR en la instancia: 9524
# ERROR en la instancia: 9525
# ERROR en la instancia: 9530
# ERROR en la instancia: 9532
# ERROR en la instancia: 9535
# ERROR en la instancia: 9536
# ERROR en la instancia: 9538
# ERROR en la instancia: 9540
# ERROR en la instancia: 9542
# ERROR en la instancia: 9550
# ERROR en la instancia: 9564
# ERROR en la instancia: 9565
# ERROR en la instancia: 9569
# ERROR en la instancia: 9577
# ERROR en la instancia: 9585
# ERROR en la instancia: 9588
# ERROR en la instancia: 9589
# ERROR en la instancia: 9590
# ERROR en la instancia: 9592
# ERROR en la instancia: 9594
# ERROR en la instancia: 9597
# ERROR en la instancia: 9598
# ERROR en la instancia: 9618
# ERROR en la instancia: 9619
# ERROR en la instancia: 9621
# ERROR en la instancia: 9623
# ERROR en la instancia: 9625
# ERROR en la instancia: 9628
# ERROR en la instancia: 9630
# ERROR en la instancia: 9640
# ERROR en la instancia: 9650
# ERROR en la instancia: 9668
# ERROR en la instancia: 9679
# ERROR en la instancia: 9687
# ERROR en la instancia: 9691
# ERROR en la instancia: 9693
# ERROR en la instancia: 9694
# ERROR en la instancia: 9695
# ERROR en la instancia: 9697
# ERROR en la instancia: 9700
# ERROR en la instancia: 9701
# ERROR en la instancia: 9719
# ERROR en la instancia: 9722
# ERROR en la instancia: 9725
# ERROR en la instancia: 9731
# ERROR en la instancia: 9733
# ERROR en la instancia: 9741
# ERROR en la instancia: 9751
# ERROR en la instancia: 9760
# ERROR en la instancia: 9766
# ERROR en la instancia: 9768
# ERROR en la instancia: 9771
# ERROR en la instancia: 9775
# ERROR en la instancia: 9782
# ERROR en la instancia: 9784
# ERROR en la instancia: 9786
# ERROR en la instancia: 9787
# ERROR en la instancia: 9793
# ERROR en la instancia: 9795
# ERROR en la instancia: 9799
# ERROR en la instancia: 9810
# ERROR en la instancia: 9811
# ERROR en la instancia: 9813
# ERROR en la instancia: 9826
# ERROR en la instancia: 9833
# ERROR en la instancia: 9834
# ERROR en la instancia: 9837
# ERROR en la instancia: 9847
# ERROR en la instancia: 9849
# ERROR en la instancia: 9850
# ERROR en la instancia: 9852
# ERROR en la instancia: 9862
# ERROR en la instancia: 9863
# ERROR en la instancia: 9868
# ERROR en la instancia: 9871
# ERROR en la instancia: 9872
# ERROR en la instancia: 9874
# ERROR en la instancia: 9877
# ERROR en la instancia: 9878
# ERROR en la instancia: 9879
# ERROR en la instancia: 9880
# ERROR en la instancia: 9888
# ERROR en la instancia: 9903
# ERROR en la instancia: 9909
# ERROR en la instancia: 9910
# ERROR en la instancia: 9913
# ERROR en la instancia: 9919
# ERROR en la instancia: 9930
# ERROR en la instancia: 9933
# ERROR en la instancia: 9934
# ERROR en la instancia: 9942
# ERROR en la instancia: 9948
# ERROR en la instancia: 9950
# ERROR en la instancia: 9970
# ERROR en la instancia: 9983
# ERROR en la instancia: 9986
# ERROR en la instancia: 9989
# ERROR en la instancia: 9993
# Patrones en STM: 34
# Se calculará este accuracy como en MINAS
# aciertos: 1557, clasificados: 1999
# Tiempo transcurrido: 1.0112650966666668
# Así quedan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
# Finalizó la ventana: 4 TimeStamp: 9999 t: 60.67590580000001[sec] accuracy 77.88894447223612
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# clasificados: 0
#
#  Longitud de ventana: 2000
# ERROR en la instancia: 10002
# ERROR en la instancia: 10003
# ERROR en la instancia: 10004
# ERROR en la instancia: 10007
# ERROR en la instancia: 10008
# ERROR en la instancia: 10013
# ERROR en la instancia: 10021
# ERROR en la instancia: 10024
# ERROR en la instancia: 10026
# ERROR en la instancia: 10029
# ERROR en la instancia: 10032
# ERROR en la instancia: 10034
# ERROR en la instancia: 10035
# ERROR en la instancia: 10042
# ERROR en la instancia: 10044
# ERROR en la instancia: 10045
# ERROR en la instancia: 10047
# ERROR en la instancia: 10048
# ERROR en la instancia: 10054
# ERROR en la instancia: 10057
# ERROR en la instancia: 10060
# ERROR en la instancia: 10069
# ERROR en la instancia: 10076
# ERROR en la instancia: 10078
# ERROR en la instancia: 10097
# ERROR en la instancia: 10105
# ERROR en la instancia: 10110
# ERROR en la instancia: 10117
# ERROR en la instancia: 10121
# ERROR en la instancia: 10125
# ERROR en la instancia: 10126
# ERROR en la instancia: 10132
# ERROR en la instancia: 10137
# ERROR en la instancia: 10144
# ERROR en la instancia: 10151
# ERROR en la instancia: 10155
# ERROR en la instancia: 10162
# ERROR en la instancia: 10164
# ERROR en la instancia: 10166
# ERROR en la instancia: 10171
# ERROR en la instancia: 10173
# ERROR en la instancia: 10176
# ERROR en la instancia: 10178
# ERROR en la instancia: 10179
# ERROR en la instancia: 10181
# ERROR en la instancia: 10184
# ERROR en la instancia: 10185
# ERROR en la instancia: 10190
# ERROR en la instancia: 10192
# ERROR en la instancia: 10197
# ERROR en la instancia: 10199
# ERROR en la instancia: 10200
# ERROR en la instancia: 10202
# ERROR en la instancia: 10203
# ERROR en la instancia: 10207
# ERROR en la instancia: 10209
# ERROR en la instancia: 10212
# ERROR en la instancia: 10220
# ERROR en la instancia: 10224
# ERROR en la instancia: 10228
# ERROR en la instancia: 10230
# ERROR en la instancia: 10231
# ERROR en la instancia: 10234
# ERROR en la instancia: 10236
# ERROR en la instancia: 10242
# ERROR en la instancia: 10245
# ERROR en la instancia: 10246
# ERROR en la instancia: 10251
# ERROR en la instancia: 10254
# ERROR en la instancia: 10265
# ERROR en la instancia: 10270
# ERROR en la instancia: 10272
# ERROR en la instancia: 10274
# ERROR en la instancia: 10276
# ERROR en la instancia: 10280
# ERROR en la instancia: 10288
# ERROR en la instancia: 10291
# ERROR en la instancia: 10294
# ERROR en la instancia: 10296
# ERROR en la instancia: 10301
# ERROR en la instancia: 10314
# ERROR en la instancia: 10318
# ERROR en la instancia: 10325
# ERROR en la instancia: 10328
# ERROR en la instancia: 10334
# ERROR en la instancia: 10337
# ERROR en la instancia: 10343
# ERROR en la instancia: 10351
# ERROR en la instancia: 10359
# ERROR en la instancia: 10360
# ERROR en la instancia: 10365
# ERROR en la instancia: 10367
# ERROR en la instancia: 10383
# ERROR en la instancia: 10385
# ERROR en la instancia: 10387
# ERROR en la instancia: 10389
# ERROR en la instancia: 10400
# ERROR en la instancia: 10435
# ERROR en la instancia: 10436
# ERROR en la instancia: 10438
# ERROR en la instancia: 10439
# ERROR en la instancia: 10441
# ERROR en la instancia: 10449
# ERROR en la instancia: 10452
# ERROR en la instancia: 10453
# ERROR en la instancia: 10457
# ERROR en la instancia: 10461
# ERROR en la instancia: 10464
# ERROR en la instancia: 10465
# ERROR en la instancia: 10471
# ERROR en la instancia: 10473
# ERROR en la instancia: 10476
# ERROR en la instancia: 10485
# ERROR en la instancia: 10496
# ERROR en la instancia: 10497
# ERROR en la instancia: 10506
# ERROR en la instancia: 10508
# ERROR en la instancia: 10517
# ERROR en la instancia: 10521
# ERROR en la instancia: 10538
# ERROR en la instancia: 10542
# ERROR en la instancia: 10551
# ERROR en la instancia: 10552
# ERROR en la instancia: 10556
# ERROR en la instancia: 10557
# ERROR en la instancia: 10561
# ERROR en la instancia: 10566
# ERROR en la instancia: 10567
# ERROR en la instancia: 10571
# ERROR en la instancia: 10573
# ERROR en la instancia: 10577
# ERROR en la instancia: 10578
# ERROR en la instancia: 10579
# ERROR en la instancia: 10585
# ERROR en la instancia: 10591
# ERROR en la instancia: 10595
# ERROR en la instancia: 10602
# ERROR en la instancia: 10604
# ERROR en la instancia: 10609
# ERROR en la instancia: 10614
# ERROR en la instancia: 10617
# ERROR en la instancia: 10638
# ERROR en la instancia: 10648
# ERROR en la instancia: 10652
# ERROR en la instancia: 10658
# ERROR en la instancia: 10662
# ERROR en la instancia: 10666
# ERROR en la instancia: 10672
# ERROR en la instancia: 10673
# ERROR en la instancia: 10679
# ERROR en la instancia: 10682
# ERROR en la instancia: 10683
# ERROR en la instancia: 10693
# ERROR en la instancia: 10715
# ERROR en la instancia: 10718
# ERROR en la instancia: 10721
# ERROR en la instancia: 10724
# ERROR en la instancia: 10726
# ERROR en la instancia: 10733
# ERROR en la instancia: 10734
# ERROR en la instancia: 10735
# ERROR en la instancia: 10737
# ERROR en la instancia: 10740
# ERROR en la instancia: 10746
# ERROR en la instancia: 10753
# ERROR en la instancia: 10754
# ERROR en la instancia: 10762
# ERROR en la instancia: 10764
# ERROR en la instancia: 10777
# ERROR en la instancia: 10778
# ERROR en la instancia: 10784
# ERROR en la instancia: 10789
# ERROR en la instancia: 10807
# ERROR en la instancia: 10808
# ERROR en la instancia: 10810
# ERROR en la instancia: 10814
# ERROR en la instancia: 10825
# ERROR en la instancia: 10827
# ERROR en la instancia: 10833
# ERROR en la instancia: 10846
# ERROR en la instancia: 10847
# ERROR en la instancia: 10850
# ERROR en la instancia: 10855
# ERROR en la instancia: 10860
# ERROR en la instancia: 10865
# ERROR en la instancia: 10871
# ERROR en la instancia: 10872
# ERROR en la instancia: 10873
# ERROR en la instancia: 10886
# ERROR en la instancia: 10887
# ERROR en la instancia: 10890
# ERROR en la instancia: 10891
# ERROR en la instancia: 10892
# ERROR en la instancia: 10894
# ERROR en la instancia: 10897
# ERROR en la instancia: 10908
# ERROR en la instancia: 10910
# ERROR en la instancia: 10921
# ERROR en la instancia: 10924
# ERROR en la instancia: 10925
# ERROR en la instancia: 10927
# ERROR en la instancia: 10931
# ERROR en la instancia: 10934
# ERROR en la instancia: 10938
# ERROR en la instancia: 10951
# ERROR en la instancia: 10955
# ERROR en la instancia: 10956
# ERROR en la instancia: 10957
# ERROR en la instancia: 10966
# ERROR en la instancia: 10973
# ERROR en la instancia: 10977
# ERROR en la instancia: 10979
# ERROR en la instancia: 10980
# ERROR en la instancia: 10986
# ERROR en la instancia: 10989
# ERROR en la instancia: 10999
# ERROR en la instancia: 11004
# ERROR en la instancia: 11007
# ERROR en la instancia: 11008
# ERROR en la instancia: 11012
# ERROR en la instancia: 11014
# ERROR en la instancia: 11015
# ERROR en la instancia: 11017
# ERROR en la instancia: 11021
# ERROR en la instancia: 11022
# ERROR en la instancia: 11027
# ERROR en la instancia: 11030
# ERROR en la instancia: 11036
# ERROR en la instancia: 11037
# ERROR en la instancia: 11046
# ERROR en la instancia: 11050
# ERROR en la instancia: 11057
# ERROR en la instancia: 11061
# ERROR en la instancia: 11069
# ERROR en la instancia: 11070
# ERROR en la instancia: 11073
# ERROR en la instancia: 11079
# ERROR en la instancia: 11081
# ERROR en la instancia: 11085
# ERROR en la instancia: 11090
# ERROR en la instancia: 11099
# ERROR en la instancia: 11100
# ERROR en la instancia: 11102
# ERROR en la instancia: 11103
# ERROR en la instancia: 11106
# ERROR en la instancia: 11107
# ERROR en la instancia: 11109
# ERROR en la instancia: 11110
# ERROR en la instancia: 11111
# ERROR en la instancia: 11116
# ERROR en la instancia: 11118
# ERROR en la instancia: 11122
# ERROR en la instancia: 11125
# ERROR en la instancia: 11128
# ERROR en la instancia: 11131
# ERROR en la instancia: 11141
# ERROR en la instancia: 11147
# ERROR en la instancia: 11155
# ERROR en la instancia: 11156
# ERROR en la instancia: 11159
# ERROR en la instancia: 11162
# ERROR en la instancia: 11164
# ERROR en la instancia: 11174
# ERROR en la instancia: 11177
# ERROR en la instancia: 11180
# ERROR en la instancia: 11182
# ERROR en la instancia: 11187
# ERROR en la instancia: 11188
# ERROR en la instancia: 11193
# ERROR en la instancia: 11206
# ERROR en la instancia: 11207
# ERROR en la instancia: 11211
# ERROR en la instancia: 11212
# ERROR en la instancia: 11228
# ERROR en la instancia: 11230
# ERROR en la instancia: 11241
# ERROR en la instancia: 11242
# ERROR en la instancia: 11251
# ERROR en la instancia: 11256
# ERROR en la instancia: 11266
# ERROR en la instancia: 11269
# ERROR en la instancia: 11272
# ERROR en la instancia: 11274
# ERROR en la instancia: 11280
# ERROR en la instancia: 11283
# ERROR en la instancia: 11286
# ERROR en la instancia: 11303
# ERROR en la instancia: 11310
# ERROR en la instancia: 11312
# ERROR en la instancia: 11320
# ERROR en la instancia: 11322
# ERROR en la instancia: 11325
# ERROR en la instancia: 11326
# ERROR en la instancia: 11327
# ERROR en la instancia: 11337
# ERROR en la instancia: 11338
# ERROR en la instancia: 11347
# ERROR en la instancia: 11357
# ERROR en la instancia: 11360
# ERROR en la instancia: 11362
# ERROR en la instancia: 11364
# ERROR en la instancia: 11367
# ERROR en la instancia: 11369
# ERROR en la instancia: 11373
# ERROR en la instancia: 11374
# ERROR en la instancia: 11380
# ERROR en la instancia: 11389
# ERROR en la instancia: 11393
# ERROR en la instancia: 11396
# ERROR en la instancia: 11398
# ERROR en la instancia: 11401
# ERROR en la instancia: 11404
# ERROR en la instancia: 11410
# ERROR en la instancia: 11412
# ERROR en la instancia: 11416
# ERROR en la instancia: 11420
# ERROR en la instancia: 11423
# ERROR en la instancia: 11425
# ERROR en la instancia: 11428
# ERROR en la instancia: 11429
# ERROR en la instancia: 11430
# ERROR en la instancia: 11431
# ERROR en la instancia: 11435
# ERROR en la instancia: 11436
# ERROR en la instancia: 11439
# ERROR en la instancia: 11441
# ERROR en la instancia: 11444
# ERROR en la instancia: 11446
# ERROR en la instancia: 11450
# ERROR en la instancia: 11452
# ERROR en la instancia: 11457
# ERROR en la instancia: 11463
# ERROR en la instancia: 11465
# ERROR en la instancia: 11473
# ERROR en la instancia: 11475
# ERROR en la instancia: 11482
# ERROR en la instancia: 11488
# ERROR en la instancia: 11492
# ERROR en la instancia: 11494
# ERROR en la instancia: 11497
# ERROR en la instancia: 11503
# ERROR en la instancia: 11510
# ERROR en la instancia: 11511
# ERROR en la instancia: 11518
# ERROR en la instancia: 11523
# ERROR en la instancia: 11524
# ERROR en la instancia: 11525
# ERROR en la instancia: 11533
# ERROR en la instancia: 11545
# ERROR en la instancia: 11547
# ERROR en la instancia: 11556
# ERROR en la instancia: 11558
# ERROR en la instancia: 11559
# ERROR en la instancia: 11572
# ERROR en la instancia: 11573
# ERROR en la instancia: 11581
# ERROR en la instancia: 11589
# ERROR en la instancia: 11595
# ERROR en la instancia: 11599
# ERROR en la instancia: 11601
# ERROR en la instancia: 11603
# ERROR en la instancia: 11607
# ERROR en la instancia: 11609
# ERROR en la instancia: 11611
# ERROR en la instancia: 11613
# ERROR en la instancia: 11624
# ERROR en la instancia: 11625
# ERROR en la instancia: 11630
# ERROR en la instancia: 11634
# ERROR en la instancia: 11638
# ERROR en la instancia: 11639
# ERROR en la instancia: 11655
# ERROR en la instancia: 11656
# ERROR en la instancia: 11657
# ERROR en la instancia: 11661
# ERROR en la instancia: 11665
# ERROR en la instancia: 11671
# ERROR en la instancia: 11694
# ERROR en la instancia: 11700
# ERROR en la instancia: 11704
# ERROR en la instancia: 11709
# ERROR en la instancia: 11711
# ERROR en la instancia: 11719
# ERROR en la instancia: 11720
# ERROR en la instancia: 11721
# ERROR en la instancia: 11724
# ERROR en la instancia: 11728
# ERROR en la instancia: 11729
# ERROR en la instancia: 11733
# ERROR en la instancia: 11738
# ERROR en la instancia: 11740
# ERROR en la instancia: 11743
# ERROR en la instancia: 11744
# ERROR en la instancia: 11747
# ERROR en la instancia: 11751
# ERROR en la instancia: 11752
# ERROR en la instancia: 11762
# ERROR en la instancia: 11765
# ERROR en la instancia: 11778
# ERROR en la instancia: 11786
# ERROR en la instancia: 11796
# ERROR en la instancia: 11797
# ERROR en la instancia: 11799
# ERROR en la instancia: 11801
# ERROR en la instancia: 11803
# ERROR en la instancia: 11804
# ERROR en la instancia: 11811
# ERROR en la instancia: 11813
# ERROR en la instancia: 11817
# ERROR en la instancia: 11819
# ERROR en la instancia: 11820
# ERROR en la instancia: 11827
# ERROR en la instancia: 11829
# ERROR en la instancia: 11834
# ERROR en la instancia: 11837
# ERROR en la instancia: 11839
# ERROR en la instancia: 11841
# ERROR en la instancia: 11843
# ERROR en la instancia: 11844
# ERROR en la instancia: 11845
# ERROR en la instancia: 11846
# ERROR en la instancia: 11851
# ERROR en la instancia: 11861
# ERROR en la instancia: 11862
# ERROR en la instancia: 11865
# ERROR en la instancia: 11866
# ERROR en la instancia: 11872
# ERROR en la instancia: 11875
# ERROR en la instancia: 11880
# ERROR en la instancia: 11886
# ERROR en la instancia: 11887
# ERROR en la instancia: 11890
# ERROR en la instancia: 11897
# ERROR en la instancia: 11899
# ERROR en la instancia: 11900
# ERROR en la instancia: 11908
# ERROR en la instancia: 11909
# ERROR en la instancia: 11912
# ERROR en la instancia: 11913
# ERROR en la instancia: 11922
# ERROR en la instancia: 11927
# ERROR en la instancia: 11937
# ERROR en la instancia: 11944
# ERROR en la instancia: 11947
# ERROR en la instancia: 11952
# ERROR en la instancia: 11956
# ERROR en la instancia: 11957
# ERROR en la instancia: 11959
# ERROR en la instancia: 11969
# ERROR en la instancia: 11970
# ERROR en la instancia: 11974
# ERROR en la instancia: 11976
# ERROR en la instancia: 11977
# ERROR en la instancia: 11980
# ERROR en la instancia: 11981
# ERROR en la instancia: 11983
# ERROR en la instancia: 11985
# ERROR en la instancia: 11987
# ERROR en la instancia: 11988
# ERROR en la instancia: 11997
# Patrones en STM: 34
# Se calculará este accuracy como en MINAS
# aciertos: 1540, clasificados: 2000
# Tiempo transcurrido: 1.0449538666666665
# Así quedan las clases y sus respectivos clusters.
# [3, 2]
# [5, 5]
# Finalizó la ventana: 5 TimeStamp: 11999 t: 62.697231999999985[sec] accuracy 77.0
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# clasificados: 0
#
#  Longitud de ventana: 2000
# ERROR en la instancia: 12000
# ERROR en la instancia: 12001
# ERROR en la instancia: 12003
# ERROR en la instancia: 12008
# ERROR en la instancia: 12010
# ERROR en la instancia: 12016
# ERROR en la instancia: 12021
# ERROR en la instancia: 12023
# ERROR en la instancia: 12025
# ERROR en la instancia: 12027
# ERROR en la instancia: 12028
# ERROR en la instancia: 12033
# ERROR en la instancia: 12035
# ERROR en la instancia: 12038
# ERROR en la instancia: 12045
# ERROR en la instancia: 12047
# ERROR en la instancia: 12048
# ERROR en la instancia: 12059
# ERROR en la instancia: 12063
# ERROR en la instancia: 12065
# ERROR en la instancia: 12066
# ERROR en la instancia: 12072
# ERROR en la instancia: 12074
# ERROR en la instancia: 12078
# ERROR en la instancia: 12084
# ERROR en la instancia: 12088
# ERROR en la instancia: 12103
# ERROR en la instancia: 12110
# ERROR en la instancia: 12115
# ERROR en la instancia: 12122
# ERROR en la instancia: 12127
# ERROR en la instancia: 12135
# ERROR en la instancia: 12140
# ERROR en la instancia: 12142
# ERROR en la instancia: 12143
# ERROR en la instancia: 12146
# ERROR en la instancia: 12151
# ERROR en la instancia: 12162
# ERROR en la instancia: 12170
# ERROR en la instancia: 12178
# ERROR en la instancia: 12179
# ERROR en la instancia: 12185
# ERROR en la instancia: 12187
# ERROR en la instancia: 12192
# ERROR en la instancia: 12194
# ERROR en la instancia: 12199
# ERROR en la instancia: 12201
# ERROR en la instancia: 12202
# ERROR en la instancia: 12204
# ERROR en la instancia: 12206
# ERROR en la instancia: 12211
# ERROR en la instancia: 12213
# ERROR en la instancia: 12214
# ERROR en la instancia: 12215
# ERROR en la instancia: 12216
# ERROR en la instancia: 12220
# ERROR en la instancia: 12224
# ERROR en la instancia: 12228
# ERROR en la instancia: 12240
# ERROR en la instancia: 12245
# ERROR en la instancia: 12248
# ERROR en la instancia: 12255
# ERROR en la instancia: 12267
# ERROR en la instancia: 12271
# ERROR en la instancia: 12281
# ERROR en la instancia: 12282
# ERROR en la instancia: 12284
# ERROR en la instancia: 12285
# ERROR en la instancia: 12288
# ERROR en la instancia: 12306
# ERROR en la instancia: 12312
# ERROR en la instancia: 12318
# ERROR en la instancia: 12331
# ERROR en la instancia: 12334
# ERROR en la instancia: 12338
# ERROR en la instancia: 12345
# ERROR en la instancia: 12355
# ERROR en la instancia: 12360
# ERROR en la instancia: 12372
# ERROR en la instancia: 12374
# ERROR en la instancia: 12375
# ERROR en la instancia: 12377
# ERROR en la instancia: 12382
# ERROR en la instancia: 12386
# ERROR en la instancia: 12390
# ERROR en la instancia: 12391
# ERROR en la instancia: 12393
# ERROR en la instancia: 12396
# ERROR en la instancia: 12401
# ERROR en la instancia: 12432
# ERROR en la instancia: 12436
# ERROR en la instancia: 12437
# ERROR en la instancia: 12438
# ERROR en la instancia: 12443
# ERROR en la instancia: 12455
# ERROR en la instancia: 12470
# ERROR en la instancia: 12476
# ERROR en la instancia: 12482
# ERROR en la instancia: 12483
# ERROR en la instancia: 12486
# ERROR en la instancia: 12503
# ERROR en la instancia: 12506
# ERROR en la instancia: 12510
# ERROR en la instancia: 12512
# ERROR en la instancia: 12518
# ERROR en la instancia: 12521
# ERROR en la instancia: 12523
# ERROR en la instancia: 12530
# ERROR en la instancia: 12535
# ERROR en la instancia: 12537
# ERROR en la instancia: 12541
# ERROR en la instancia: 12544
# ERROR en la instancia: 12547
# ERROR en la instancia: 12548
# ERROR en la instancia: 12550
# ERROR en la instancia: 12552
# ERROR en la instancia: 12556
# ERROR en la instancia: 12557
# ERROR en la instancia: 12558
# ERROR en la instancia: 12565
# ERROR en la instancia: 12566
# ERROR en la instancia: 12572
# ERROR en la instancia: 12590
# ERROR en la instancia: 12594
# ERROR en la instancia: 12597
# ERROR en la instancia: 12603
# ERROR en la instancia: 12605
# ERROR en la instancia: 12606
# ERROR en la instancia: 12607
# ERROR en la instancia: 12611
# ERROR en la instancia: 12620
# ERROR en la instancia: 12621
# ERROR en la instancia: 12622
# ERROR en la instancia: 12629
# ERROR en la instancia: 12631
# ERROR en la instancia: 12634
# ERROR en la instancia: 12643
# ERROR en la instancia: 12647
# ERROR en la instancia: 12650
# ERROR en la instancia: 12655
# ERROR en la instancia: 12659
# ERROR en la instancia: 12660
# ERROR en la instancia: 12661
# ERROR en la instancia: 12663
# ERROR en la instancia: 12671
# ERROR en la instancia: 12672
# ERROR en la instancia: 12673
# ERROR en la instancia: 12675
# ERROR en la instancia: 12676
# ERROR en la instancia: 12677
# ERROR en la instancia: 12685

# %% [markdown]
# -----
# -----
# -----

# %%
accuracy_ventana

# %%
Cj

# %% [markdown]
# ---
# ---
# # Guardar y graficar información
# ---
# ---

# %% [markdown]
# # Guardar el accuracy

# %%
# Importing library 
import csv
# opening the csv file in 'w+' mode 
file = open('accuracy_' + str(cadena) +'.csv', 'w+', newline ='')# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(accuracy_ventana)

# %%
Cj

# %%
## accuracy_ventana

# %%
len(Cj)

# %% [markdown]
# # Guardar tiempos

# %%
# Dataframe de clasificaciones
columns_clasificaciones = ["Ventana", 'TS', "Accuracy", "Tiempo transcurrido [sec]"]
#lista = [55, 54]                      
for clase in range(len(C_tot)):
    print(Cj[clase])
    aux_col = ["Instancias presentadas clase_" + str(C_tot[clase]), \
    "Clasificadas en clase_" + str(C_tot[clase]), "Numero de clusters en clase_" + str(C_tot[clase])]
    columns_clasificaciones = columns_clasificaciones + aux_col
columns_clasificaciones 
Tiempos = pd.DataFrame(clasificaciones, index_time, columns_clasificaciones)
Tiempos.to_csv('Tiempos_' + str(cadena) +'.csv')

# %%
Tiempos

# %% [markdown]
# # Desglose de tiempos por sección del programa

# %%
# #Dataframe de tiempo por sección
T_desglose = pd.DataFrame(tiempos_c_s, index_time, col_time)
T_desglose.to_csv('T_desglose' + str(cadena) +'.csv')

# %%
T_desglose

# %% [markdown]
# ---
# Graficas
# ---
# ---

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
DataChunk = list(range(1, n_ventana + 1))

# %%
plt.plot(DataChunk, accuracy_ventana, label = "STM =" +str(n_clusters_stm[-1])+ ", MC = " +str(num_cluster))
plt.xlabel('Data Chunk')
plt.ylabel('Accuracy (%)')
plt.title("Accuracy del banco:")
plt.legend()
plt.savefig('Accuracy.jpg')
plt.show()

# %%
tiempos = Tiempos['Tiempo transcurrido [sec]']

# %%
tiempos = tiempos/60

# %%
plt.plot(DataChunk, tiempos, label = "STM =" +str(n_clusters_stm[-1])+ ", MC = " +str(num_cluster))
plt.xlabel('Data Chunk')
plt.ylabel('Tiempo [min])')
locs, labels = plt.xticks()  # Get the current locations and labels.
#plt.xticks(np.arange(0, 250, step=20))  # Set label locations.
plt.grid(True)
plt.title("Tiempos")
plt.legend()
plt.savefig('Tiempo_x_ventana.jpg')
plt.show()

# %% [markdown]
# # Guardar microclusteres creados

# %%
# Se guardan los micro clusteres creados- - MC_j_i -  j es la clase - i el cluster - - - - -
j = 0
n_c = []
for j in range(len(Cj)): # Número de clases
    for i in range(num_cluster[j]): # Número de clusters 
        # Escribir archivos csv
        globals()['MC_'+str(Cj[j])+'_'+str(i+1)].to_csv('MC_'+str(Cj[j])+'_'+str(i+1)+'.csv')

# %% [markdown]
# # Guardar los patrones clasificados por el NACOD

# %%
# Dataframe de las instancias clasificadas correctamente
patrones_clasificaciones_NACOD = pd.DataFrame(clases, index, columns)
patrones_clasificaciones_NACOD.to_csv('patrones_clasificaciones_NACOD.csv')
patrones_clasificaciones_NACOD

# %% [markdown]
# # Guardar los patrones mandados a STM

# %% [markdown]
# Son todas las instancias que NACOD no pudo clasificar y se fueron a la memoria corta.

# %%
# Dataframe del histórico de la información de las instancias que llegaron al
# short term memory durante la ejecución del programa.
patrones_mandados_a_STM = pd.DataFrame(clases_stm, index_stm, columns_stm)
patrones_mandados_a_STM.to_csv('patrones_mandados_a_STM.csv')
patrones_mandados_a_STM

# %% [markdown]
# # Patrones que se detectaron en extensión o en nueva clase pero que son erroneos.

# %%
index_no_emerging = list(range(1,len(no_emerging)+1))
Clases_no_emerging = pd.DataFrame(no_emerging, index_no_emerging, col_no_emerging)
Clases_no_emerging.to_csv('Clusters_desechados.csv')
Clases_no_emerging

# %% [markdown]
# ---
# ---

# %%
# Como queda STM al final del análisis
short_term_memory # STM Actualizado
short_term_memory.to_csv('STM_actualizada.csv')

# %%
# Clases correctas de la STM
short_classes # Clases de la STM Actualizadas
short_classes.to_csv('STM_clases_actualizadas.csv')

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
